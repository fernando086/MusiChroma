# %% [markdown]
# ## RESUMEN DEL PIPELINE
#
# ✅ **Fases completadas:**
#
# 1. **Extracción de 102 Features**: Mel (64) + MFCC (13) + Chroma CQT (12) + Spectral (13)
# 2. **Normalización Per-Bloque**: Mean/Std computado globalmente y aplicado por bloque
# 3. **Train/Val Split**: División a nivel de canción (sin leakage)
# 4. **Serialización TFRecords**: Almacenamiento eficiente de audio + labels
# 5. **Funciones de Carga**: Parse y dataset pipeline listo para Keras
# 6. **Modelo CNN+GRU**: Arquitectura para capturar spectrogramas + dinámica temporal
#
# ### ¿Qué hace cada componente?
#
# | Fase | Propósito | Entrada | Salida |
# |------|-----------|---------|--------|
# | Extracción | 102 features por ventana 2s | Audio .mp3 | (102, n_frames) |
# | Normalización | Escala features a distribución estándar | X + scaler_info | X_normalized |
# | TFRecords | Almacenamiento comprimido | X_norm + labels | .tfrecord binarios |
# | Carga | Prepara batches para red neuronal | .tfrecord | tf.data.Dataset |
# | CNN+GRU | Predicción valence/arousal | Espectrogramas dinámicos | [valence, arousal] ∈ [-1,1] |
#
# ### Siguientes pasos:
#
# ```python
# # 1. Entrenar el modelo (ejecutar siguiente celda)
# history, model_path = train_with_validation(
#     model, train_dataset, val_dataset, epochs=20
# )
#
# # 2. Evaluar en test (si lo necesitas)
# # test_dataset = load_tfrecord_dataset(tfrecord_output, split_name="test", batch_size=32)
# # results = model.evaluate(test_dataset)
#
# # 3. Hacer predicciones
# # predictions = model.predict(val_dataset)
# ```
#
# ### Archivos generados:
#
# - `intento9/scaler_per_block_102.pkl` → Estadísticas de normalización
# - `intento9/tfrecords_102_features/` → Archivos TFRecord (train + val)
# - `intento9/best_cnn_gru.keras` → Mejor modelo entrenado

# %%
# Verificar la ruta del intérprete de Python que se está usando
import sys
print(sys.executable)
# Out:
# c:\Users\thepe\anaconda3\envs\tf_gpu_clean\python.exe

# %%
# Verificar versiones de librerías clave y disponibilidad de GPU
import tensorflow as tf
print("TF:", tf.__version__)
print("NumPy:", __import__("numpy").__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# c:\Users\thepe\anaconda3\envs\tf_gpu_clean\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# TF: 2.10.0
# NumPy: 1.24.4
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Mostrar dispositivos de computación disponibles (CPU/GPU)
import tensorflow as tf

print("Versión:", tf.__version__)
print("Dispositivos disponibles:", tf.config.list_physical_devices())
print("GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# Versión: 2.10.0
# Dispositivos disponibles: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Información detallada de compilación de TensorFlow y soporte CUDA
import tensorflow as tf
from tensorflow.python.platform import build_info as tf_build_info

print("Versión:", tf.__version__)
print(tf_build_info.build_info)
print("GPU:", tf.config.list_physical_devices('GPU'))
print("Built with CUDA?", tf.test.is_built_with_cuda())
print("Can access GPU?", tf.test.is_gpu_available())
# Out:
# Versión: 2.10.0
# OrderedDict([('cpu_compiler', 'C:/Program Files (x86)/Microsoft Visual Studio/2019/Community/VC/Tools/MSVC/14.29.30133/bin/HostX64/x64/cl.exe'), ('cuda_compute_capabilities', ['sm_35', 'sm_50', 'sm_60', 'sm_70', 'sm_75', 'compute_80']), ('cuda_version', '64_112'), ('cudart_dll_name', 'cudart64_112.dll'), ('cudnn_dll_name', 'cudnn64_8.dll'), ('cudnn_version', '64_8'), ('is_cuda_build', True), ('is_rocm_build', False), ('is_tensorrt_build', False), ('msvcp_dll_names', 'msvcp140.dll,msvcp140_1.dll'), ('nvcuda_dll_name', 'nvcuda.dll')])
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Built with CUDA? True
# WARNING:tensorflow:From C:\Users\thepe\AppData\Local\Temp\ipykernel_25704\506333081.py:9: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# Can access GPU? True

# %%
# Prueba de operación en GPU: multiplicación de matrices grandes
import tensorflow as tf

with tf.device('/GPU:0'):
    a = tf.random.normal([10000, 10000])
    b = tf.random.normal([10000, 10000])
    c = tf.matmul(a, b)

print("✅ Operación completada en GPU")
print(c)
# Out:
# ✅ Operación completada en GPU
# tf.Tensor(
# [[ 111.30223   -223.4001     114.07895   ... -170.63893    125.55569
#   -142.23758  ]
#  [   4.0314255  -33.353657   133.91571   ...  -30.121262  -163.04108
#    119.196754 ]
#  [ 120.085846    42.83405    -47.78804   ...   42.304165   -92.86868
#     60.153484 ]
#  ...
#  [ -78.10452   -195.87042    168.46191   ...  -89.76249    -74.09616
#     78.965996 ]
#  [-142.51775    104.248764  -198.23532   ...  145.90073    -87.44699
#     76.425    ]
#  [ 183.84106    198.17392     41.418602  ...  -65.43149     51.812325
#   -176.72401  ]], shape=(10000, 10000), dtype=float32)

# %% [markdown]
# LEER ARCHIVOS DE DEAM (FORMATEADOS COMO SE MUESTRA PMEMO)

# %%
# Cargar datos de anotaciones DEAM: valence (0-1) y arousal (0-1) por segundo
import pandas as pd

# Leer CSV con anotaciones de valence y arousal para cada canción (por segundo)
deam_valence = pd.read_csv("C:/Users/thepe/Downloads/DEAM/DEAM_Annotations/annotations/annotations averaged per song/dynamic (per second annotations)/valence.csv")
deam_arousal = pd.read_csv("C:/Users/thepe/Downloads/DEAM/DEAM_Annotations/annotations/annotations averaged per song/dynamic (per second annotations)/arousal.csv")

# %%
deam_valence
# Out:
#       song_id  sample_15000ms  sample_15500ms  sample_16000ms  sample_16500ms  \
# 0           2       -0.073341       -0.074661       -0.074077       -0.078154
# 1           3       -0.189702       -0.187765       -0.183740       -0.188761
# 2           4        0.154286        0.148063        0.146956        0.151180
# 3           5        0.149053        0.148260        0.147369        0.146956
# 4           7        0.342816        0.345193        0.332023        0.328887
# ...       ...             ...             ...             ...             ...
# 1797     2054        0.088000        0.088000        0.086000        0.080000
# 1798     2055        0.128000        0.098000        0.080000        0.080000
# 1799     2056        0.198000        0.182000        0.164000        0.156000
# 1800     2057       -0.071667       -0.061667       -0.076667       -0.078333
# 1801     2058       -0.152000       -0.154000       -0.160000       -0.162000
#
#       sample_17000ms  sample_17500ms  sample_18000ms  sample_18500ms  \
# 0          -0.081588       -0.080873       -0.083611       -0.082145
# 1          -0.193704       -0.190834       -0.189041       -0.197554
# 2           0.135942        0.076832        0.084487        0.088513
# 3           0.147857        0.146927        0.145651        0.145795
# 4           0.327603        0.329011        0.327883        0.334822
# ...              ...             ...             ...             ...
# 1797        0.070000        0.068000        0.076000        0.078000
# 1798        0.088000        0.088000        0.086000        0.078000
# 1799        0.148000        0.142000        0.144000        0.146000
# 1800       -0.081667       -0.046667       -0.046667       -0.068333
# 1801       -0.158000       -0.162000       -0.166000       -0.164000
#
#       sample_19000ms  ...  sample_621500ms  sample_622000ms  sample_622500ms  \
# 0          -0.081632  ...              NaN              NaN              NaN
# 1          -0.202871  ...              NaN              NaN              NaN
# 2           0.090944  ...              NaN              NaN              NaN
# 3           0.146420  ...              NaN              NaN              NaN
# 4           0.328447  ...              NaN              NaN              NaN
# ...              ...  ...              ...              ...              ...
# 1797        0.074000  ...              NaN              NaN              NaN
# 1798        0.068000  ...              NaN              NaN              NaN
# 1799        0.160000  ...              NaN              NaN              NaN
# 1800       -0.113333  ...              NaN              NaN              NaN
# 1801       -0.172000  ...              NaN              NaN              NaN
#
#       sample_623000ms  sample_623500ms  sample_624000ms  sample_624500ms  \
# 0                 NaN              NaN              NaN              NaN
# 1                 NaN              NaN              NaN              NaN
# 2                 NaN              NaN              NaN              NaN
# 3                 NaN              NaN              NaN              NaN
# 4                 NaN              NaN              NaN              NaN
# ...               ...              ...              ...              ...
# 1797              NaN              NaN              NaN              NaN
# 1798              NaN              NaN              NaN              NaN
# 1799              NaN              NaN              NaN              NaN
# 1800              NaN              NaN              NaN              NaN
# 1801              NaN              NaN              NaN              NaN
#
#       sample_625000ms  sample_625500ms  sample_626000ms
# 0                 NaN              NaN              NaN
# 1                 NaN              NaN              NaN
# 2                 NaN              NaN              NaN
# 3                 NaN              NaN              NaN
# 4                 NaN              NaN              NaN
# ...               ...              ...              ...
# 1797              NaN              NaN              NaN
# 1798              NaN              NaN              NaN
# 1799              NaN              NaN              NaN
# 1800              NaN              NaN              NaN
# 1801              NaN              NaN              NaN
#
# [1802 rows x 1224 columns]

# %%
deam_arousal
# Out:
#       song_id  sample_15000ms  sample_15500ms  sample_16000ms  sample_16500ms  \
# 0           2       -0.109386       -0.114942   -1.164126e-01       -0.118613
# 1           3       -0.110846       -0.123973   -1.311026e-01       -0.135956
# 2           4        0.222327        0.179446    1.783881e-01        0.184056
# 3           5       -0.255613       -0.251579   -2.519577e-01       -0.251124
# 4           7        0.464234        0.460789    4.609907e-01        0.461046
# ...       ...             ...             ...             ...             ...
# 1797     2054       -0.190000       -0.182000   -1.800000e-01       -0.158000
# 1798     2055       -0.070000       -0.086000   -1.100000e-01       -0.072000
# 1799     2056       -0.044000       -0.044000   -4.400000e-02       -0.044000
# 1800     2057        0.413333        0.413333    4.116667e-01        0.410000
# 1801     2058        0.008000        0.002000   -2.775558e-18        0.006000
#
#       sample_17000ms  sample_17500ms  sample_18000ms  sample_18500ms  \
# 0      -1.264569e-01       -0.133199       -0.136855       -0.144713
# 1      -1.407755e-01       -0.144664       -0.163118       -0.165218
# 2       1.760421e-01        0.178720        0.176345        0.175793
# 3      -2.507627e-01       -0.251957       -0.251957       -0.251957
# 4       4.572397e-01        0.465702        0.471809        0.469918
# ...              ...             ...             ...             ...
# 1797   -1.560000e-01       -0.150000       -0.152000       -0.150000
# 1798   -6.200000e-02       -0.062000       -0.076000       -0.062000
# 1799   -4.200000e-02       -0.046000       -0.050000       -0.052000
# 1800    4.066667e-01        0.410000        0.401667        0.371667
# 1801   -5.551115e-18        0.002000        0.002000        0.002000
#
#       sample_19000ms  ...  sample_622000ms  sample_622500ms  sample_623000ms  \
# 0          -0.138985  ...              NaN              NaN              NaN
# 1          -0.158858  ...              NaN              NaN              NaN
# 2           0.176154  ...              NaN              NaN              NaN
# 3          -0.251957  ...              NaN              NaN              NaN
# 4           0.473377  ...              NaN              NaN              NaN
# ...              ...  ...              ...              ...              ...
# 1797       -0.150000  ...              NaN              NaN              NaN
# 1798       -0.042000  ...              NaN              NaN              NaN
# 1799       -0.052000  ...              NaN              NaN              NaN
# 1800        0.340000  ...              NaN              NaN              NaN
# 1801        0.006000  ...              NaN              NaN              NaN
#
#       sample_623500ms  sample_624000ms  sample_624500ms  sample_625000ms  \
# 0                 NaN              NaN              NaN              NaN
# 1                 NaN              NaN              NaN              NaN
# 2                 NaN              NaN              NaN              NaN
# 3                 NaN              NaN              NaN              NaN
# 4                 NaN              NaN              NaN              NaN
# ...               ...              ...              ...              ...
# 1797              NaN              NaN              NaN              NaN
# 1798              NaN              NaN              NaN              NaN
# 1799              NaN              NaN              NaN              NaN
# 1800              NaN              NaN              NaN              NaN
# 1801              NaN              NaN              NaN              NaN
#
#       sample_625500ms  sample_626000ms  sample_626500ms
# 0                 NaN              NaN              NaN
# 1                 NaN              NaN              NaN
# 2                 NaN              NaN              NaN
# 3                 NaN              NaN              NaN
# 4                 NaN              NaN              NaN
# ...               ...              ...              ...
# 1797              NaN              NaN              NaN
# 1798              NaN              NaN              NaN
# 1799              NaN              NaN              NaN
# 1800              NaN              NaN              NaN
# 1801              NaN              NaN              NaN
#
# [1802 rows x 1225 columns]

# %%
# Transformar datos DEAM de formato ancho (una fila por canción, múltiples columnas por tiempo)
# a formato largo (una fila por canción-tiempo)
import pandas as pd

# Pivotar de formato ancho a largo: crea filas (song_id, frame, valor)
deam_valence_long = deam_valence.melt(id_vars=["song_id"],
                                      var_name="frame",
                                      value_name="valence")
deam_arousal_long = deam_arousal.melt(id_vars=["song_id"],
                                      var_name="frame",
                                      value_name="arousal")

# Combinar valence y arousal en un solo DataFrame
deam = pd.merge(deam_valence_long, deam_arousal_long,
                on=["song_id", "frame"])

# Convertir frame de "sample_15000ms" a segundos (tiempo numérico)
deam["time"] = deam["frame"].str.replace("sample_", "").str.replace("ms", "").astype(int) / 1000
deam = deam.drop(columns=["frame"])

# %%
# Renombrar columnas para estandarizar (musicId, frameTime) y ordenar por canción y tiempo
deam = deam.rename(columns={"song_id": "musicId", "time": "frameTime"})
deam = deam.sort_values(by=["musicId", "frameTime"]).reset_index(drop=True)

# %%
deam
# Out:
#          musicId   valence   arousal  frameTime
# 0              2 -0.073341 -0.109386       15.0
# 1              2 -0.074661 -0.114942       15.5
# 2              2 -0.074077 -0.116413       16.0
# 3              2 -0.078154 -0.118613       16.5
# 4              2 -0.081588 -0.126457       17.0
# ...          ...       ...       ...        ...
# 2203841     2058       NaN       NaN      624.0
# 2203842     2058       NaN       NaN      624.5
# 2203843     2058       NaN       NaN      625.0
# 2203844     2058       NaN       NaN      625.5
# 2203845     2058       NaN       NaN      626.0
#
# [2203846 rows x 4 columns]

# %%
# Cargar datos de PMEmo: anotaciones de valence y arousal (dinámicas por segundo)
pmemo = pd.read_csv("C:/Users/thepe/Downloads/PMEmo2019/PMEmo2019/annotations/dynamic_annotations.csv")

# %%
pmemo
# Out:
#        musicId  frameTime  Arousal(mean)  Valence(mean)
# 0            1       15.5       0.437663       0.559975
# 1            1       16.0       0.437775       0.560650
# 2            1       16.5       0.443125       0.559900
# 3            1       17.0       0.442887       0.560212
# 4            1       17.5       0.444563       0.563337
# ...        ...        ...            ...            ...
# 36429     1000       75.0       0.657438       0.593450
# 36430     1000       75.5       0.641650       0.591437
# 36431     1000       76.0       0.641650       0.588437
# 36432     1000       76.5       0.637537       0.588437
# 36433     1000       77.0       0.577650       0.588112
#
# [36434 rows x 4 columns]

# %%
# Renombrar columnas de PMEmo para estandarizar el nombre
pmemo = pmemo.rename(columns={
    "Arousal(mean)": "arousal",
    "Valence(mean)": "valence"
})

# %% [markdown]
# NORMALIZACIÓN (-1, 1)

# %%
# Normalizar PMEmo de rango [0,1] a [-1,1] (como DEAM está originalmente en [0,1])
# Usar fórmula: normalized = 2 * original - 1
pmemo["arousal"] = 2 * pmemo["arousal"] - 1
pmemo["valence"] = 2 * pmemo["valence"] - 1

# %%
pmemo
# Out:
#        musicId  frameTime   arousal   valence
# 0            1       15.5 -0.124675  0.119950
# 1            1       16.0 -0.124450  0.121300
# 2            1       16.5 -0.113750  0.119800
# 3            1       17.0 -0.114225  0.120425
# 4            1       17.5 -0.110875  0.126675
# ...        ...        ...       ...       ...
# 36429     1000       75.0  0.314875  0.186900
# 36430     1000       75.5  0.283300  0.182875
# 36431     1000       76.0  0.283300  0.176875
# 36432     1000       76.5  0.275075  0.176875
# 36433     1000       77.0  0.155300  0.176225
#
# [36434 rows x 4 columns]

# %% [markdown]
# AGREGAR COLUMNA PARA IDENTIFICAR DATASET Y CANCIÓN

# %%
# Agregar columna "dataset" para identificar fuente: DEAM o PMEmo
# Esto permite saber qué dataset tiene cada anotación
deam["dataset"] = "DEAM"

# Hacer lo mismo para PMEmo
pmemo["dataset"] = "PMEmo"

# %% [markdown]
# UNIFICAR

# %%
# Combinar DEAM y PMEmo en un único DataFrame para procesamiento unificado
all_data = pd.concat([deam, pmemo], ignore_index=True)

# %%
all_data
# Out:
#          musicId   valence   arousal  frameTime dataset
# 0              2 -0.073341 -0.109386       15.0    DEAM
# 1              2 -0.074661 -0.114942       15.5    DEAM
# 2              2 -0.074077 -0.116413       16.0    DEAM
# 3              2 -0.078154 -0.118613       16.5    DEAM
# 4              2 -0.081588 -0.126457       17.0    DEAM
# ...          ...       ...       ...        ...     ...
# 2240275     1000  0.186900  0.314875       75.0   PMEmo
# 2240276     1000  0.182875  0.283300       75.5   PMEmo
# 2240277     1000  0.176875  0.283300       76.0   PMEmo
# 2240278     1000  0.176875  0.275075       76.5   PMEmo
# 2240279     1000  0.176225  0.155300       77.0   PMEmo
#
# [2240280 rows x 5 columns]

# %% [markdown]
# Revisar si existen nulos INTERNOS

# %%
# Detectar valores NaN DENTRO del rango válido de cada canción
# Esto identifica anotaciones faltantes mientras la canción estaba siendo anotada
# (no es falta de audio, sino anotación incompleta)
internal_nans = []

for (dataset, musicId), group in all_data.groupby(["dataset", "musicId"]):
    group = group.sort_values("frameTime")

    # Rango válido: desde min hasta max frameTime que tiene anotaciones válidas
    valid = group.dropna(subset=["valence", "arousal"])
    if valid.empty:
        continue  # Canción sin anotaciones útiles

    min_t, max_t = valid["frameTime"].min(), valid["frameTime"].max()

    # Filtrar solo los tiempos que están dentro del rango válido
    mask_range = (group["frameTime"] >= min_t) & (group["frameTime"] <= max_t)
    in_range = group[mask_range]

    # Buscar NaN dentro de este rango
    nan_rows = in_range[in_range["valence"].isnull() | in_range["arousal"].isnull()]

    if not nan_rows.empty:
        internal_nans.append(nan_rows)

if internal_nans:
    internal_nans = pd.concat(internal_nans, ignore_index=True)
else:
    internal_nans = pd.DataFrame()

print(f"Total de nulos internos encontrados: {len(internal_nans)}")
print(internal_nans.head(20))
# Out:
# Total de nulos internos encontrados: 0
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Revisar si existen nulos EXTERNOS

# %%
# Contar valores faltantes por columna
# Si hay muchos NaN en valence/arousal, significa datos incompletos
print(all_data.isnull().sum())
# Out:
# musicId            0
# valence      2073848
# arousal      2073848
# frameTime          0
# dataset            0
# dtype: int64

# %%
# Mostrar muestras donde faltan valores de valence o arousal
nulos = all_data[all_data["valence"].isnull() | all_data["arousal"].isnull()]
print(nulos.head())
# Out:
#     musicId  valence  arousal  frameTime dataset
# 60        2      NaN      NaN       45.0    DEAM
# 61        2      NaN      NaN       45.5    DEAM
# 62        2      NaN      NaN       46.0    DEAM
# 63        2      NaN      NaN       46.5    DEAM
# 64        2      NaN      NaN       47.0    DEAM

# %% [markdown]
# ELIMINACIÓN DE NULOS (PORQUE LA CANCIÓN YA TERMINÓ)

# %%
# Crear versión limpia del dataset: eliminar filas con NaN en valence o arousal
# Estos NaN representan muestras al final de la canción (después del audio disponible)
all_data_clean = all_data.dropna(subset=["valence", "arousal"]).reset_index(drop=True)

# %%
# Verificar que no quedan valores NaN en las columnas críticas
print(all_data_clean.isnull().sum())
# Out:
# musicId      0
# valence      0
# arousal      0
# frameTime    0
# dataset      0
# dtype: int64

# %%
all_data_clean.count() # 166429 para todas las columnas
# Out:
# musicId      166429
# valence      166429
# arousal      166429
# frameTime    166429
# dataset      166429
# dtype: int64

# %%
all_data_clean.head()
# Out:
#    musicId   valence   arousal  frameTime dataset
# 0        2 -0.073341 -0.109386       15.0    DEAM
# 1        2 -0.074661 -0.114942       15.5    DEAM
# 2        2 -0.074077 -0.116413       16.0    DEAM
# 3        2 -0.078154 -0.118613       16.5    DEAM
# 4        2 -0.081588 -0.126457       17.0    DEAM

# %%
all_data_clean.tail()
# Out:
#         musicId   valence   arousal  frameTime dataset
# 166424     1000  0.186900  0.314875       75.0   PMEmo
# 166425     1000  0.182875  0.283300       75.5   PMEmo
# 166426     1000  0.176875  0.283300       76.0   PMEmo
# 166427     1000  0.176875  0.275075       76.5   PMEmo
# 166428     1000  0.176225  0.155300       77.0   PMEmo

# %% [markdown]
# VERIFICACIÓN DE DATOS CRÍTICOS

# %%
# Función para verificar que las anotaciones están en el rango [-1, 1]
# y calcular estadísticas básicas (media, desv.est.) por dataset
def check_label_distribution(all_data_clean):
    print("=== Distribución de Labels ===")
    print("Valence - Min: %.3f, Max: %.3f, Mean: %.3f" % 
          (all_data_clean['valence'].min(), all_data_clean['valence'].max(), 
           all_data_clean['valence'].mean()))
    print("Arousal - Min: %.3f, Max: %.3f, Mean: %.3f" % 
          (all_data_clean['arousal'].min(), all_data_clean['arousal'].max(), 
           all_data_clean['arousal'].mean()))
    
    # Mostrar estadísticas separadas por cada dataset
    for dataset in all_data_clean['dataset'].unique():
        subset = all_data_clean[all_data_clean['dataset'] == dataset]
        print(f"\n{dataset}: {len(subset)} samples")
        print(f"Valence: mean={subset['valence'].mean():.3f}, std={subset['valence'].std():.3f}")
        print(f"Arousal: mean={subset['arousal'].mean():.3f}, std={subset['arousal'].std():.3f}")

check_label_distribution(all_data_clean)
# Out:
# === Distribución de Labels ===
# Valence - Min: -0.832, Max: 0.859, Mean: 0.107
# Arousal - Min: -0.809, Max: 0.943, Mean: 0.158
#
# DEAM: 129995 samples
# Valence: mean=0.077, std=0.251
# Arousal: mean=0.127, std=0.283
#
# PMEmo: 36434 samples
# Valence: mean=0.214, std=0.320
# Arousal: mean=0.265, std=0.354

# %% [markdown]
# HALLAR RUTA DE ARCHIVO

# %%
# Configurar rutas base para acceder a los archivos de audio
# Cada dataset (DEAM, PMEmo) tiene su propia carpeta con archivos .mp3
import os

AUDIO_BASE = {
    "DEAM": "C:/Users/thepe/Downloads/DEAM/DEAM_audio/MEMD_audio",
    "PMEmo": "C:/Users/thepe/Downloads/PMEmo2019/PMEmo2019/chorus",
}

OUTPUT_PATH = "C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED"
os.makedirs(OUTPUT_PATH, exist_ok=True)

def get_audio_path(row):
    """
    Construir la ruta completa al archivo de audio basándose en dataset y musicId
    """
    base_path = AUDIO_BASE.get(row["dataset"])
    if base_path is None:
        raise ValueError(f"Dataset desconocido: {row['dataset']}")
    return os.path.join(base_path, f"{row['musicId']}.mp3")

# %% [markdown]
# ### FASE 1: EXTRACCIÓN DE 102 FEATURES MUSICALES

# %%
# Importar librerías para procesamiento de audio y análisis numérico
import librosa
import numpy as np
from scipy import stats
import warnings
warnings.filterwarnings('ignore')

# ==================== PARÁMETROS GLOBALES PARA AUDIO ====================
SAMPLE_RATE = 22050          # Frecuencia de muestreo estándar (Hz)
WINDOW_SIZE = 2              # Ventana temporal: 2 segundos por muestra
HOP_LENGTH = 512             # Salto entre frames de análisis (~23ms)
N_MELS = 64                  # Número de bandas de filtro mel

# ==================== DEFINICIÓN GLOBAL DE BLOQUES DE FEATURES ====================
# NUNCA repliques esta lista - debe estar centralizada para evitar inconsistencias
FEATURE_BLOCKS_FIXED = [
    ("Mel", 64),                    # Mel Spectrogram: 64 bins
    ("MFCC", 13),                   # Coeficientes Mel-Frequency Cepstral: 13
    ("Chroma_CQT", 12),             # Pitch class features: 12 notas musicales
    ("Spectral_Centroid", 1),       # Centro de gravedad espectral: 1
    ("Spectral_Bandwidth", 1),      # Ancho de banda espectral: 1
    ("Spectral_Contrast", 7),       # Contraste espectral (7 bandas): 7
    ("Spectral_Rolloff", 1),        # Frecuencia de corte espectral: 1
    ("Spectral_Flatness", 1),       # Planicidad espectral: 1
    ("RMS", 1),                     # Root Mean Square energy: 1
    ("Zero_Crossing", 1),           # Tasa de cruces por cero: 1
]

# Validar que suma total sea 102
TOTAL_FEATURES = sum(count for _, count in FEATURE_BLOCKS_FIXED)
print(f"✅ Total features definidos: {TOTAL_FEATURES}")
# Out:
# ✅ Total features definidos: 102

# %%
def load_centered_audio_segment(audio_path, center_time_sec, window_sec=2, sr=SAMPLE_RATE):
    """
    Carga un segmento de audio CENTRADO en 'center_time_sec'.
    
    Ejemplo: center_time=10, window_sec=2 → carga de 9 a 11 segundos
    
    Si el segmento está fuera de límites:
    - Rellena con ceros al principio (si center_time < 1 segundo)
    - Rellena con ceros al final (si está cerca del fin de la canción)
    
    Args:
        audio_path: ruta al archivo .mp3
        center_time_sec: tiempo en segundos donde centrar la ventana
        window_sec: tamaño de ventana en segundos (default 2)
        sr: sample rate (default 22050)
    
    Returns:
        (y, sr): audio array y sample rate, o (None, sr) si hay error
    """
    start_sec = center_time_sec - window_sec / 2
    end_sec = center_time_sec + window_sec / 2
    
    # Cargar archivo de audio completo
    try:
        y, sr = librosa.load(audio_path, sr=sr)
    except Exception as e:
        print(f"❌ Error cargando {audio_path}: {e}")
        return None, sr
    
    # Convertir tiempo a índices de samples
    start_sample = max(0, int(start_sec * sr))
    end_sample = min(len(y), int(end_sec * sr))
    
    # Extraer el segmento especificado
    segment = y[start_sample:end_sample]
    
    # Rellenar si es necesario (si está muy cerca del inicio o final)
    target_length = int(window_sec * sr)
    if len(segment) < target_length:
        samples_before = start_sample - int(start_sec * sr)
        segment = np.pad(segment, (samples_before, target_length - len(segment) - samples_before), mode='constant')
    
    return segment[:target_length], sr

def extract_features(y, sr=SAMPLE_RATE, hop_length=HOP_LENGTH):
    """
    Extrae 102 features musicales en orden específico.
    
    El orden es CRÍTICO para que coincida con FEATURE_BLOCKS_FIXED.
    
    Args:
        y: audio waveform (array de samples)
        sr: sample rate (Hz)
        hop_length: salto entre frames
    
    Returns:
        X: ndarray de forma (102, n_frames) o None si hay error
    """
    if y is None or len(y) == 0:
        return None
    
    features_list = []
    
    # 1. Mel Spectrogram (64 features) - representación tiempo-frecuencia
    S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=N_MELS, hop_length=hop_length)
    S_db = librosa.power_to_db(S, ref=np.max)  # Convertir a dB
    features_list.append(S_db)  # Forma: (64, n_frames)
    
    # 2. MFCC (13 features) - coeficientes mel-frequency cepstral (estáticos, SIN deltas)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13, hop_length=hop_length)
    features_list.append(mfcc)  # Forma: (13, n_frames)
    
    # 3. Chroma CQT (12 features) - notas musicales (C, C#, D, ..., B)
    chroma_cqt = librosa.feature.chroma_cqt(y=y, sr=sr, hop_length=hop_length)
    features_list.append(chroma_cqt)  # Forma: (12, n_frames)
    
    # 4-10. Features espectrales varios
    spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sr, hop_length=hop_length)
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr, hop_length=hop_length)
    spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr, hop_length=hop_length)
    spectral_rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr, hop_length=hop_length)
    
    features_list.append(spectral_centroid)   # Forma: (1, n_frames)
    features_list.append(spectral_bandwidth)  # Forma: (1, n_frames)
    features_list.append(spectral_contrast)   # Forma: (7, n_frames)
    features_list.append(spectral_rolloff)    # Forma: (1, n_frames)
    
    # 11-12. Planicidad espectral y energía RMS
    spectral_flatness = librosa.feature.spectral_flatness(y=y, hop_length=hop_length)
    rms = librosa.feature.rms(y=y, hop_length=hop_length)
    
    features_list.append(spectral_flatness)   # Forma: (1, n_frames)
    features_list.append(rms)                 # Forma: (1, n_frames)
    
    # 13. Tasa de cruces por cero - cambios de signo en la onda (indica ruido/fricativos)
    zcr = librosa.feature.zero_crossing_rate(y, hop_length=hop_length)
    features_list.append(zcr)                 # Forma: (1, n_frames)
    
    # Concatenar todas en un array de (102, n_frames)
    X = np.vstack(features_list)
    
    return X

print("✅ Funciones de carga y extracción de features definidas")
# Out:
# ✅ Funciones de carga y extracción de features definidas

# %%
def get_window_labels(row, all_data_clean, window_sec=2):
    """
    Obtiene los labels (valence, arousal) promediados para la ventana de tiempo.
    
    Si múltiples anotaciones caen en la ventana de 2 segundos, promediarlas.
    Si no hay anotaciones disponibles en la ventana, retorna (None, None).
    
    Args:
        row: fila de datos (dataset, musicId, frameTime, ...)
        all_data_clean: DataFrame completo con todas las anotaciones
        window_sec: tamaño de ventana en segundos
    
    Returns:
        (val_mean, aro_mean) o (None, None)
    """
    dataset = row["dataset"]
    musicId = row["musicId"]
    center_time = row["frameTime"]
    
    # Definir rango temporal: center_time ± window_sec/2
    start_time = center_time - window_sec / 2
    end_time = center_time + window_sec / 2
    
    # Filtrar anotaciones de la MISMA canción que caen dentro del rango
    same_song = all_data_clean[
        (all_data_clean["dataset"] == dataset) &
        (all_data_clean["musicId"] == musicId) &
        (all_data_clean["frameTime"] >= start_time) &
        (all_data_clean["frameTime"] <= end_time)
    ]
    
    if same_song.empty:
        return None, None
    
    # Promediar valence y arousal de todas las anotaciones en la ventana
    val_mean = same_song["valence"].mean()
    aro_mean = same_song["arousal"].mean()
    
    return val_mean, aro_mean

print("✅ Función de agregación de labels definida")
# Out:
# ✅ Función de agregación de labels definida

# %% [markdown]
# ### FASE 2: COMPUTAR SCALER GLOBAL (normalización per-bloque)

# %%
import joblib

def compute_global_scaler(all_data_clean, sample_limit=5000, random_seed=42):
    """
    Computa estadísticas de normalización (mean, std) PER BLOQUE de features.
    
    Procesa una muestra del dataset para acelerar, luego calcula mean/std
    para cada bloque (Mel, MFCC, Chroma, etc.)
    
    CRÍTICO: Este scaler se aplicará después para normalizar TODOS los features.
    
    Args:
        all_data_clean: DataFrame con [musicId, frameTime, valence, arousal, dataset]
        sample_limit: número máximo de muestras a usar (para acelerar cálculo)
        random_seed: para reproducibilidad
    
    Returns:
        dict con estructura: 
        {
            "block_name": {
                "mean": array de means,
                "std": array de desv.est,
                "count": número de features en ese bloque
            },
            ...
        }
    """
    np.random.seed(random_seed) # Fijar semilla para reproducibilidad
    
    # Muestrear filas aleatoriamente
    sample_indices = np.random.choice(len(all_data_clean), 
                                      size=min(sample_limit, len(all_data_clean)),
                                      replace=False)
    sample_df = all_data_clean.iloc[sample_indices].reset_index(drop=True) # DataFrame muestreado
    
    print(f"📊 Computando scaler con {len(sample_df)} muestras...")
    
    scaler_info = {} # Diccionario para guardar mean/std por bloque
    block_start = 0 # Índice inicial para cada bloque de features
    
    # Iterar sobre cada bloque de features
    for block_name, block_count in FEATURE_BLOCKS_FIXED:
        block_features = []
        
        for idx, row in sample_df.iterrows():
            audio_path = get_audio_path(row)
            
            try:
                # Cargar y extraer features para esta muestra
                y, sr = load_centered_audio_segment(audio_path, row["frameTime"])
                if y is None:
                    continue
                
                X = extract_features(y, sr)
                if X is None:
                    continue
                
                # Extraer solo este bloque específico
                block_data = X[block_start:block_start + block_count, :] # Extraer bloque
                block_features.append(block_data.flatten()) # Agregar features del bloque
                
            except Exception as e:
                print(f"⚠️  Error en {audio_path}: {e}")
                continue
        
        # Calcular estadísticas para este bloque
        if block_features:
            block_array = np.array(block_features)
            scaler_info[block_name] = {
                "mean": block_array.mean(axis=0),
                "std": block_array.std(axis=0),
                "count": block_count,
            }
            print(f"  ✅ {block_name}: mean≈{scaler_info[block_name]['mean'].mean():.4f}, "
                  f"std≈{scaler_info[block_name]['std'].mean():.4f}")
        else:
            print(f"  ⚠️  {block_name}: sin datos válidos")
        
        block_start += block_count
    
    # Guardar scaler para uso posterior
    scaler_path = os.path.join(OUTPUT_PATH, "scaler_per_block_102.pkl")
    joblib.dump(scaler_info, scaler_path)
    print(f"\n✅ Scaler guardado en: {scaler_path}")
    
    return scaler_info

# %%
# Computar scaler (CRITICAL para normalización posterior)
scaler_info = compute_global_scaler(all_data_clean, sample_limit=5000)

# %%
# Cargar scaler existente si está disponible, de lo contrario calcularlo
scaler_path = os.path.join(OUTPUT_PATH, "scaler_per_block_102.pkl")

if os.path.exists(scaler_path):
    # Si ya existe el scaler, cargarlo (más rápido)
    scaler_info = joblib.load(scaler_path)
    print(f"✅ Scaler cargado desde: {scaler_path}")
    print(f"   Bloques disponibles: {list(scaler_info.keys())}")
else:
    # Si no existe, calcularlo a partir de muestras
    print(f"⚠️  Scaler no encontrado en {scaler_path}")
    print(f"   Ejecutando compute_global_scaler()...")
    scaler_info = compute_global_scaler(all_data_clean, sample_limit=5000)
# Out:
# ⚠️  Scaler no encontrado en C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\scaler_per_block_102.pkl
#    Ejecutando compute_global_scaler()...
# 📊 Computando scaler con 5000 muestras...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 13
#      11 print(f"⚠️  Scaler no encontrado en {scaler_path}")
#      12 print(f"   Ejecutando compute_global_scaler()...")
# ---> 13 scaler_info = compute_global_scaler(all_data_clean, sample_limit=5000)
#
# Cell In[38], line 54, in compute_global_scaler(all_data_clean, sample_limit, random_seed)
#      51 if y is None:
#      52     continue
# ---> 54 X = extract_features(y, sr)
#      55 if X is None:
#      56     continue
#
# Cell In[36], line 74, in extract_features(y, sr, hop_length)
#      71 features_list.append(mfcc)  # Forma: (13, n_frames)
#      73 # 3. Chroma CQT (12 features) - notas musicales (C, C#, D, ..., B)
# ---> 74 chroma_cqt = librosa.feature.chroma_cqt(y=y, sr=sr, hop_length=hop_length)
#      75 features_list.append(chroma_cqt)  # Forma: (12, n_frames)
#      77 # 4-10. Features espectrales varios
#
# File c:\Users\thepe\anaconda3\envs\tf_gpu_clean\lib\site-packages\librosa\feature\spectral.py:1386, in chroma_cqt(y, sr, C, hop_length, fmin, norm, threshold, tuning, n_chroma, n_octaves, window, bins_per_octave, cqt_mode)
#    1381     if y is None:
#    1382         raise ParameterError(
#    1383             "At least one of C or y must be provided to compute chroma"
#    1384         )
#    1385     C = np.abs(
# -> 1386         cqt_func[cqt_mode](
#    1387             y,
#    1388             sr=sr,
#    1389             hop_length=hop_length,
#    1390             fmin=fmin,
#    1391             n_bins=n_octaves * bins_per_octave,
#    1392             bins_per_octave=bins_per_octave,
#    1393             tuning=tuning,
#    1394         )
#    1395     )
#    1397 # Map to chroma
#    1398 cq_to_chr = filters.cq_to_chroma(
#    1399     C.shape[-2],
#    1400     bins_per_octave=bins_per_octave,
#    (...)
#    1403     window=window,
#    1404 )
#
# File c:\Users\thepe\anaconda3\envs\tf_gpu_clean\lib\site-packages\librosa\core\constantq.py:171, in cqt(y, sr, hop_length, fmin, n_bins, bins_per_octave, tuning, filter_scale, norm, sparsity, window, scale, pad_mode, res_type, dtype)
#      46 """Compute the constant-Q transform of an audio signal.
#      47
#      48 This implementation is based on the recursive sub-sampling method
#    (...)
#     168        [5.147e-02, 6.959e-02, ..., 1.694e-05, 5.811e-06]])
#     169 """
#     170 # CQT is the special case of VQT with gamma=0
# --> 171 return vqt(
#     172     y=y,
#     173     sr=sr,
#     174     hop_length=hop_length,
#     175     fmin=fmin,
#     176     n_bins=n_bins,
#     177     intervals="equal",
#     178     gamma=0,
#     179     bins_per_octave=bins_per_octave,
#     180     tuning=tuning,
#     181     filter_scale=filter_scale,
#     182     norm=norm,
#     183     sparsity=sparsity,
#     184     window=window,
#     185     scale=scale,
#     186     pad_mode=pad_mode,
#     187     res_type=res_type,
#     188     dtype=dtype,
#     189 )
#
# File c:\Users\thepe\anaconda3\envs\tf_gpu_clean\lib\site-packages\librosa\core\constantq.py:981, in vqt(y, sr, hop_length, fmin, n_bins, intervals, gamma, bins_per_octave, tuning, filter_scale, norm, sparsity, window, scale, pad_mode, res_type, dtype)
#     973     warnings.warn(
#     974         "Support for VQT with res_type=None is deprecated in librosa 0.10\n"
#     975         "and will be removed in version 1.0.",
#     976         category=FutureWarning,
#     977         stacklevel=2,
#     978     )
#     979     res_type = "soxr_hq"
# --> 981 y, sr, hop_length = __early_downsample(
#     982     y, sr, hop_length, res_type, n_octaves, nyquist, filter_cutoff, scale
#     983 )
#     985 vqt_resp = []
#     987 # Iterate down the octaves
#
# File c:\Users\thepe\anaconda3\envs\tf_gpu_clean\lib\site-packages\librosa\core\constantq.py:1164, in __early_downsample(y, sr, hop_length, res_type, n_octaves, nyquist, filter_cutoff, scale)
#    1160 def __early_downsample(
#    1161     y, sr, hop_length, res_type, n_octaves, nyquist, filter_cutoff, scale
#    1162 ):
#    1163     """Perform early downsampling on an audio signal, if it applies."""
# -> 1164     downsample_count = __early_downsample_count(
#    1165         nyquist, filter_cutoff, hop_length, n_octaves
#    1166     )
#    1168     if downsample_count > 0:
#    1169         downsample_factor = 2 ** (downsample_count)
#
# File c:\Users\thepe\anaconda3\envs\tf_gpu_clean\lib\site-packages\librosa\core\constantq.py:1154, in __early_downsample_count(nyquist, filter_cutoff, hop_length, n_octaves)
#    1151 """Compute the number of early downsampling operations"""
#    1152 downsample_count1 = max(0, int(np.ceil(np.log2(nyquist / filter_cutoff)) - 1) - 1)
# -> 1154 num_twos = __num_two_factors(hop_length)
#    1155 downsample_count2 = max(0, num_twos - n_octaves + 1)
#    1157 return min(downsample_count1, downsample_count2)
#
# File c:\Users\thepe\anaconda3\envs\tf_gpu_clean\lib\site-packages\numba\core\dispatcher.py:420, in _DispatcherBase._compile_for_args(self, *args, **kws)
#     418 return_val = None
#     419 try:
# --> 420     return_val = self.compile(tuple(argtypes))
#     421 except errors.ForceLiteralArg as e:
#     422     # Received request for compiler re-entry with the list of arguments
#     423     # indicated by e.requested_args.
#     424     # First, check if any of these args are already Literal-ized
#     425     already_lit_pos = [i for i in e.requested_args
#     426                        if isinstance(args[i], types.Literal)]
#
# File c:\Users\thepe\anaconda3\envs\tf_gpu_clean\lib\site-packages\numba\core\dispatcher.py:946, in Dispatcher.compile(self, sig)
#     944     return existing.entry_point
#     945 # Try to load from disk cache
# --> 946 cres = self._cache.load_overload(sig, self.targetctx)
#     947 if cres is not None:
#     948     self._cache_hits[sig] += 1
#
# File c:\Users\thepe\anaconda3\envs\tf_gpu_clean\lib\site-packages\numba\core\caching.py:633, in Cache.load_overload(self, sig, target_context)
#     628 """
#     629 Load and recreate the cached object for the given signature,
#     630 using the *target_context*.
#     631 """
#     632 # Refresh the context to ensure it is initialized
# --> 633 target_context.refresh()
#     634 with self._guard_against_spurious_io_errors():
#     635     return self._load_overload(sig, target_context)
#
# File c:\Users\thepe\anaconda3\envs\tf_gpu_clean\lib\site-packages\numba\core\base.py:277, in BaseContext.refresh(self)
#     273 self.install_registry(builtin_registry)
#     275 # Also refresh typing context, since @overload declarations can
#     276 # affect it.
# --> 277 self.typing_context.refresh()
#
# File c:\Users\thepe\anaconda3\envs\tf_gpu_clean\lib\site-packages\numba\core\typing\context.py:158, in BaseContext.refresh(self)
#     153 def refresh(self):
#     154     """
#     155     Refresh context with new declarations from known registries.
#     156     Useful for third-party extensions.
#     157     """
# --> 158     self.load_additional_registries()
#     159     # Some extensions may have augmented the builtin registry
#     160     self._load_builtins()
#
# File c:\Users\thepe\anaconda3\envs\tf_gpu_clean\lib\site-packages\numba\core\typing\context.py:716, in Context.load_additional_registries(self)
#     714 self.install_registry(listdecl.registry)
#     715 self.install_registry(mathdecl.registry)
# --> 716 self.install_registry(npydecl.registry)
#     717 self.install_registry(setdecl.registry)
#     718 self.install_registry(dictdecl.registry)
#
# File c:\Users\thepe\anaconda3\envs\tf_gpu_clean\lib\site-packages\numba\core\typing\context.py:438, in BaseContext.install_registry(self, registry)
#     436     loader = templates.RegistryLoader(registry)
#     437     self._registries[registry] = loader
# --> 438 for ftcls in loader.new_registrations('functions'):
#     439     self.insert_function(ftcls(self))
#     440 for ftcls in loader.new_registrations('attributes'):
#
# File c:\Users\thepe\anaconda3\envs\tf_gpu_clean\lib\site-packages\numba\core\typing\templates.py:1300, in BaseRegistryLoader.new_registrations(self, name)
#    1295 def __init__(self, registry):
#    1296     self._registrations = dict(
#    1297         (name, utils.stream_list(getattr(registry, name)))
#    1298         for name in self.registry_items)
# -> 1300 def new_registrations(self, name):
#    1301     for item in next(self._registrations[name]):
#    1302         yield item
#
# KeyboardInterrupt:

# %%
def apply_per_block_normalization(X, scaler_info):
    """
    Normaliza features X aplicando (x - mean) / std PER BLOQUE.
    
    Esto estandariza cada bloque de features (Mel, MFCC, Chroma, etc.)
    de forma independiente, lo que estabiliza el entrenamiento.
    
    Fórmula: X_norm[i] = (X[i] - mean[i]) / std[i]
    
    Args:
        X: ndarray de forma (102, n_frames)
        scaler_info: dict con mean y std por bloque (de compute_global_scaler)
    
    Returns:
        X_normalized: ndarray normalizado, o None si hay error
    """
    if X is None:
        return None
    
    X_norm = X.copy().astype(np.float32) # Copia para no modificar original
    block_start = 0
    
    # Iterar sobre cada bloque
    for block_name, block_count in FEATURE_BLOCKS_FIXED:
        if block_name not in scaler_info:
            print(f"⚠️  Bloque {block_name} no en scaler_info")
            continue
        
        mean = scaler_info[block_name]["mean"]
        std = scaler_info[block_name]["std"]
        
        # Extraer este bloque
        block_data = X_norm[block_start:block_start + block_count, :]
        
        # Evitar división por cero
        std_safe = np.where(std > 0, std, 1.0)
        
        # Normalizar cada feature del bloque
        for feat_idx in range(block_count):
            if feat_idx < len(mean):
                block_data[feat_idx, :] = (block_data[feat_idx, :] - mean[feat_idx]) / std_safe[feat_idx]
        
        block_start += block_count
    
    return X_norm

print("✅ Función de normalización per-bloque definida")
# Out:
# ✅ Función de normalización per-bloque definida

# %% [markdown]
# ### FASE 3: CREAR SPLIT TRAIN/VAL (por canción, evitando leakage)

# %%
def create_train_val_split_by_music(all_data_clean, val_frac=0.2, seed=42):
    """
    Divide el dataset a nivel de CANCIÓN (musicId), no por muestra individual.
    
    IMPORTANTE: Esto evita leakage - la MISMA canción no aparece en train y val.
    
    Ejemplo:
    - Total: 100 canciones
    - Val: 20 canciones (20% de 100)
    - Train: 80 canciones (80% de 100)
    
    Args:
        all_data_clean: DataFrame con todas las muestras
        val_frac: fracción de canciones para validación (default 0.2 = 20%)
        seed: para reproducibilidad
    
    Returns:
        (train_df, val_df): DataFrames separados
    """
    np.random.seed(seed)
    
    # Obtener lista única de (dataset, musicId)
    music_list = []
    for dataset in all_data_clean["dataset"].unique():
        subset = all_data_clean[all_data_clean["dataset"] == dataset]
        unique_music = sorted(subset["musicId"].unique())
        music_list.extend([(dataset, mid) for mid in unique_music])
    
    # Mezclar aleatoriamente para distribución uniforme
    music_list = np.array(music_list, dtype=object)
    np.random.shuffle(music_list)
    
    # Dividir: primeras N son validación, resto entrenamiento
    n_val = max(1, int(len(music_list) * val_frac)) # Al menos 1 canción en val
    val_music = set([(d, m) for d, m in music_list[:n_val]]) # Conjunto de canciones de validación
    train_music = set([(d, m) for d, m in music_list[n_val:]]) # Conjunto de canciones de entrenamiento
    
    # Asignar TODAS las muestras de cada canción a train o val
    train_mask = all_data_clean.apply(
        lambda row: (row["dataset"], row["musicId"]) in train_music,
        axis=1
    ) # Máscara booleana para train
    val_mask = all_data_clean.apply(
        lambda row: (row["dataset"], row["musicId"]) in val_music,
        axis=1
    ) # Máscara booleana para val
    
    train_df = all_data_clean[train_mask].reset_index(drop=True)
    val_df = all_data_clean[val_mask].reset_index(drop=True)
    
    print(f"📊 Split Train/Val (por canción - sin leakage):")
    print(f"  Train: {len(train_df)} samples ({len(train_music)} canciones)")
    print(f"  Val:   {len(val_df)} samples ({len(val_music)} canciones)")
    
    return train_df, val_df

train_df, val_df = create_train_val_split_by_music(all_data_clean, val_frac=0.2)
# Out:
# 📊 Split Train/Val (por canción - sin leakage):
#   Train: 133334 samples (2056 canciones)
#   Val:   33095 samples (513 canciones)

# %% [markdown]
# ### FASE 4: GENERAR TFRecords (con normalización)

# %%
import tensorflow as tf

def create_tf_example(X_normalized, valence, arousal, musicId, dataset, frameTime):
    """
    Crea un ejemplo de TensorFlow serializado para almacenar en TFRecord.
    
    TFRecord es un formato binario eficiente para almacenar múltiples ejemplos.
    
    Campos almacenados:
        - X: features normalizados (flattened a 1D)
        - valence, arousal: labels objetivo
        - musicId, dataset, frameTime: metadatos
    
    Args:
        X_normalized: ndarray (102, n_frames) ya normalizado
        valence, arousal: labels (floats en [-1, 1])
        musicId, dataset, frameTime: metadatos
    
    Returns:
        bytes: ejemplo serializado listo para TFRecord
    """
    # X tiene forma (102, n_frames) -> flattenear a vector 1D
    X_flat = X_normalized.flatten().astype(np.float32) # Convertir a float32 para eficiencia
    
    # Crear diccionario de features
    feature_dict = {
        'X': tf.train.Feature(float_list=tf.train.FloatList(value=X_flat)), # Features normalizados
        'valence': tf.train.Feature(float_list=tf.train.FloatList(value=[float(valence)])), # Label valence
        'arousal': tf.train.Feature(float_list=tf.train.FloatList(value=[float(arousal)])), # Label arousal
        'musicId': tf.train.Feature(int64_list=tf.train.Int64List(value=[int(musicId)])), # ID de canción
        'dataset': tf.train.Feature(bytes_list=tf.train.BytesList(value=[dataset.encode('utf-8')])), # Nombre del dataset
        'frameTime': tf.train.Feature(float_list=tf.train.FloatList(value=[float(frameTime)])), # Tiempo del frame
    }
    
    # Crear Example y serializarlo
    example = tf.train.Example(features=tf.train.Features(feature=feature_dict)) # Crear Example
    return example.SerializeToString()

def process_and_save_tfrecords(df, output_dir, scaler_info, split_name="train", batch_size=1000):
    """
    Procesa un DataFrame y guarda muestras en archivos TFRecord.
    
    Para cada fila en df:
    1. Carga el audio (2 segundos centrados en frameTime)
    2. Extrae 102 features
    3. Normaliza features usando scaler_info
    4. Serializa y guarda en TFRecord
    
    Args:
        df: DataFrame con [musicId, frameTime, valence, arousal, dataset]
        output_dir: directorio para guardar archivos .tfrecord
        scaler_info: dict con estadísticas de normalización
        split_name: "train" o "val"
        batch_size: muestras por archivo (para evitar archivos muy grandes)
    
    Returns:
        (total_samples, failed_samples): estadísticas de procesamiento
    """
    os.makedirs(output_dir, exist_ok=True)
    
    batch_count = 0
    current_batch = []
    total_samples = 0
    failed_samples = 0
    
    print(f"\n🔄 Procesando {len(df)} samples ({split_name})...")
    
    for idx, row in df.iterrows():
        if idx % 500 == 0:
            print(f"  Progreso: {idx}/{len(df)}")
        
        try:
            # 1. Cargar segmento de audio centrado
            audio_path = get_audio_path(row)
            y, sr = load_centered_audio_segment(audio_path, row["frameTime"])
            
            if y is None:
                failed_samples += 1
                continue
            
            # 2. Extraer 102 features
            X = extract_features(y, sr)
            if X is None:
                failed_samples += 1
                continue
            
            # 3. Normalizar per-bloque
            X_norm = apply_per_block_normalization(X, scaler_info)
            if X_norm is None:
                failed_samples += 1
                continue
            
            # 4. Crear ejemplo serializado
            example = create_tf_example(
                X_norm,
                row["valence"],
                row["arousal"],
                row["musicId"],
                row["dataset"],
                row["frameTime"]
            )
            
            current_batch.append(example)
            total_samples += 1
            
            # Escribir batch cuando esté lleno
            if len(current_batch) >= batch_size:
                batch_file = os.path.join(output_dir, f"{split_name}_batch_{batch_count:03d}.tfrecord") # Nombre del archivo
                writer = tf.io.TFRecordWriter(batch_file) # Crear writer TFRecord
                for ex in current_batch:
                    writer.write(ex) # Escribir cada ejemplo
                writer.close()
                
                print(f"    ✅ {batch_file} ({len(current_batch)} samples)")
                batch_count += 1
                current_batch = []
        
        except Exception as e:
            print(f"    ⚠️  Error en row {idx}: {e}")
            failed_samples += 1
            continue
    
    # Escribir batch final (si quedan muestras)
    if current_batch:
        batch_file = os.path.join(output_dir, f"{split_name}_batch_{batch_count:03d}.tfrecord")
        writer = tf.io.TFRecordWriter(batch_file)
        for ex in current_batch:
            writer.write(ex)
        writer.close()
        print(f"    ✅ {batch_file} ({len(current_batch)} samples)")
    
    print(f"\n✅ {split_name.upper()} procesado: {total_samples} samples exitosos, {failed_samples} fallidos")
    return total_samples, failed_samples

# Generar TFRecords para train y val
tfrecord_output = os.path.join(OUTPUT_PATH, "tfrecords_102_features")

# %%
train_success, train_fail = process_and_save_tfrecords(
    train_df, tfrecord_output, scaler_info, split_name="train", batch_size=1000
)

val_success, val_fail = process_and_save_tfrecords(
    val_df, tfrecord_output, scaler_info, split_name="val", batch_size=1000
)
# Out:
# 🔄 Procesando 133334 samples (train)...
#   Progreso: 0/133334
#   Progreso: 500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_000.tfrecord (1000 samples)
#   Progreso: 1000/133334
#   Progreso: 1500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_001.tfrecord (1000 samples)
#   Progreso: 2000/133334
#   Progreso: 2500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_002.tfrecord (1000 samples)
#   Progreso: 3000/133334
#   Progreso: 3500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_003.tfrecord (1000 samples)
#   Progreso: 4000/133334
#   Progreso: 4500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_004.tfrecord (1000 samples)
#   Progreso: 5000/133334
#   Progreso: 5500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_005.tfrecord (1000 samples)
#   Progreso: 6000/133334
#   Progreso: 6500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_006.tfrecord (1000 samples)
#   Progreso: 7000/133334
#   Progreso: 7500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_007.tfrecord (1000 samples)
#   Progreso: 8000/133334
#   Progreso: 8500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_008.tfrecord (1000 samples)
#   Progreso: 9000/133334
#   Progreso: 9500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_009.tfrecord (1000 samples)
#   Progreso: 10000/133334
#   Progreso: 10500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_010.tfrecord (1000 samples)
#   Progreso: 11000/133334
#   Progreso: 11500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_011.tfrecord (1000 samples)
#   Progreso: 12000/133334
#   Progreso: 12500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_012.tfrecord (1000 samples)
#   Progreso: 13000/133334
#   Progreso: 13500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_013.tfrecord (1000 samples)
#   Progreso: 14000/133334
#   Progreso: 14500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_014.tfrecord (1000 samples)
#   Progreso: 15000/133334
#   Progreso: 15500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_015.tfrecord (1000 samples)
#   Progreso: 16000/133334
#   Progreso: 16500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_016.tfrecord (1000 samples)
#   Progreso: 17000/133334
#   Progreso: 17500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_017.tfrecord (1000 samples)
#   Progreso: 18000/133334
#   Progreso: 18500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_018.tfrecord (1000 samples)
#   Progreso: 19000/133334
#   Progreso: 19500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_019.tfrecord (1000 samples)
#   Progreso: 20000/133334
#   Progreso: 20500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_020.tfrecord (1000 samples)
#   Progreso: 21000/133334
#   Progreso: 21500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_021.tfrecord (1000 samples)
#   Progreso: 22000/133334
#   Progreso: 22500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_022.tfrecord (1000 samples)
#   Progreso: 23000/133334
#   Progreso: 23500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_023.tfrecord (1000 samples)
#   Progreso: 24000/133334
#   Progreso: 24500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_024.tfrecord (1000 samples)
#   Progreso: 25000/133334
#   Progreso: 25500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_025.tfrecord (1000 samples)
#   Progreso: 26000/133334
#   Progreso: 26500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_026.tfrecord (1000 samples)
#   Progreso: 27000/133334
#   Progreso: 27500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_027.tfrecord (1000 samples)
#   Progreso: 28000/133334
#   Progreso: 28500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_028.tfrecord (1000 samples)
#   Progreso: 29000/133334
#   Progreso: 29500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_029.tfrecord (1000 samples)
#   Progreso: 30000/133334
#   Progreso: 30500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_030.tfrecord (1000 samples)
#   Progreso: 31000/133334
#   Progreso: 31500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_031.tfrecord (1000 samples)
#   Progreso: 32000/133334
#   Progreso: 32500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_032.tfrecord (1000 samples)
#   Progreso: 33000/133334
#   Progreso: 33500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_033.tfrecord (1000 samples)
#   Progreso: 34000/133334
#   Progreso: 34500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_034.tfrecord (1000 samples)
#   Progreso: 35000/133334
#   Progreso: 35500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_035.tfrecord (1000 samples)
#   Progreso: 36000/133334
#   Progreso: 36500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_036.tfrecord (1000 samples)
#   Progreso: 37000/133334
#   Progreso: 37500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_037.tfrecord (1000 samples)
#   Progreso: 38000/133334
#   Progreso: 38500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_038.tfrecord (1000 samples)
#   Progreso: 39000/133334
#   Progreso: 39500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_039.tfrecord (1000 samples)
#   Progreso: 40000/133334
#   Progreso: 40500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_040.tfrecord (1000 samples)
#   Progreso: 41000/133334
#   Progreso: 41500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_041.tfrecord (1000 samples)
#   Progreso: 42000/133334
#   Progreso: 42500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_042.tfrecord (1000 samples)
#   Progreso: 43000/133334
#   Progreso: 43500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_043.tfrecord (1000 samples)
#   Progreso: 44000/133334
#   Progreso: 44500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_044.tfrecord (1000 samples)
#   Progreso: 45000/133334
#   Progreso: 45500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_045.tfrecord (1000 samples)
#   Progreso: 46000/133334
#   Progreso: 46500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_046.tfrecord (1000 samples)
#   Progreso: 47000/133334
#   Progreso: 47500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_047.tfrecord (1000 samples)
#   Progreso: 48000/133334
#   Progreso: 48500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_048.tfrecord (1000 samples)
#   Progreso: 49000/133334
#   Progreso: 49500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_049.tfrecord (1000 samples)
#   Progreso: 50000/133334
#   Progreso: 50500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_050.tfrecord (1000 samples)
#   Progreso: 51000/133334
#   Progreso: 51500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_051.tfrecord (1000 samples)
#   Progreso: 52000/133334
#   Progreso: 52500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_052.tfrecord (1000 samples)
#   Progreso: 53000/133334
#   Progreso: 53500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_053.tfrecord (1000 samples)
#   Progreso: 54000/133334
#   Progreso: 54500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_054.tfrecord (1000 samples)
#   Progreso: 55000/133334
#   Progreso: 55500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_055.tfrecord (1000 samples)
#   Progreso: 56000/133334
#   Progreso: 56500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_056.tfrecord (1000 samples)
#   Progreso: 57000/133334
#   Progreso: 57500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_057.tfrecord (1000 samples)
#   Progreso: 58000/133334
#   Progreso: 58500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_058.tfrecord (1000 samples)
#   Progreso: 59000/133334
#   Progreso: 59500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_059.tfrecord (1000 samples)
#   Progreso: 60000/133334
#   Progreso: 60500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_060.tfrecord (1000 samples)
#   Progreso: 61000/133334
#   Progreso: 61500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_061.tfrecord (1000 samples)
#   Progreso: 62000/133334
#   Progreso: 62500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_062.tfrecord (1000 samples)
#   Progreso: 63000/133334
#   Progreso: 63500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_063.tfrecord (1000 samples)
#   Progreso: 64000/133334
#   Progreso: 64500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_064.tfrecord (1000 samples)
#   Progreso: 65000/133334
#   Progreso: 65500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_065.tfrecord (1000 samples)
#   Progreso: 66000/133334
#   Progreso: 66500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_066.tfrecord (1000 samples)
#   Progreso: 67000/133334
#   Progreso: 67500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_067.tfrecord (1000 samples)
#   Progreso: 68000/133334
#   Progreso: 68500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_068.tfrecord (1000 samples)
#   Progreso: 69000/133334
#   Progreso: 69500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_069.tfrecord (1000 samples)
#   Progreso: 70000/133334
#   Progreso: 70500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_070.tfrecord (1000 samples)
#   Progreso: 71000/133334
#   Progreso: 71500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_071.tfrecord (1000 samples)
#   Progreso: 72000/133334
#   Progreso: 72500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_072.tfrecord (1000 samples)
#   Progreso: 73000/133334
#   Progreso: 73500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_073.tfrecord (1000 samples)
#   Progreso: 74000/133334
#   Progreso: 74500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_074.tfrecord (1000 samples)
#   Progreso: 75000/133334
#   Progreso: 75500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_075.tfrecord (1000 samples)
#   Progreso: 76000/133334
#   Progreso: 76500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_076.tfrecord (1000 samples)
#   Progreso: 77000/133334
#   Progreso: 77500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_077.tfrecord (1000 samples)
#   Progreso: 78000/133334
#   Progreso: 78500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_078.tfrecord (1000 samples)
#   Progreso: 79000/133334
#   Progreso: 79500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_079.tfrecord (1000 samples)
#   Progreso: 80000/133334
#   Progreso: 80500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_080.tfrecord (1000 samples)
#   Progreso: 81000/133334
#   Progreso: 81500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_081.tfrecord (1000 samples)
#   Progreso: 82000/133334
#   Progreso: 82500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_082.tfrecord (1000 samples)
#   Progreso: 83000/133334
#   Progreso: 83500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_083.tfrecord (1000 samples)
#   Progreso: 84000/133334
#   Progreso: 84500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_084.tfrecord (1000 samples)
#   Progreso: 85000/133334
#   Progreso: 85500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_085.tfrecord (1000 samples)
#   Progreso: 86000/133334
#   Progreso: 86500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_086.tfrecord (1000 samples)
#   Progreso: 87000/133334
#   Progreso: 87500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_087.tfrecord (1000 samples)
#   Progreso: 88000/133334
#   Progreso: 88500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_088.tfrecord (1000 samples)
#   Progreso: 89000/133334
#   Progreso: 89500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_089.tfrecord (1000 samples)
#   Progreso: 90000/133334
#   Progreso: 90500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_090.tfrecord (1000 samples)
#   Progreso: 91000/133334
#   Progreso: 91500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_091.tfrecord (1000 samples)
#   Progreso: 92000/133334
#   Progreso: 92500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_092.tfrecord (1000 samples)
#   Progreso: 93000/133334
#   Progreso: 93500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_093.tfrecord (1000 samples)
#   Progreso: 94000/133334
#   Progreso: 94500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_094.tfrecord (1000 samples)
#   Progreso: 95000/133334
#   Progreso: 95500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_095.tfrecord (1000 samples)
#   Progreso: 96000/133334
#   Progreso: 96500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_096.tfrecord (1000 samples)
#   Progreso: 97000/133334
#   Progreso: 97500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_097.tfrecord (1000 samples)
#   Progreso: 98000/133334
#   Progreso: 98500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_098.tfrecord (1000 samples)
#   Progreso: 99000/133334
#   Progreso: 99500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_099.tfrecord (1000 samples)
#   Progreso: 100000/133334
#   Progreso: 100500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_100.tfrecord (1000 samples)
#   Progreso: 101000/133334
#   Progreso: 101500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_101.tfrecord (1000 samples)
#   Progreso: 102000/133334
#   Progreso: 102500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_102.tfrecord (1000 samples)
#   Progreso: 103000/133334
#   Progreso: 103500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_103.tfrecord (1000 samples)
#   Progreso: 104000/133334
#   Progreso: 104500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_104.tfrecord (1000 samples)
#   Progreso: 105000/133334
#   Progreso: 105500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_105.tfrecord (1000 samples)
#   Progreso: 106000/133334
#   Progreso: 106500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_106.tfrecord (1000 samples)
#   Progreso: 107000/133334
#   Progreso: 107500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_107.tfrecord (1000 samples)
#   Progreso: 108000/133334
#   Progreso: 108500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_108.tfrecord (1000 samples)
#   Progreso: 109000/133334
#   Progreso: 109500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_109.tfrecord (1000 samples)
#   Progreso: 110000/133334
#   Progreso: 110500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_110.tfrecord (1000 samples)
#   Progreso: 111000/133334
#   Progreso: 111500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_111.tfrecord (1000 samples)
#   Progreso: 112000/133334
#   Progreso: 112500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_112.tfrecord (1000 samples)
#   Progreso: 113000/133334
#   Progreso: 113500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_113.tfrecord (1000 samples)
#   Progreso: 114000/133334
#   Progreso: 114500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_114.tfrecord (1000 samples)
#   Progreso: 115000/133334
#   Progreso: 115500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_115.tfrecord (1000 samples)
#   Progreso: 116000/133334
#   Progreso: 116500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_116.tfrecord (1000 samples)
#   Progreso: 117000/133334
#   Progreso: 117500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_117.tfrecord (1000 samples)
#   Progreso: 118000/133334
#   Progreso: 118500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_118.tfrecord (1000 samples)
#   Progreso: 119000/133334
#   Progreso: 119500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_119.tfrecord (1000 samples)
#   Progreso: 120000/133334
#   Progreso: 120500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_120.tfrecord (1000 samples)
#   Progreso: 121000/133334
#   Progreso: 121500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_121.tfrecord (1000 samples)
#   Progreso: 122000/133334
#   Progreso: 122500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_122.tfrecord (1000 samples)
#   Progreso: 123000/133334
#   Progreso: 123500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_123.tfrecord (1000 samples)
#   Progreso: 124000/133334
#   Progreso: 124500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_124.tfrecord (1000 samples)
#   Progreso: 125000/133334
#   Progreso: 125500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_125.tfrecord (1000 samples)
#   Progreso: 126000/133334
#   Progreso: 126500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_126.tfrecord (1000 samples)
#   Progreso: 127000/133334
#   Progreso: 127500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_127.tfrecord (1000 samples)
#   Progreso: 128000/133334
#   Progreso: 128500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_128.tfrecord (1000 samples)
#   Progreso: 129000/133334
#   Progreso: 129500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_129.tfrecord (1000 samples)
#   Progreso: 130000/133334
#   Progreso: 130500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_130.tfrecord (1000 samples)
#   Progreso: 131000/133334
#   Progreso: 131500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_131.tfrecord (1000 samples)
#   Progreso: 132000/133334
#   Progreso: 132500/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_132.tfrecord (1000 samples)
#   Progreso: 133000/133334
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\train_batch_133.tfrecord (334 samples)
#
# ✅ TRAIN procesado: 133334 samples exitosos, 0 fallidos
#
# 🔄 Procesando 33095 samples (val)...
#   Progreso: 0/33095
#   Progreso: 500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_000.tfrecord (1000 samples)
#   Progreso: 1000/33095
#   Progreso: 1500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_001.tfrecord (1000 samples)
#   Progreso: 2000/33095
#   Progreso: 2500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_002.tfrecord (1000 samples)
#   Progreso: 3000/33095
#   Progreso: 3500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_003.tfrecord (1000 samples)
#   Progreso: 4000/33095
#   Progreso: 4500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_004.tfrecord (1000 samples)
#   Progreso: 5000/33095
#   Progreso: 5500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_005.tfrecord (1000 samples)
#   Progreso: 6000/33095
#   Progreso: 6500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_006.tfrecord (1000 samples)
#   Progreso: 7000/33095
#   Progreso: 7500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_007.tfrecord (1000 samples)
#   Progreso: 8000/33095
#   Progreso: 8500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_008.tfrecord (1000 samples)
#   Progreso: 9000/33095
#   Progreso: 9500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_009.tfrecord (1000 samples)
#   Progreso: 10000/33095
#   Progreso: 10500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_010.tfrecord (1000 samples)
#   Progreso: 11000/33095
#   Progreso: 11500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_011.tfrecord (1000 samples)
#   Progreso: 12000/33095
#   Progreso: 12500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_012.tfrecord (1000 samples)
#   Progreso: 13000/33095
#   Progreso: 13500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_013.tfrecord (1000 samples)
#   Progreso: 14000/33095
#   Progreso: 14500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_014.tfrecord (1000 samples)
#   Progreso: 15000/33095
#   Progreso: 15500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_015.tfrecord (1000 samples)
#   Progreso: 16000/33095
#   Progreso: 16500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_016.tfrecord (1000 samples)
#   Progreso: 17000/33095
#   Progreso: 17500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_017.tfrecord (1000 samples)
#   Progreso: 18000/33095
#   Progreso: 18500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_018.tfrecord (1000 samples)
#   Progreso: 19000/33095
#   Progreso: 19500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_019.tfrecord (1000 samples)
#   Progreso: 20000/33095
#   Progreso: 20500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_020.tfrecord (1000 samples)
#   Progreso: 21000/33095
#   Progreso: 21500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_021.tfrecord (1000 samples)
#   Progreso: 22000/33095
#   Progreso: 22500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_022.tfrecord (1000 samples)
#   Progreso: 23000/33095
#   Progreso: 23500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_023.tfrecord (1000 samples)
#   Progreso: 24000/33095
#   Progreso: 24500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_024.tfrecord (1000 samples)
#   Progreso: 25000/33095
#   Progreso: 25500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_025.tfrecord (1000 samples)
#   Progreso: 26000/33095
#   Progreso: 26500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_026.tfrecord (1000 samples)
#   Progreso: 27000/33095
#   Progreso: 27500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_027.tfrecord (1000 samples)
#   Progreso: 28000/33095
#   Progreso: 28500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_028.tfrecord (1000 samples)
#   Progreso: 29000/33095
#   Progreso: 29500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_029.tfrecord (1000 samples)
#   Progreso: 30000/33095
#   Progreso: 30500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_030.tfrecord (1000 samples)
#   Progreso: 31000/33095
#   Progreso: 31500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_031.tfrecord (1000 samples)
#   Progreso: 32000/33095
#   Progreso: 32500/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_032.tfrecord (1000 samples)
#   Progreso: 33000/33095
#     ✅ C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features\val_batch_033.tfrecord (95 samples)
#
# ✅ VAL procesado: 33095 samples exitosos, 0 fallidos

# %% [markdown]
# ### FASE 5: FUNCIONES DE VALIDACIÓN Y CARGA DE TFRecords

# %%
def parse_tfrecord_example(serialized_example):
    """
    Parsea un ejemplo individual de TFRecord.
    
    Convierte el formato binario de vuelta a tensores utilizables.
    
    Retorna:
        (X, y) donde:
        - X tiene forma (102, n_frames) - features del audio
        - y tiene forma (2,) - [valence, arousal]
    """
    feature_description = {
        'X': tf.io.VarLenFeature(tf.float32), # Vector flattenizado de features
        'valence': tf.io.FixedLenFeature([], tf.float32), # Label valence
        'arousal': tf.io.FixedLenFeature([], tf.float32), # Label arousal
        'musicId': tf.io.FixedLenFeature([], tf.int64), # ID de canción
        'dataset': tf.io.FixedLenFeature([], tf.string), # Nombre del dataset
        'frameTime': tf.io.FixedLenFeature([], tf.float32), # Tiempo del frame
    }
    
    # Parsear según la descripción
    parsed = tf.io.parse_single_example(serialized_example, feature_description)
    
    # X está en formato sparse (eficiente) - convertir a denso
    X_flat = tf.sparse.to_dense(parsed['X'])
    X = tf.reshape(X_flat, (102, -1))  # Reshape a (102, n_frames)
    
    # Combinar labels en un vector (2,)
    y = tf.stack([parsed['valence'], parsed['arousal']])
    
    # Retornar solo X e y (ignorar metadatos)
    return X, y

def load_tfrecord_dataset(tfrecord_dir, split_name="train", batch_size=32, shuffle_buffer=1000):
    """
    Carga un dataset desde archivos TFRecord.
    
    Busca todos los archivos "train_batch_*.tfrecord" o "val_batch_*.tfrecord"
    en el directorio y los carga en un tf.data.Dataset.
    
    Args:
        tfrecord_dir: directorio con archivos .tfrecord
        split_name: "train" o "val"
        batch_size: tamaño de batch para entrenamiento
        shuffle_buffer: tamaño del buffer de shuffle (train) o 0 (val)
    
    Returns:
        tf.data.Dataset listo para entrenar, o None si no hay archivos
    """
    # Encontrar todos los archivos .tfrecord para este split
    pattern = os.path.join(tfrecord_dir, f"{split_name}_batch_*.tfrecord")
    tfrecord_files = sorted(tf.io.gfile.glob(pattern))
    
    if not tfrecord_files:
        print(f"❌ No se encontraron archivos: {pattern}")
        return None
    
    print(f"✅ Encontrados {len(tfrecord_files)} archivos para {split_name}")
    
    # Crear dataset desde TFRecords
    dataset = tf.data.TFRecordDataset(tfrecord_files)
    dataset = dataset.map(parse_tfrecord_example, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle solo en train (para evitar correlación entre batches)
    if split_name == "train":
        dataset = dataset.shuffle(shuffle_buffer)
    
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)  # Precarga siguiente batch mientras entrena
    
    return dataset

def verify_tfrecords(tfrecord_dir, num_samples=5):
    """
    Verifica integridad de TFRecords: lee algunos ejemplos y valida el formato.
    
    Comprueba:
    - Que los archivos se puedan leer
    - Que X tenga forma correcta (102, n_frames)
    - Que y tenga forma correcta (2,) con valores en [-1, 1]
    - Que los features estén normalizados (mean≈0, std≈1)
    
    Args:
        tfrecord_dir: directorio con archivos .tfrecord
        num_samples: número de ejemplos a verificar
    
    Returns:
        True si todo OK, False si hay error
    """
    print(f"\n🔍 Verificando TFRecords en {tfrecord_dir}...")
    
    pattern = os.path.join(tfrecord_dir, "*.tfrecord")
    tfrecord_files = sorted(tf.io.gfile.glob(pattern))
    
    if not tfrecord_files:
        print(f"❌ No se encontraron archivos .tfrecord")
        return False
    
    print(f"📁 {len(tfrecord_files)} archivos encontrados")
    
    count = 0
    for tfrecord_file in tfrecord_files:
        for raw_record in tf.data.TFRecordDataset([tfrecord_file]).take(num_samples):
            try:
                # Parsear el ejemplo
                X, y = parse_tfrecord_example(raw_record)
                
                print(f"  Sample: X.shape={X.shape}, y={y.numpy()}")
                
                # Verificar normalización aproximada
                X_mean = tf.reduce_mean(X).numpy()
                X_std = tf.math.reduce_std(X).numpy()
                print(f"    → X: mean≈{X_mean:.4f}, std≈{X_std:.4f}")
                
                count += 1
            except Exception as e:
                print(f"  ❌ Error: {e}")
                return False
    
    print(f"\n✅ Verificación exitosa: {count} samples leídos correctamente")
    return True

print("✅ Funciones de validación y carga de TFRecords definidas")
# Out:
# ✅ Funciones de validación y carga de TFRecords definidas

# %% [markdown]
# ### FASE 6: VALIDACIÓN DE TFRecords Y ESTADÍSTICAS

# %%
# Verificar integridad de TFRecords generados
# Lee 3 ejemplos de cada tipo de archivo para validar formato
verify_tfrecords(tfrecord_output, num_samples=3)
# Out:
# 🔍 Verificando TFRecords en C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\tfrecords_102_features...
# 📁 168 archivos encontrados
#   Sample: X.shape=(102, 87), y=[-0.0733407 -0.109386 ]
#     → X: mean≈-0.7339, std≈1.3770
#   Sample: X.shape=(102, 87), y=[-0.0746607 -0.1149416]
#     → X: mean≈-0.5705, std≈1.2855
#   Sample: X.shape=(102, 87), y=[-0.0740767 -0.1164126]
#     → X: mean≈-0.5545, std≈1.2717
#   Sample: X.shape=(102, 87), y=[-0.1711795  0.512703 ]
#     → X: mean≈-0.5769, std≈1.2656
#   Sample: X.shape=(102, 87), y=[-0.1584696  0.502759 ]
#     → X: mean≈-0.5700, std≈1.2613
#   Sample: X.shape=(102, 87), y=[-0.1630074  0.498675 ]
#     → X: mean≈-0.4366, std≈1.2266
#   Sample: X.shape=(102, 87), y=[-0.1950931 -0.2286169]
#     → X: mean≈-0.8300, std≈1.5987
#   Sample: X.shape=(102, 87), y=[-0.1956898 -0.22955  ]
#     → X: mean≈-0.7319, std≈1.5440
#   Sample: X.shape=(102, 87), y=[-0.1994899 -0.2324285]
#     → X: mean≈-0.7596, std≈1.5634
#   Sample: X.shape=(102, 87), y=[0.1827443 0.3543832]
#     → X: mean≈-0.3271, std≈1.2539
#   Sample: X.shape=(102, 87), y=[0.1810979 0.3799242]
#     → X: mean≈-0.1451, std≈1.1897
#   Sample: X.shape=(102, 87), y=[0.2107   0.380971]
#     → X: mean≈-0.2288, std≈1.2135
#   Sample: X.shape=(102, 87), y=[-0.0412946  0.2895233]
#     → X: mean≈-0.2539, std≈1.3125
#   Sample: X.shape=(102, 87), y=[-0.0393476  0.2914043]
#     → X: mean≈-0.2916, std≈1.3436
#   Sample: X.shape=(102, 87), y=[-0.0385866  0.2965763]
#     → X: mean≈-0.3741, std≈1.3789
#   Sample: X.shape=(102, 87), y=[ 0.1241804 -0.4611905]
#     → X: mean≈-1.3532, std≈2.0243
#   Sample: X.shape=(102, 87), y=[ 0.1172399 -0.4636565]
#     → X: mean≈-1.3523, std≈2.0215
#   Sample: X.shape=(102, 87), y=[ 0.1138752 -0.4628605]
#     → X: mean≈-1.3163, std≈2.0184
#   Sample: X.shape=(102, 87), y=[-0.0052487 -0.0349131]
#     → X: mean≈-0.4247, std≈1.5214
#   Sample: X.shape=(102, 87), y=[ 0.0318883 -0.0234231]
#     → X: mean≈-0.4966, std≈1.5606
#   Sample: X.shape=(102, 87), y=[ 0.0495395 -0.0151918]
#     → X: mean≈-0.6415, std≈1.6456
#   Sample: X.shape=(102, 87), y=[-0.1875697 -0.465217 ]
#     → X: mean≈-1.2658, std≈2.0290
#   Sample: X.shape=(102, 87), y=[-0.1868225 -0.460506 ]
#     → X: mean≈-1.0228, std≈1.9870
#   Sample: X.shape=(102, 87), y=[-0.1884253 -0.450774 ]
#     → X: mean≈-0.9877, std≈1.9300
#   Sample: X.shape=(102, 87), y=[0.3309298 0.0997304]
#     → X: mean≈-0.9710, std≈1.7871
#   Sample: X.shape=(102, 87), y=[0.3344488 0.1032184]
#     → X: mean≈-1.0265, std≈1.7978
#   Sample: X.shape=(102, 87), y=[0.3374348 0.1059154]
#     → X: mean≈-1.0595, std≈1.8137
#   Sample: X.shape=(102, 87), y=[ 0.0928116  -0.10720286]
#     → X: mean≈-0.5021, std≈1.4465
#   Sample: X.shape=(102, 87), y=[ 0.0920966 -0.1075262]
#     → X: mean≈-0.4748, std≈1.4828
#   Sample: X.shape=(102, 87), y=[ 0.0920966 -0.1047498]
#     → X: mean≈-0.4076, std≈1.4814
#   Sample: X.shape=(102, 87), y=[-0.0621861 -0.415218 ]
#     → X: mean≈-1.4620, std≈2.0806
#   Sample: X.shape=(102, 87), y=[-0.0607817 -0.418005 ]
#     → X: mean≈-1.5899, std≈2.0975
#   Sample: X.shape=(102, 87), y=[-0.0624817 -0.422846 ]
#     → X: mean≈-1.5783, std≈2.1069
#   Sample: X.shape=(102, 87), y=[0.359066  0.2498173]
#     → X: mean≈-0.9758, std≈1.8749
#   Sample: X.shape=(102, 87), y=[0.359066  0.2507193]
#     → X: mean≈-0.8760, std≈1.8755
#   Sample: X.shape=(102, 87), y=[0.360137  0.2501682]
#     → X: mean≈-0.8747, std≈1.8901
#   Sample: X.shape=(102, 87), y=[0.0709944 0.3346453]
#     → X: mean≈-0.1514, std≈1.1728
#   Sample: X.shape=(102, 87), y=[0.0569935 0.3371683]
#     → X: mean≈-0.1775, std≈1.1783
#   Sample: X.shape=(102, 87), y=[0.05153176 0.3404693 ]
#     → X: mean≈-0.1741, std≈1.1739
#   Sample: X.shape=(102, 87), y=[0.441942 0.276242]
#     → X: mean≈-0.5325, std≈1.3901
#   Sample: X.shape=(102, 87), y=[0.44026  0.277965]
#     → X: mean≈-0.5040, std≈1.3788
#   Sample: X.shape=(102, 87), y=[0.443256 0.266687]
#     → X: mean≈-0.5200, std≈1.3948
#   Sample: X.shape=(102, 87), y=[0.253682  0.4952726]
#     → X: mean≈-0.0730, std≈1.1785
#   Sample: X.shape=(102, 87), y=[0.249041  0.4912576]
#     → X: mean≈-0.0575, std≈1.1807
#   Sample: X.shape=(102, 87), y=[0.244673  0.4904446]
#     → X: mean≈-0.0609, std≈1.1598
#   Sample: X.shape=(102, 87), y=[0.1697828 0.49631  ]
#     → X: mean≈-0.0328, std≈1.1167
#   Sample: X.shape=(102, 87), y=[0.1718023 0.4952294]
#     → X: mean≈-0.0418, std≈1.1137
#   Sample: X.shape=(102, 87), y=[0.1741071 0.494941 ]
#     → X: mean≈-0.0433, std≈1.0938
#   Sample: X.shape=(102, 87), y=[0.3748457 0.3486255]
#     → X: mean≈-0.4664, std≈1.5523
#   Sample: X.shape=(102, 87), y=[0.37053695 0.3376294 ]
#     → X: mean≈-0.4360, std≈1.5488
#   Sample: X.shape=(102, 87), y=[0.3648171 0.3409994]
#     → X: mean≈-0.2200, std≈1.4419
#   Sample: X.shape=(102, 87), y=[-0.018097   0.2070173]
#     → X: mean≈-0.4459, std≈1.4247
#   Sample: X.shape=(102, 87), y=[-0.015569   0.1968093]
#     → X: mean≈-0.4474, std≈1.4325
#   Sample: X.shape=(102, 87), y=[-0.018277   0.1981213]
#     → X: mean≈-0.5177, std≈1.4752
#   Sample: X.shape=(102, 87), y=[0.2245843 0.1943954]
#     → X: mean≈-0.6502, std≈1.4875
#   Sample: X.shape=(102, 87), y=[0.2574111 0.1969304]
#     → X: mean≈-0.7025, std≈1.5161
#   Sample: X.shape=(102, 87), y=[0.2796961 0.1973904]
#     → X: mean≈-0.6676, std≈1.4998
#   Sample: X.shape=(102, 87), y=[0.179941  0.5530129]
#     → X: mean≈-0.5942, std≈1.4523
#   Sample: X.shape=(102, 87), y=[0.179941  0.5523299]
#     → X: mean≈-0.5736, std≈1.4507
#   Sample: X.shape=(102, 87), y=[0.180329  0.5535249]
#     → X: mean≈-0.5573, std≈1.4380
#   Sample: X.shape=(102, 87), y=[-0.1367562 -0.2783471]
#     → X: mean≈-1.1509, std≈1.7857
#   Sample: X.shape=(102, 87), y=[-0.1329252 -0.2794841]
#     → X: mean≈-1.1497, std≈1.7673
#   Sample: X.shape=(102, 87), y=[-0.1278122 -0.2771801]
#     → X: mean≈-1.1749, std≈1.8018
#   Sample: X.shape=(102, 87), y=[-0.0809953 -0.2683433]
#     → X: mean≈-1.1383, std≈1.8321
#   Sample: X.shape=(102, 87), y=[-0.0815703 -0.2669193]
#     → X: mean≈-1.2095, std≈1.8249
#   Sample: X.shape=(102, 87), y=[-0.1640563  -0.26169705]
#     → X: mean≈-1.1669, std≈1.8293
#   Sample: X.shape=(102, 87), y=[0.2966593 0.3968075]
#     → X: mean≈-0.4425, std≈1.5526
#   Sample: X.shape=(102, 87), y=[0.2895444 0.3916296]
#     → X: mean≈-0.4525, std≈1.5269
#   Sample: X.shape=(102, 87), y=[0.2820872 0.3876764]
#     → X: mean≈-0.4618, std≈1.5292
#   Sample: X.shape=(102, 87), y=[ 0.1574985 -0.1140737]
#     → X: mean≈-0.6245, std≈1.3701
#   Sample: X.shape=(102, 87), y=[ 0.1569845 -0.1141655]
#     → X: mean≈-0.6147, std≈1.3811
#   Sample: X.shape=(102, 87), y=[ 0.1556625 -0.1274244]
#     → X: mean≈-0.6837, std≈1.3887
#   Sample: X.shape=(102, 87), y=[-0.1714088 -0.3148628]
#     → X: mean≈-1.3831, std≈1.9847
#   Sample: X.shape=(102, 87), y=[-0.1714088 -0.3147548]
#     → X: mean≈-1.5400, std≈2.0450
#   Sample: X.shape=(102, 87), y=[-0.1714088 -0.3131238]
#     → X: mean≈-1.0792, std≈1.9334
#   Sample: X.shape=(102, 87), y=[-0.1105328 -0.1461488]
#     → X: mean≈-0.8709, std≈1.6085
#   Sample: X.shape=(102, 87), y=[-0.1128517 -0.1247121]
#     → X: mean≈-0.8463, std≈1.6289
#   Sample: X.shape=(102, 87), y=[-0.0963919 -0.0863467]
#     → X: mean≈-0.7164, std≈1.6014
#   Sample: X.shape=(102, 87), y=[0.0606908 0.1743587]
#     → X: mean≈-0.5703, std≈1.3864
#   Sample: X.shape=(102, 87), y=[0.06258238 0.1620182 ]
#     → X: mean≈-0.5241, std≈1.3508
#   Sample: X.shape=(102, 87), y=[0.0652953 0.1510431]
#     → X: mean≈-0.4640, std≈1.3234
#   Sample: X.shape=(102, 87), y=[0.0690039 0.0085602]
#     → X: mean≈-0.6622, std≈1.5057
#   Sample: X.shape=(102, 87), y=[0.0692757 0.0145448]
#     → X: mean≈-0.6062, std≈1.4609
#   Sample: X.shape=(102, 87), y=[0.0444868  0.02088564]
#     → X: mean≈-0.5729, std≈1.4482
#   Sample: X.shape=(102, 87), y=[0.1865026 0.0736098]
#     → X: mean≈-0.4109, std≈1.3028
#   Sample: X.shape=(102, 87), y=[0.1814896 0.0794168]
#     → X: mean≈-0.4586, std≈1.3508
#   Sample: X.shape=(102, 87), y=[0.1853876 0.0906598]
#     → X: mean≈-0.5223, std≈1.3635
#   Sample: X.shape=(102, 87), y=[0.2742547 0.0986104]
#     → X: mean≈-0.5736, std≈1.6088
#   Sample: X.shape=(102, 87), y=[0.2702427 0.0986104]
#     → X: mean≈-0.6039, std≈1.6139
#   Sample: X.shape=(102, 87), y=[0.2644125 0.0986104]
#     → X: mean≈-0.6195, std≈1.6408
#   Sample: X.shape=(102, 87), y=[ 0.0907406 -0.0931777]
#     → X: mean≈-0.6097, std≈1.4396
#   Sample: X.shape=(102, 87), y=[ 0.0907406 -0.0998437]
#     → X: mean≈-0.6177, std≈1.4557
#   Sample: X.shape=(102, 87), y=[ 0.0907406  -0.10163221]
#     → X: mean≈-0.6505, std≈1.4616
#   Sample: X.shape=(102, 87), y=[0.3373159 0.3369842]
#     → X: mean≈-0.4298, std≈1.3658
#   Sample: X.shape=(102, 87), y=[0.3366741  0.31122518]
#     → X: mean≈-0.4481, std≈1.3757
#   Sample: X.shape=(102, 87), y=[0.3405031 0.3371114]
#     → X: mean≈-0.4460, std≈1.3727
#   Sample: X.shape=(102, 87), y=[ 0.076643  -0.0895884]
#     → X: mean≈-0.8000, std≈1.5754
#   Sample: X.shape=(102, 87), y=[ 0.07928958 -0.0857989 ]
#     → X: mean≈-0.8512, std≈1.6252
#   Sample: X.shape=(102, 87), y=[ 0.0797858 -0.0862989]
#     → X: mean≈-0.8630, std≈1.6485
#   Sample: X.shape=(102, 87), y=[-0.0046483 -0.1248296]
#     → X: mean≈-0.5195, std≈1.3997
#   Sample: X.shape=(102, 87), y=[-0.0155813 -0.130331 ]
#     → X: mean≈-0.3770, std≈1.3571
#   Sample: X.shape=(102, 87), y=[-0.0157123 -0.133882 ]
#     → X: mean≈-0.3988, std≈1.3736
#   Sample: X.shape=(102, 87), y=[-0.2982    0.570725]
#     → X: mean≈0.0156, std≈1.1274
#   Sample: X.shape=(102, 87), y=[-0.297399  0.57219 ]
#     → X: mean≈0.0090, std≈1.1188
#   Sample: X.shape=(102, 87), y=[-0.297359  0.572706]
#     → X: mean≈-0.1091, std≈1.1415
#   Sample: X.shape=(102, 87), y=[-0.2425873 -0.0341745]
#     → X: mean≈-0.8124, std≈1.5287
#   Sample: X.shape=(102, 87), y=[-0.2445292 -0.0332605]
#     → X: mean≈-0.8432, std≈1.5406
#   Sample: X.shape=(102, 87), y=[-0.2463669 -0.0338775]
#     → X: mean≈-0.8709, std≈1.5302
#   Sample: X.shape=(102, 87), y=[-0.111 -0.05 ]
#     → X: mean≈-1.1281, std≈1.7271
#   Sample: X.shape=(102, 87), y=[-0.108 -0.053]
#     → X: mean≈-1.0881, std≈1.6951
#   Sample: X.shape=(102, 87), y=[-0.11  -0.042]
#     → X: mean≈-1.1064, std≈1.7248
#   Sample: X.shape=(102, 87), y=[0.427 0.326]
#     → X: mean≈-0.5091, std≈1.3349
#   Sample: X.shape=(102, 87), y=[0.425 0.323]
#     → X: mean≈-0.5393, std≈1.3659
#   Sample: X.shape=(102, 87), y=[0.432 0.331]
#     → X: mean≈-0.5299, std≈1.3628
#   Sample: X.shape=(102, 87), y=[0.565 0.544]
#     → X: mean≈0.0844, std≈1.0562
#   Sample: X.shape=(102, 87), y=[0.563 0.564]
#     → X: mean≈0.0152, std≈1.0631
#   Sample: X.shape=(102, 87), y=[0.558 0.564]
#     → X: mean≈-0.0297, std≈1.0736
#   Sample: X.shape=(102, 87), y=[0.226 0.052]
#     → X: mean≈-0.6946, std≈1.4206
#   Sample: X.shape=(102, 87), y=[0.231 0.043]
#     → X: mean≈-0.6803, std≈1.4234
#   Sample: X.shape=(102, 87), y=[0.238 0.037]
#     → X: mean≈-0.6853, std≈1.4220
#   Sample: X.shape=(102, 87), y=[-0.201  0.011]
#     → X: mean≈-0.8397, std≈1.6766
#   Sample: X.shape=(102, 87), y=[-0.186 -0.02 ]
#     → X: mean≈-0.6858, std≈1.5699
#   Sample: X.shape=(102, 87), y=[-0.189  0.066]
#     → X: mean≈-0.6050, std≈1.5133
#   Sample: X.shape=(102, 87), y=[0.08555555 0.032     ]
#     → X: mean≈-1.4042, std≈2.0124
#   Sample: X.shape=(102, 87), y=[0.04888889 0.015     ]
#     → X: mean≈-1.4750, std≈2.0102
#   Sample: X.shape=(102, 87), y=[0.04333333 0.014     ]
#     → X: mean≈-1.3871, std≈1.9639
#   Sample: X.shape=(102, 87), y=[-0.019  0.279]
#     → X: mean≈-0.6387, std≈1.4862
#   Sample: X.shape=(102, 87), y=[0.033 0.25 ]
#     → X: mean≈-0.6350, std≈1.4783
#   Sample: X.shape=(102, 87), y=[0.044 0.245]
#     → X: mean≈-0.5301, std≈1.4285
#   Sample: X.shape=(102, 87), y=[ 0.038 -0.035]
#     → X: mean≈-0.6939, std≈1.3293
#   Sample: X.shape=(102, 87), y=[ 0.021 -0.041]
#     → X: mean≈-0.5387, std≈1.2611
#   Sample: X.shape=(102, 87), y=[ 0.008 -0.056]
#     → X: mean≈-0.5999, std≈1.3021
#   Sample: X.shape=(102, 87), y=[0.478 0.409]
#     → X: mean≈-0.5512, std≈1.4880
#   Sample: X.shape=(102, 87), y=[0.491 0.39 ]
#     → X: mean≈-0.5849, std≈1.4894
#   Sample: X.shape=(102, 87), y=[0.501 0.408]
#     → X: mean≈-0.5822, std≈1.4846
#   Sample: X.shape=(102, 87), y=[ 0.164 -0.047]
#     → X: mean≈-0.7124, std≈1.5115
#   Sample: X.shape=(102, 87), y=[ 0.162 -0.043]
#     → X: mean≈-0.9427, std≈1.5833
#   Sample: X.shape=(102, 87), y=[ 0.159 -0.039]
#     → X: mean≈-0.9402, std≈1.5649
#   Sample: X.shape=(102, 87), y=[-0.052  0.049]
#     → X: mean≈-0.8228, std≈2.0271
#   Sample: X.shape=(102, 87), y=[-0.049  0.062]
#     → X: mean≈-0.8240, std≈2.0224
#   Sample: X.shape=(102, 87), y=[-0.047  0.057]
#     → X: mean≈-0.8571, std≈2.0094
#   Sample: X.shape=(102, 87), y=[0.424 0.362]
#     → X: mean≈-0.3568, std≈1.2923
#   Sample: X.shape=(102, 87), y=[0.426 0.36 ]
#     → X: mean≈-0.4252, std≈1.3253
#   Sample: X.shape=(102, 87), y=[0.425 0.361]
#     → X: mean≈-0.3958, std≈1.3118
#   Sample: X.shape=(102, 87), y=[0.326 0.29 ]
#     → X: mean≈-0.2102, std≈1.1419
#   Sample: X.shape=(102, 87), y=[0.32  0.291]
#     → X: mean≈-0.2350, std≈1.1522
#   Sample: X.shape=(102, 87), y=[0.314 0.294]
#     → X: mean≈-0.2741, std≈1.1728
#   Sample: X.shape=(102, 87), y=[0.178 0.295]
#     → X: mean≈-0.5926, std≈1.2648
#   Sample: X.shape=(102, 87), y=[0.179 0.297]
#     → X: mean≈-0.5281, std≈1.2719
#   Sample: X.shape=(102, 87), y=[0.181 0.295]
#     → X: mean≈-0.5342, std≈1.2785
#   Sample: X.shape=(102, 87), y=[0.327 0.364]
#     → X: mean≈-0.4823, std≈1.2918
#   Sample: X.shape=(102, 87), y=[0.324 0.362]
#     → X: mean≈-0.4940, std≈1.3015
#   Sample: X.shape=(102, 87), y=[0.322 0.368]
#     → X: mean≈-0.5156, std≈1.2837
#   Sample: X.shape=(102, 87), y=[0.123 0.541]
#     → X: mean≈-0.3340, std≈1.2942
#   Sample: X.shape=(102, 87), y=[0.127 0.541]
#     → X: mean≈-0.4034, std≈1.2736
#   Sample: X.shape=(102, 87), y=[0.108 0.547]
#     → X: mean≈-0.3957, std≈1.3157
#   Sample: X.shape=(102, 87), y=[0.173      0.48444444]
#     → X: mean≈-0.3742, std≈1.2409
#   Sample: X.shape=(102, 87), y=[0.168      0.47777778]
#     → X: mean≈-0.3677, std≈1.2339
#   Sample: X.shape=(102, 87), y=[0.175      0.48666668]
#     → X: mean≈-0.3627, std≈1.2330
#   Sample: X.shape=(102, 87), y=[0.522 0.463]
#     → X: mean≈-0.2988, std≈1.2582
#   Sample: X.shape=(102, 87), y=[0.524 0.46 ]
#     → X: mean≈-0.2827, std≈1.2666
#   Sample: X.shape=(102, 87), y=[0.539 0.468]
#     → X: mean≈-0.2498, std≈1.2463
#   Sample: X.shape=(102, 87), y=[0.157 0.304]
#     → X: mean≈-0.6836, std≈1.4057
#   Sample: X.shape=(102, 87), y=[0.151 0.301]
#     → X: mean≈-0.7115, std≈1.4031
#   Sample: X.shape=(102, 87), y=[0.14  0.297]
#     → X: mean≈-0.6574, std≈1.3705
#   Sample: X.shape=(102, 87), y=[-0.33  -0.225]
#     → X: mean≈-1.1152, std≈1.6183
#   Sample: X.shape=(102, 87), y=[-0.33  -0.267]
#     → X: mean≈-0.9067, std≈1.4828
#   Sample: X.shape=(102, 87), y=[-0.332 -0.299]
#     → X: mean≈-0.9270, std≈1.4988
#   Sample: X.shape=(102, 87), y=[0.237 0.002]
#     → X: mean≈-0.3615, std≈1.2458
#   Sample: X.shape=(102, 87), y=[0.237 0.004]
#     → X: mean≈-0.3377, std≈1.2232
#   Sample: X.shape=(102, 87), y=[0.24  0.009]
#     → X: mean≈-0.3454, std≈1.2085
#   Sample: X.shape=(102, 87), y=[0.294 0.265]
#     → X: mean≈-0.8936, std≈1.4558
#   Sample: X.shape=(102, 87), y=[0.293 0.261]
#     → X: mean≈-0.8810, std≈1.4577
#   Sample: X.shape=(102, 87), y=[0.296 0.26 ]
#     → X: mean≈-0.8935, std≈1.4617
#   Sample: X.shape=(102, 87), y=[0.083 0.087]
#     → X: mean≈-1.0095, std≈1.7597
#   Sample: X.shape=(102, 87), y=[0.086 0.081]
#     → X: mean≈-1.0074, std≈1.7614
#   Sample: X.shape=(102, 87), y=[0.086 0.081]
#     → X: mean≈-0.9919, std≈1.7390
#   Sample: X.shape=(102, 87), y=[0.361 0.17 ]
#     → X: mean≈-0.8694, std≈1.5046
#   Sample: X.shape=(102, 87), y=[0.361 0.168]
#     → X: mean≈-0.8094, std≈1.4487
#   Sample: X.shape=(102, 87), y=[0.356 0.167]
#     → X: mean≈-0.8235, std≈1.4773
#   Sample: X.shape=(102, 87), y=[0.336 0.363]
#     → X: mean≈-0.8326, std≈1.5278
#   Sample: X.shape=(102, 87), y=[0.357 0.371]
#     → X: mean≈-0.8848, std≈1.5566
#   Sample: X.shape=(102, 87), y=[0.36  0.362]
#     → X: mean≈-0.8522, std≈1.5349
#   Sample: X.shape=(102, 87), y=[0.328 0.452]
#     → X: mean≈-1.1252, std≈1.6400
#   Sample: X.shape=(102, 87), y=[0.324 0.454]
#     → X: mean≈-1.0876, std≈1.6408
#   Sample: X.shape=(102, 87), y=[0.33  0.458]
#     → X: mean≈-1.0636, std≈1.6381
#   Sample: X.shape=(102, 87), y=[0.251 0.465]
#     → X: mean≈-0.9100, std≈1.5063
#   Sample: X.shape=(102, 87), y=[0.259 0.447]
#     → X: mean≈-0.8792, std≈1.4796
#   Sample: X.shape=(102, 87), y=[0.208 0.442]
#     → X: mean≈-0.9833, std≈1.5520
#   Sample: X.shape=(102, 87), y=[0.424 0.347]
#     → X: mean≈-0.7872, std≈1.5084
#   Sample: X.shape=(102, 87), y=[0.428 0.352]
#     → X: mean≈-0.8154, std≈1.4953
#   Sample: X.shape=(102, 87), y=[0.425 0.353]
#     → X: mean≈-0.8916, std≈1.5710
#   Sample: X.shape=(102, 87), y=[0.441 0.343]
#     → X: mean≈-0.5693, std≈1.6521
#   Sample: X.shape=(102, 87), y=[0.431 0.348]
#     → X: mean≈-0.5200, std≈1.6172
#   Sample: X.shape=(102, 87), y=[0.428 0.341]
#     → X: mean≈-0.5290, std≈1.5717
#   Sample: X.shape=(102, 87), y=[0.273 0.152]
#     → X: mean≈-0.4672, std≈1.2531
#   Sample: X.shape=(102, 87), y=[0.266 0.149]
#     → X: mean≈-0.5209, std≈1.2635
#   Sample: X.shape=(102, 87), y=[0.271 0.153]
#     → X: mean≈-0.5177, std≈1.2636
#   Sample: X.shape=(102, 87), y=[0.26  0.292]
#     → X: mean≈-0.1674, std≈1.1169
#   Sample: X.shape=(102, 87), y=[0.265 0.3  ]
#     → X: mean≈-0.2390, std≈1.1886
#   Sample: X.shape=(102, 87), y=[0.256 0.31 ]
#     → X: mean≈-0.3058, std≈1.2222
#   Sample: X.shape=(102, 87), y=[0.299 0.481]
#     → X: mean≈-0.5429, std≈1.5673
#   Sample: X.shape=(102, 87), y=[0.296 0.48 ]
#     → X: mean≈-0.4649, std≈1.5162
#   Sample: X.shape=(102, 87), y=[0.304 0.481]
#     → X: mean≈-0.4950, std≈1.4868
#   Sample: X.shape=(102, 87), y=[0.014 0.014]
#     → X: mean≈-1.3766, std≈1.8328
#   Sample: X.shape=(102, 87), y=[0.014 0.017]
#     → X: mean≈-1.0139, std≈1.7032
#   Sample: X.shape=(102, 87), y=[0.018 0.018]
#     → X: mean≈-0.8911, std≈1.6166
#   Sample: X.shape=(102, 87), y=[0.13  0.106]
#     → X: mean≈-1.0943, std≈1.5928
#   Sample: X.shape=(102, 87), y=[0.132 0.105]
#     → X: mean≈-1.1044, std≈1.5923
#   Sample: X.shape=(102, 87), y=[0.13  0.106]
#     → X: mean≈-1.1039, std≈1.6069
#   Sample: X.shape=(102, 87), y=[0.373 0.171]
#     → X: mean≈-0.5834, std≈1.4416
#   Sample: X.shape=(102, 87), y=[0.374 0.18 ]
#     → X: mean≈-0.5925, std≈1.4185
#   Sample: X.shape=(102, 87), y=[0.376 0.18 ]
#     → X: mean≈-0.5215, std≈1.3872
#   Sample: X.shape=(102, 87), y=[0.223 0.137]
#     → X: mean≈-0.7432, std≈1.5479
#   Sample: X.shape=(102, 87), y=[0.229 0.139]
#     → X: mean≈-0.6601, std≈1.5123
#   Sample: X.shape=(102, 87), y=[0.228 0.135]
#     → X: mean≈-0.6112, std≈1.4861
#   Sample: X.shape=(102, 87), y=[0.085 0.054]
#     → X: mean≈-0.8543, std≈1.6842
#   Sample: X.shape=(102, 87), y=[0.068 0.042]
#     → X: mean≈-0.8411, std≈1.6788
#   Sample: X.shape=(102, 87), y=[0.047 0.044]
#     → X: mean≈-0.9455, std≈1.6912
#   Sample: X.shape=(102, 87), y=[-0.145  0.343]
#     → X: mean≈-0.1657, std≈1.1305
#   Sample: X.shape=(102, 87), y=[-0.135  0.345]
#     → X: mean≈-0.2549, std≈1.1692
#   Sample: X.shape=(102, 87), y=[-0.13   0.344]
#     → X: mean≈-0.3072, std≈1.1911
#   Sample: X.shape=(102, 87), y=[0.139 0.349]
#     → X: mean≈-0.1831, std≈1.1027
#   Sample: X.shape=(102, 87), y=[0.149 0.347]
#     → X: mean≈-0.1980, std≈1.1007
#   Sample: X.shape=(102, 87), y=[0.152 0.344]
#     → X: mean≈-0.1859, std≈1.0927
#   Sample: X.shape=(102, 87), y=[0.319 0.365]
#     → X: mean≈-0.1027, std≈1.1316
#   Sample: X.shape=(102, 87), y=[0.321 0.355]
#     → X: mean≈-0.0876, std≈1.1363
#   Sample: X.shape=(102, 87), y=[0.327 0.36 ]
#     → X: mean≈-0.1231, std≈1.1716
#   Sample: X.shape=(102, 87), y=[0.126 0.214]
#     → X: mean≈-0.3351, std≈1.1609
#   Sample: X.shape=(102, 87), y=[0.143 0.219]
#     → X: mean≈-0.4168, std≈1.1887
#   Sample: X.shape=(102, 87), y=[0.14  0.222]
#     → X: mean≈-0.4705, std≈1.2108
#   Sample: X.shape=(102, 87), y=[0.174      0.09555556]
#     → X: mean≈-0.7034, std≈1.4549
#   Sample: X.shape=(102, 87), y=[0.175      0.09444445]
#     → X: mean≈-0.7147, std≈1.4393
#   Sample: X.shape=(102, 87), y=[0.181      0.09666666]
#     → X: mean≈-0.7936, std≈1.4910
#   Sample: X.shape=(102, 87), y=[-0.031  0.143]
#     → X: mean≈-0.5530, std≈1.4630
#   Sample: X.shape=(102, 87), y=[-0.021  0.141]
#     → X: mean≈-0.6021, std≈1.4566
#   Sample: X.shape=(102, 87), y=[-0.023  0.148]
#     → X: mean≈-0.6344, std≈1.4656
#   Sample: X.shape=(102, 87), y=[0.19  0.656]
#     → X: mean≈0.2731, std≈0.9832
#   Sample: X.shape=(102, 87), y=[0.2   0.661]
#     → X: mean≈0.2731, std≈0.9893
#   Sample: X.shape=(102, 87), y=[0.196 0.662]
#     → X: mean≈0.2312, std≈1.0029
#   Sample: X.shape=(102, 87), y=[0.16  0.225]
#     → X: mean≈-0.0958, std≈1.0978
#   Sample: X.shape=(102, 87), y=[0.17 0.23]
#     → X: mean≈-0.1371, std≈1.1142
#   Sample: X.shape=(102, 87), y=[0.167 0.236]
#     → X: mean≈-0.1527, std≈1.1227
#   Sample: X.shape=(102, 87), y=[-0.143  0.116]
#     → X: mean≈-0.8272, std≈1.6404
#   Sample: X.shape=(102, 87), y=[-0.147  0.102]
#     → X: mean≈-0.8410, std≈1.6523
#   Sample: X.shape=(102, 87), y=[-0.153  0.072]
#     → X: mean≈-0.8859, std≈1.6443
#   Sample: X.shape=(102, 87), y=[0.127 0.398]
#     → X: mean≈-0.5349, std≈1.3204
#   Sample: X.shape=(102, 87), y=[0.113 0.403]
#     → X: mean≈-0.5207, std≈1.3386
#   Sample: X.shape=(102, 87), y=[0.107 0.39 ]
#     → X: mean≈-0.5829, std≈1.3923
#   Sample: X.shape=(102, 87), y=[-0.244 -0.166]
#     → X: mean≈-0.4945, std≈1.3214
#   Sample: X.shape=(102, 87), y=[-0.242 -0.176]
#     → X: mean≈-0.4795, std≈1.2935
#   Sample: X.shape=(102, 87), y=[-0.248 -0.176]
#     → X: mean≈-0.4766, std≈1.3104
#   Sample: X.shape=(102, 87), y=[ 0.068 -0.228]
#     → X: mean≈-1.1257, std≈1.8588
#   Sample: X.shape=(102, 87), y=[ 0.06 -0.23]
#     → X: mean≈-1.0596, std≈1.8523
#   Sample: X.shape=(102, 87), y=[ 0.038 -0.222]
#     → X: mean≈-0.8140, std≈1.7401
#   Sample: X.shape=(102, 87), y=[-0.38   0.022]
#     → X: mean≈-0.3995, std≈1.3086
#   Sample: X.shape=(102, 87), y=[-0.378  0.014]
#     → X: mean≈-0.3536, std≈1.3049
#   Sample: X.shape=(102, 87), y=[-0.374  0.008]
#     → X: mean≈-0.3533, std≈1.3101
#   Sample: X.shape=(102, 87), y=[0.296 0.192]
#     → X: mean≈-0.5065, std≈1.4243
#   Sample: X.shape=(102, 87), y=[0.296 0.2  ]
#     → X: mean≈-0.4973, std≈1.4411
#   Sample: X.shape=(102, 87), y=[0.294 0.204]
#     → X: mean≈-0.5321, std≈1.4575
#   Sample: X.shape=(102, 87), y=[-0.194  0.26 ]
#     → X: mean≈-0.2055, std≈1.1821
#   Sample: X.shape=(102, 87), y=[-0.206  0.268]
#     → X: mean≈-0.2551, std≈1.2129
#   Sample: X.shape=(102, 87), y=[-0.212  0.264]
#     → X: mean≈-0.2729, std≈1.2219
#   Sample: X.shape=(102, 87), y=[-0.23   0.544]
#     → X: mean≈-0.0905, std≈1.0902
#   Sample: X.shape=(102, 87), y=[-0.228  0.542]
#     → X: mean≈-0.2180, std≈1.1748
#   Sample: X.shape=(102, 87), y=[-0.228  0.526]
#     → X: mean≈-0.3395, std≈1.2287
#   Sample: X.shape=(102, 87), y=[ 0.304 -0.022]
#     → X: mean≈-0.7398, std≈1.5968
#   Sample: X.shape=(102, 87), y=[ 0.304 -0.028]
#     → X: mean≈-0.7241, std≈1.6012
#   Sample: X.shape=(102, 87), y=[ 0.3  -0.03]
#     → X: mean≈-0.7147, std≈1.6348
#   Sample: X.shape=(102, 87), y=[0.314 0.268]
#     → X: mean≈-0.7157, std≈1.5012
#   Sample: X.shape=(102, 87), y=[0.318 0.266]
#     → X: mean≈-0.7191, std≈1.4943
#   Sample: X.shape=(102, 87), y=[0.316 0.266]
#     → X: mean≈-0.5082, std≈1.3773
#   Sample: X.shape=(102, 87), y=[-0.196  0.186]
#     → X: mean≈-0.8105, std≈1.6539
#   Sample: X.shape=(102, 87), y=[-0.196  0.194]
#     → X: mean≈-0.8105, std≈1.6368
#   Sample: X.shape=(102, 87), y=[-0.198  0.206]
#     → X: mean≈-0.7106, std≈1.5607
#   Sample: X.shape=(102, 87), y=[0.326 0.034]
#     → X: mean≈-0.4436, std≈1.3630
#   Sample: X.shape=(102, 87), y=[ 0.326 -0.014]
#     → X: mean≈-0.4636, std≈1.3698
#   Sample: X.shape=(102, 87), y=[0.326 0.012]
#     → X: mean≈-0.4618, std≈1.3663
#   Sample: X.shape=(102, 87), y=[ 0.302 -0.058]
#     → X: mean≈-0.6130, std≈1.3905
#   Sample: X.shape=(102, 87), y=[ 0.302 -0.072]
#     → X: mean≈-0.7044, std≈1.4149
#   Sample: X.shape=(102, 87), y=[ 0.302 -0.074]
#     → X: mean≈-0.6451, std≈1.3958
#   Sample: X.shape=(102, 87), y=[-0.418  0.506]
#     → X: mean≈-0.0523, std≈1.0794
#   Sample: X.shape=(102, 87), y=[-0.414  0.51 ]
#     → X: mean≈-0.0824, std≈1.1046
#   Sample: X.shape=(102, 87), y=[-0.41  0.49]
#     → X: mean≈-0.0558, std≈1.0949
#   Sample: X.shape=(102, 87), y=[0.222 0.026]
#     → X: mean≈-1.0584, std≈1.8397
#   Sample: X.shape=(102, 87), y=[0.224 0.018]
#     → X: mean≈-1.0039, std≈1.7884
#   Sample: X.shape=(102, 87), y=[0.22  0.028]
#     → X: mean≈-0.8066, std≈1.6587
#   Sample: X.shape=(102, 87), y=[-0.3    0.135]
#     → X: mean≈-0.7487, std≈1.4356
#   Sample: X.shape=(102, 87), y=[-0.305  0.14 ]
#     → X: mean≈-0.5105, std≈1.3277
#   Sample: X.shape=(102, 87), y=[-0.31166667  0.14166667]
#     → X: mean≈-0.7394, std≈1.4549
#   Sample: X.shape=(102, 87), y=[0.184 0.014]
#     → X: mean≈-0.4589, std≈1.3937
#   Sample: X.shape=(102, 87), y=[0.186 0.006]
#     → X: mean≈-0.4117, std≈1.3666
#   Sample: X.shape=(102, 87), y=[ 0.188 -0.002]
#     → X: mean≈-0.5440, std≈1.3668
#   Sample: X.shape=(102, 87), y=[-0.028 -0.046]
#     → X: mean≈-0.5051, std≈1.2861
#   Sample: X.shape=(102, 87), y=[-0.022 -0.048]
#     → X: mean≈-0.4306, std≈1.2576
#   Sample: X.shape=(102, 87), y=[-0.014 -0.036]
#     → X: mean≈-0.3679, std≈1.2337
#   Sample: X.shape=(102, 87), y=[0.218 0.166]
#     → X: mean≈-1.1712, std≈1.7722
#   Sample: X.shape=(102, 87), y=[0.222 0.172]
#     → X: mean≈-1.2259, std≈1.7875
#   Sample: X.shape=(102, 87), y=[0.228 0.174]
#     → X: mean≈-1.3174, std≈1.8411
#   Sample: X.shape=(102, 87), y=[-0.016 -0.226]
#     → X: mean≈-1.0890, std≈1.6814
#   Sample: X.shape=(102, 87), y=[-0.054 -0.234]
#     → X: mean≈-0.9613, std≈1.6369
#   Sample: X.shape=(102, 87), y=[-0.054 -0.234]
#     → X: mean≈-1.1121, std≈1.7053
#   Sample: X.shape=(102, 87), y=[-0.47   0.154]
#     → X: mean≈-0.4302, std≈1.2364
#   Sample: X.shape=(102, 87), y=[-0.468  0.156]
#     → X: mean≈-0.4450, std≈1.2509
#   Sample: X.shape=(102, 87), y=[-0.472  0.156]
#     → X: mean≈-0.5683, std≈1.3597
#   Sample: X.shape=(102, 87), y=[-0.314 -0.102]
#     → X: mean≈-0.7733, std≈1.5785
#   Sample: X.shape=(102, 87), y=[-0.314 -0.098]
#     → X: mean≈-0.7757, std≈1.5743
#   Sample: X.shape=(102, 87), y=[-0.314 -0.102]
#     → X: mean≈-0.7907, std≈1.5826
#   Sample: X.shape=(102, 87), y=[0.158 0.024]
#     → X: mean≈-0.9188, std≈1.5922
#   Sample: X.shape=(102, 87), y=[0.164 0.022]
#     → X: mean≈-0.8955, std≈1.5825
#   Sample: X.shape=(102, 87), y=[0.162 0.02 ]
#     → X: mean≈-0.8794, std≈1.5676
#   Sample: X.shape=(102, 87), y=[0.299125 0.636   ]
#     → X: mean≈-1.1949, std≈2.2943
#   Sample: X.shape=(102, 87), y=[0.290225 0.59335 ]
#     → X: mean≈-1.6380, std≈2.8319
#   Sample: X.shape=(102, 87), y=[0.6711  0.63825]
#     → X: mean≈-0.2956, std≈1.3228
#   Sample: X.shape=(102, 87), y=[0.12155 0.57665]
#     → X: mean≈-0.3000, std≈1.4231
#   Sample: X.shape=(102, 87), y=[0.12155 0.6031 ]
#     → X: mean≈-0.2894, std≈1.3965
#   Sample: X.shape=(102, 87), y=[0.134    0.605075]
#     → X: mean≈-0.3112, std≈1.3960
#   Sample: X.shape=(102, 87), y=[0.2073 0.3131]
#     → X: mean≈-0.2295, std≈1.1985
#   Sample: X.shape=(102, 87), y=[0.19065 0.32535]
#     → X: mean≈-0.2260, std≈1.1868
#   Sample: X.shape=(102, 87), y=[0.19     0.324025]
#     → X: mean≈-0.2436, std≈1.2027
#   Sample: X.shape=(102, 87), y=[0.592675 0.613875]
#     → X: mean≈-0.1918, std≈1.2446
#   Sample: X.shape=(102, 87), y=[0.59825 0.5661 ]
#     → X: mean≈-0.2626, std≈1.2582
#   Sample: X.shape=(102, 87), y=[0.60005  0.621025]
#     → X: mean≈-0.4653, std≈1.3396
#   Sample: X.shape=(102, 87), y=[0.46935 0.34975]
#     → X: mean≈-0.3692, std≈1.2236
#   Sample: X.shape=(102, 87), y=[0.4935 0.3064]
#     → X: mean≈-0.3342, std≈1.2109
#   Sample: X.shape=(102, 87), y=[0.4829   0.309325]
#     → X: mean≈-0.3898, std≈1.2210
#   Sample: X.shape=(102, 87), y=[0.581975 0.615775]
#     → X: mean≈0.2302, std≈1.1525
#   Sample: X.shape=(102, 87), y=[0.5811 0.6082]
#     → X: mean≈0.1251, std≈1.1731
#   Sample: X.shape=(102, 87), y=[0.5876   0.631125]
#     → X: mean≈-0.2770, std≈1.3095
#   Sample: X.shape=(102, 87), y=[-0.27465   0.382875]
#     → X: mean≈-0.0694, std≈1.1209
#   Sample: X.shape=(102, 87), y=[-0.25485  0.3971 ]
#     → X: mean≈-0.0343, std≈1.1254
#   Sample: X.shape=(102, 87), y=[-0.269975  0.3947  ]
#     → X: mean≈-0.0168, std≈1.1372
#   Sample: X.shape=(102, 87), y=[-0.08535 -0.27755]
#     → X: mean≈-1.3977, std≈1.8733
#   Sample: X.shape=(102, 87), y=[-0.088225 -0.242875]
#     → X: mean≈-1.4716, std≈1.8746
#   Sample: X.shape=(102, 87), y=[-0.094   -0.26265]
#     → X: mean≈-1.5265, std≈1.9661
#   Sample: X.shape=(102, 87), y=[0.577325 0.7544  ]
#     → X: mean≈-0.1846, std≈1.1921
#   Sample: X.shape=(102, 87), y=[0.555125 0.75975 ]
#     → X: mean≈-0.1954, std≈1.1829
#   Sample: X.shape=(102, 87), y=[0.5429  0.74445]
#     → X: mean≈-0.2289, std≈1.1778
#   Sample: X.shape=(102, 87), y=[-0.03425  -0.239325]
#     → X: mean≈-0.9000, std≈1.5571
#   Sample: X.shape=(102, 87), y=[-0.035825 -0.246625]
#     → X: mean≈-0.8646, std≈1.5284
#   Sample: X.shape=(102, 87), y=[-0.00335 -0.22445]
#     → X: mean≈-0.9713, std≈1.5895
#   Sample: X.shape=(102, 87), y=[-0.1438  0.4362]
#     → X: mean≈-0.4551, std≈1.3388
#   Sample: X.shape=(102, 87), y=[-0.133125  0.4558  ]
#     → X: mean≈-0.3406, std≈1.2399
#   Sample: X.shape=(102, 87), y=[-0.1162    0.496875]
#     → X: mean≈-0.3320, std≈1.2252
#   Sample: X.shape=(102, 87), y=[0.4362   0.395575]
#     → X: mean≈-0.2012, std≈1.2634
#   Sample: X.shape=(102, 87), y=[0.43335  0.390025]
#     → X: mean≈-0.1843, std≈1.2663
#   Sample: X.shape=(102, 87), y=[0.390275 0.36335 ]
#     → X: mean≈-0.2283, std≈1.2849
#   Sample: X.shape=(102, 87), y=[0.529975 0.76685 ]
#     → X: mean≈-0.3620, std≈1.4466
#   Sample: X.shape=(102, 87), y=[0.5569   0.808425]
#     → X: mean≈-0.3851, std≈1.4528
#   Sample: X.shape=(102, 87), y=[0.569325 0.818175]
#     → X: mean≈-0.4009, std≈1.4504
#   Sample: X.shape=(102, 87), y=[0.67755  0.753975]
#     → X: mean≈-0.2830, std≈1.2057
#   Sample: X.shape=(102, 87), y=[0.6709   0.742675]
#     → X: mean≈-0.2821, std≈1.2091
#   Sample: X.shape=(102, 87), y=[0.673525 0.746   ]
#     → X: mean≈-0.3238, std≈1.2342
#   Sample: X.shape=(102, 87), y=[-0.21918182 -0.2870909 ]
#     → X: mean≈-0.9189, std≈1.7574
#   Sample: X.shape=(102, 87), y=[-0.22645454 -0.27961364]
#     → X: mean≈-0.9185, std≈1.7636
#   Sample: X.shape=(102, 87), y=[-0.24175   -0.2585909]
#     → X: mean≈-0.9414, std≈1.7864
#   Sample: X.shape=(102, 87), y=[0.303325 0.328875]
#     → X: mean≈-0.3939, std≈1.3232
#   Sample: X.shape=(102, 87), y=[0.3171   0.325075]
#     → X: mean≈-0.3892, std≈1.3191
#   Sample: X.shape=(102, 87), y=[0.3289   0.324875]
#     → X: mean≈-0.3464, std≈1.3057
#   Sample: X.shape=(102, 87), y=[ 0.01335  -0.127075]
#     → X: mean≈-0.2463, std≈1.2151
#   Sample: X.shape=(102, 87), y=[ 0.0158   -0.136875]
#     → X: mean≈-0.2649, std≈1.2182
#   Sample: X.shape=(102, 87), y=[ 0.004025 -0.12555 ]
#     → X: mean≈-0.3322, std≈1.2488
#   Sample: X.shape=(102, 87), y=[ 0.03575  -0.171525]
#     → X: mean≈-1.1457, std≈2.2565
#   Sample: X.shape=(102, 87), y=[ 0.035125 -0.18485 ]
#     → X: mean≈-1.4556, std≈2.8301
#   Sample: X.shape=(102, 87), y=[0.333325 0.62805 ]
#     → X: mean≈-0.0226, std≈1.1852
#   Sample: X.shape=(102, 87), y=[0.05955 0.208  ]
#     → X: mean≈-0.0740, std≈1.1749
#   Sample: X.shape=(102, 87), y=[0.0531   0.190875]
#     → X: mean≈-0.5672, std≈1.4206
#   Sample: X.shape=(102, 87), y=[0.041125 0.2118  ]
#     → X: mean≈-0.5567, std≈1.4059
#   Sample: X.shape=(102, 87), y=[-0.392   -0.13575]
#     → X: mean≈-0.8528, std≈1.6449
#   Sample: X.shape=(102, 87), y=[-0.388425 -0.115075]
#     → X: mean≈-0.8160, std≈1.6185
#   Sample: X.shape=(102, 87), y=[-0.3873   -0.129325]
#     → X: mean≈-0.8562, std≈1.6429
#   Sample: X.shape=(102, 87), y=[-0.008475 -0.01135 ]
#     → X: mean≈-0.5282, std≈1.3909
#   Sample: X.shape=(102, 87), y=[ 0.030475 -0.044225]
#     → X: mean≈-0.5463, std≈1.4170
#   Sample: X.shape=(102, 87), y=[ 0.0067 -0.0587]
#     → X: mean≈-0.5079, std≈1.4047
#   Sample: X.shape=(102, 87), y=[0.206675 0.14645 ]
#     → X: mean≈-0.1926, std≈1.2109
#   Sample: X.shape=(102, 87), y=[0.212    0.140675]
#     → X: mean≈-0.2228, std≈1.2452
#   Sample: X.shape=(102, 87), y=[0.217125 0.1298  ]
#     → X: mean≈-0.2340, std≈1.2673
#   Sample: X.shape=(102, 87), y=[0.431975 0.63375 ]
#     → X: mean≈-0.0476, std≈1.1168
#   Sample: X.shape=(102, 87), y=[0.443525 0.616175]
#     → X: mean≈-0.0244, std≈1.1016
#   Sample: X.shape=(102, 87), y=[0.469775 0.616425]
#     → X: mean≈-0.0263, std≈1.1014
#   Sample: X.shape=(102, 87), y=[0.7091   0.702475]
#     → X: mean≈-0.3301, std≈1.2701
#   Sample: X.shape=(102, 87), y=[0.709575 0.686675]
#     → X: mean≈-0.3029, std≈1.2732
#   Sample: X.shape=(102, 87), y=[0.737575 0.692225]
#     → X: mean≈-0.3199, std≈1.2941
#   Sample: X.shape=(102, 87), y=[0.59935 0.75155]
#     → X: mean≈-0.3069, std≈1.2822
#   Sample: X.shape=(102, 87), y=[0.599325 0.748225]
#     → X: mean≈-0.3055, std≈1.2704
#   Sample: X.shape=(102, 87), y=[0.6082   0.739775]
#     → X: mean≈-0.2904, std≈1.2801
#   Sample: X.shape=(102, 87), y=[0.481125 0.142225]
#     → X: mean≈-0.1163, std≈1.1047
#   Sample: X.shape=(102, 87), y=[0.483325 0.1502  ]
#     → X: mean≈-0.1720, std≈1.1322
#   Sample: X.shape=(102, 87), y=[0.486    0.150625]
#     → X: mean≈-0.1528, std≈1.1116
#   Sample: X.shape=(102, 87), y=[0.17465  0.373575]
#     → X: mean≈-0.1122, std≈1.2449
#   Sample: X.shape=(102, 87), y=[0.159325 0.426175]
#     → X: mean≈-0.1162, std≈1.2504
#   Sample: X.shape=(102, 87), y=[0.134425 0.366675]
#     → X: mean≈-0.0323, std≈1.3147
#   Sample: X.shape=(102, 87), y=[-0.23502272  0.05472727]
#     → X: mean≈-1.0825, std≈1.8361
#   Sample: X.shape=(102, 87), y=[-0.23802273  0.05820455]
#     → X: mean≈-1.0883, std≈1.8466
#   Sample: X.shape=(102, 87), y=[-0.24909091  0.03475   ]
#     → X: mean≈-1.1111, std≈1.9066
#   Sample: X.shape=(102, 87), y=[0.0618  0.36955]
#     → X: mean≈-0.6379, std≈1.4974
#   Sample: X.shape=(102, 87), y=[0.1      0.391975]
#     → X: mean≈-0.7182, std≈1.6526
#   Sample: X.shape=(102, 87), y=[0.119125 0.395075]
#     → X: mean≈-0.7699, std≈1.6507
#   Sample: X.shape=(102, 87), y=[-0.176875  0.01    ]
#     → X: mean≈-0.5685, std≈1.4144
#   Sample: X.shape=(102, 87), y=[-0.19645 -0.01065]
#     → X: mean≈-0.5893, std≈1.4463
#   Sample: X.shape=(102, 87), y=[-0.200625  0.0098  ]
#     → X: mean≈-0.5711, std≈1.4239
#   Sample: X.shape=(102, 87), y=[-0.0815215  0.3753291]
#     → X: mean≈-0.1014, std≈1.3251
#   Sample: X.shape=(102, 87), y=[-0.0823911  0.3760145]
#     → X: mean≈-0.0694, std≈1.3178
#   Sample: X.shape=(102, 87), y=[-0.083517   0.3840306]
#     → X: mean≈-0.0969, std≈1.3388
#   Sample: X.shape=(102, 87), y=[-0.0217385  0.286251 ]
#     → X: mean≈-0.0528, std≈1.2559
#   Sample: X.shape=(102, 87), y=[-0.0222185  0.2934596]
#     → X: mean≈-0.0673, std≈1.2445
#   Sample: X.shape=(102, 87), y=[-0.0239861  0.295271 ]
#     → X: mean≈-0.0973, std≈1.2855
#   Sample: X.shape=(102, 87), y=[ 0.174522  -0.0009737]
#     → X: mean≈-0.8360, std≈1.5815
#   Sample: X.shape=(102, 87), y=[ 0.1757293 -0.0059217]
#     → X: mean≈-0.7995, std≈1.5927
#   Sample: X.shape=(102, 87), y=[ 0.1758907 -0.0049539]
#     → X: mean≈-0.7188, std≈1.5660
#   Sample: X.shape=(102, 87), y=[-0.2932446 -0.295457 ]
#     → X: mean≈-1.1735, std≈1.8041
#   Sample: X.shape=(102, 87), y=[-0.297282 -0.318993]
#     → X: mean≈-1.1518, std≈1.7904
#   Sample: X.shape=(102, 87), y=[-0.3042619 -0.3204478]
#     → X: mean≈-1.1163, std≈1.7525
#   Sample: X.shape=(102, 87), y=[0.1074884 0.1978873]
#     → X: mean≈-0.4958, std≈1.3932
#   Sample: X.shape=(102, 87), y=[0.1074884 0.1986015]
#     → X: mean≈-0.5049, std≈1.4002
#   Sample: X.shape=(102, 87), y=[0.1066184 0.1970553]
#     → X: mean≈-0.4695, std≈1.3901
#   Sample: X.shape=(102, 87), y=[ 0.0634787 -0.0572627]
#     → X: mean≈-1.4665, std≈1.8837
#   Sample: X.shape=(102, 87), y=[ 0.0611184 -0.0576087]
#     → X: mean≈-1.4779, std≈1.8746
#   Sample: X.shape=(102, 87), y=[ 0.0604354 -0.0576087]
#     → X: mean≈-1.2431, std≈1.7659
#   Sample: X.shape=(102, 87), y=[ 0.0573913 -0.2294848]
#     → X: mean≈-0.8731, std≈1.4607
#   Sample: X.shape=(102, 87), y=[ 0.0573913 -0.2295648]
#     → X: mean≈-0.6972, std≈1.3898
#   Sample: X.shape=(102, 87), y=[ 0.0573913 -0.2374528]
#     → X: mean≈-0.6850, std≈1.3646
#   Sample: X.shape=(102, 87), y=[0.2964929 0.1403838]
#     → X: mean≈-0.8516, std≈1.5407
#   Sample: X.shape=(102, 87), y=[0.2975656 0.1460338]
#     → X: mean≈-0.8092, std≈1.5097
#   Sample: X.shape=(102, 87), y=[0.2994184 0.1494588]
#     → X: mean≈-0.8351, std≈1.4946
#   Sample: X.shape=(102, 87), y=[0.4058881 0.511513 ]
#     → X: mean≈0.0303, std≈1.1000
#   Sample: X.shape=(102, 87), y=[0.4064631 0.5081097]
#     → X: mean≈0.0920, std≈1.0694
#   Sample: X.shape=(102, 87), y=[0.4083081 0.501629 ]
#     → X: mean≈0.0824, std≈1.0779
#   Sample: X.shape=(102, 87), y=[-0.105144  -0.0602173]
#     → X: mean≈-0.7809, std≈1.4390
#   Sample: X.shape=(102, 87), y=[-0.123261  -0.0623912]
#     → X: mean≈-0.7060, std≈1.4421
#   Sample: X.shape=(102, 87), y=[-0.13113   -0.0598774]
#     → X: mean≈-0.5482, std≈1.4023
#   Sample: X.shape=(102, 87), y=[0.288 0.151]
#     → X: mean≈-0.6351, std≈1.4705
#   Sample: X.shape=(102, 87), y=[0.285 0.16 ]
#     → X: mean≈-0.7484, std≈1.5058
#   Sample: X.shape=(102, 87), y=[0.29  0.162]
#     → X: mean≈-0.5551, std≈1.3736
#   Sample: X.shape=(102, 87), y=[ 0.013 -0.286]
#     → X: mean≈-1.4232, std≈2.0928
#   Sample: X.shape=(102, 87), y=[ 0.024 -0.284]
#     → X: mean≈-1.4001, std≈2.1003
#   Sample: X.shape=(102, 87), y=[ 0.059 -0.276]
#     → X: mean≈-1.4533, std≈2.1027
#   Sample: X.shape=(102, 87), y=[-0.013 -0.069]
#     → X: mean≈-0.9445, std≈1.6942
#   Sample: X.shape=(102, 87), y=[-0.022 -0.067]
#     → X: mean≈-0.9824, std≈1.6706
#   Sample: X.shape=(102, 87), y=[-0.032 -0.056]
#     → X: mean≈-1.0207, std≈1.6473
#   Sample: X.shape=(102, 87), y=[0.408 0.39 ]
#     → X: mean≈-0.3114, std≈1.1676
#   Sample: X.shape=(102, 87), y=[0.405 0.396]
#     → X: mean≈-0.4100, std≈1.2242
#   Sample: X.shape=(102, 87), y=[0.405 0.397]
#     → X: mean≈-0.4442, std≈1.2242
#   Sample: X.shape=(102, 87), y=[0.531 0.622]
#     → X: mean≈-0.2145, std≈1.2106
#   Sample: X.shape=(102, 87), y=[0.556 0.62 ]
#     → X: mean≈-0.1384, std≈1.1726
#   Sample: X.shape=(102, 87), y=[0.556 0.633]
#     → X: mean≈-0.1354, std≈1.1542
#   Sample: X.shape=(102, 87), y=[0.155 0.149]
#     → X: mean≈-0.5366, std≈1.4568
#   Sample: X.shape=(102, 87), y=[0.15  0.155]
#     → X: mean≈-0.6072, std≈1.4600
#   Sample: X.shape=(102, 87), y=[0.139 0.148]
#     → X: mean≈-0.6068, std≈1.4602
#   Sample: X.shape=(102, 87), y=[0.126 0.255]
#     → X: mean≈-1.0451, std≈1.7995
#   Sample: X.shape=(102, 87), y=[0.119 0.253]
#     → X: mean≈-0.9787, std≈1.7904
#   Sample: X.shape=(102, 87), y=[0.122 0.256]
#     → X: mean≈-0.9627, std≈1.8207
#   Sample: X.shape=(102, 87), y=[0.492 0.527]
#     → X: mean≈0.0168, std≈1.1353
#   Sample: X.shape=(102, 87), y=[0.491 0.544]
#     → X: mean≈-0.1405, std≈1.1948
#   Sample: X.shape=(102, 87), y=[0.494 0.521]
#     → X: mean≈-0.1261, std≈1.2014
#   Sample: X.shape=(102, 87), y=[0.066 0.073]
#     → X: mean≈-0.7409, std≈1.4420
#   Sample: X.shape=(102, 87), y=[ 0.066 -0.085]
#     → X: mean≈-0.6974, std≈1.3950
#   Sample: X.shape=(102, 87), y=[ 0.064 -0.084]
#     → X: mean≈-0.7137, std≈1.3512
#   Sample: X.shape=(102, 87), y=[0.424 0.207]
#     → X: mean≈-0.4110, std≈1.2181
#   Sample: X.shape=(102, 87), y=[0.426 0.204]
#     → X: mean≈-0.3605, std≈1.1918
#   Sample: X.shape=(102, 87), y=[0.413 0.202]
#     → X: mean≈-0.4012, std≈1.1998
#   Sample: X.shape=(102, 87), y=[0.506 0.478]
#     → X: mean≈-0.9518, std≈1.8436
#   Sample: X.shape=(102, 87), y=[0.506 0.477]
#     → X: mean≈-0.9688, std≈1.8179
#   Sample: X.shape=(102, 87), y=[0.506 0.485]
#     → X: mean≈-1.0528, std≈1.8927
#   Sample: X.shape=(102, 87), y=[0.172 0.592]
#     → X: mean≈-0.3447, std≈1.1537
#   Sample: X.shape=(102, 87), y=[0.175 0.596]
#     → X: mean≈-0.3808, std≈1.1641
#   Sample: X.shape=(102, 87), y=[0.175 0.596]
#     → X: mean≈-0.3360, std≈1.1608
#   Sample: X.shape=(102, 87), y=[-0.088 -0.074]
#     → X: mean≈-0.7477, std≈1.5574
#   Sample: X.shape=(102, 87), y=[-0.082 -0.076]
#     → X: mean≈-0.7987, std≈1.5420
#   Sample: X.shape=(102, 87), y=[-0.068 -0.078]
#     → X: mean≈-0.8072, std≈1.5664
#   Sample: X.shape=(102, 87), y=[-0.40333334 -0.3       ]
#     → X: mean≈-0.4029, std≈1.4460
#   Sample: X.shape=(102, 87), y=[-0.40666667 -0.265     ]
#     → X: mean≈-0.4810, std≈1.5196
#   Sample: X.shape=(102, 87), y=[-0.52       -0.28166667]
#     → X: mean≈-0.4049, std≈1.5219
#   Sample: X.shape=(102, 87), y=[ 0.018 -0.032]
#     → X: mean≈-0.9817, std≈1.6215
#   Sample: X.shape=(102, 87), y=[ 0.03  -0.076]
#     → X: mean≈-0.6939, std≈1.4886
#   Sample: X.shape=(102, 87), y=[ 0.014 -0.124]
#     → X: mean≈-0.6835, std≈1.4656
#   Sample: X.shape=(102, 87), y=[0.474 0.172]
#     → X: mean≈-0.2483, std≈1.2448
#   Sample: X.shape=(102, 87), y=[0.478 0.172]
#     → X: mean≈-0.3760, std≈1.2905
#   Sample: X.shape=(102, 87), y=[0.474 0.17 ]
#     → X: mean≈-0.5052, std≈1.3557
#   Sample: X.shape=(102, 87), y=[ 0.388 -0.258]
#     → X: mean≈-0.8455, std≈1.5004
#   Sample: X.shape=(102, 87), y=[ 0.386 -0.256]
#     → X: mean≈-0.8153, std≈1.4905
#   Sample: X.shape=(102, 87), y=[ 0.386 -0.254]
#     → X: mean≈-0.8485, std≈1.5012
#   Sample: X.shape=(102, 87), y=[0.63375  0.534875]
#     → X: mean≈-0.6300, std≈1.5721
#   Sample: X.shape=(102, 87), y=[0.621975 0.53375 ]
#     → X: mean≈-0.5980, std≈1.5758
#   Sample: X.shape=(102, 87), y=[0.621975 0.53555 ]
#     → X: mean≈-0.6513, std≈1.5707
#   Sample: X.shape=(102, 87), y=[-0.2473  -0.47425]
#     → X: mean≈-0.9489, std≈1.7170
#   Sample: X.shape=(102, 87), y=[-0.253125 -0.49625 ]
#     → X: mean≈-0.7708, std≈1.6132
#   Sample: X.shape=(102, 87), y=[-0.257775 -0.489125]
#     → X: mean≈-0.7423, std≈1.6145
#   Sample: X.shape=(102, 87), y=[0.2831  0.04025]
#     → X: mean≈-0.7301, std≈1.5041
#   Sample: X.shape=(102, 87), y=[0.291375 0.04845 ]
#     → X: mean≈-0.7652, std≈1.5076
#   Sample: X.shape=(102, 87), y=[0.296225 0.054425]
#     → X: mean≈-0.7507, std≈1.5254
#   Sample: X.shape=(102, 87), y=[0.441575 0.406875]
#     → X: mean≈-0.3162, std≈1.2352
#   Sample: X.shape=(102, 87), y=[0.458875 0.415525]
#     → X: mean≈-0.3436, std≈1.2457
#   Sample: X.shape=(102, 87), y=[0.456   0.40285]
#     → X: mean≈-0.3000, std≈1.2246
#   Sample: X.shape=(102, 87), y=[0.171775 0.06445 ]
#     → X: mean≈-0.4906, std≈1.5263
#   Sample: X.shape=(102, 87), y=[0.173325 0.0729  ]
#     → X: mean≈-0.5278, std≈1.5453
#   Sample: X.shape=(102, 87), y=[0.17265 0.0847 ]
#     → X: mean≈-0.4088, std≈1.4943
#   Sample: X.shape=(102, 87), y=[-0.15634091  0.09981818]
#     → X: mean≈-0.5536, std≈1.3648
#   Sample: X.shape=(102, 87), y=[-0.15877272  0.10222727]
#     → X: mean≈-0.5735, std≈1.3598
#   Sample: X.shape=(102, 87), y=[-0.16709091  0.08988637]
#     → X: mean≈-0.5780, std≈1.3773
#   Sample: X.shape=(102, 87), y=[0.147775 0.44715 ]
#     → X: mean≈0.0879, std≈1.1596
#   Sample: X.shape=(102, 87), y=[0.1531 0.4618]
#     → X: mean≈0.0778, std≈1.1923
#   Sample: X.shape=(102, 87), y=[0.157975 0.438675]
#     → X: mean≈0.1100, std≈1.1658
#
# ✅ Verificación exitosa: 504 samples leídos correctamente
# True

# %% [markdown]
# ### FASE 7: EJEMPLO DE CARGA Y ENTRENAMIENTO CON CNN+GRU
#
# Esta sección muestra cómo cargar el dataset y construir tu arquitectura CNN+GRU.

# %%
# Cargar datasets desde TFRecords CON OPTIMIZACIÓN
# Transposición: (102, n_frames) → (n_frames, 102) para mejor cache locality en redes RNN
print("=" * 60)
print("CARGANDO DATASETS OPTIMIZADOS PARA ENTRENAMIENTO")
print("=" * 60)

def parse_tfrecord_optimized(serialized_example):
    """
    Parse optimizado que retorna X transpuesto.
    
    Forma original: (102, n_frames) = 102 features, ~86 frames
    Forma optimizada: (n_frames, 102) = ~86 frames, 102 features
    
    Esta forma es mejor para RNN/LSTM porque el tiempo es la primera dimensión.
    """
    feature_description = {
        'X': tf.io.VarLenFeature(tf.float32),
        'valence': tf.io.FixedLenFeature([], tf.float32),
        'arousal': tf.io.FixedLenFeature([], tf.float32),
        'musicId': tf.io.FixedLenFeature([], tf.int64),
        'dataset': tf.io.FixedLenFeature([], tf.string),
        'frameTime': tf.io.FixedLenFeature([], tf.float32),
    }
    
    parsed = tf.io.parse_single_example(serialized_example, feature_description)
    
    # Convertir X de sparse a denso
    X_flat = tf.sparse.to_dense(parsed['X']) # Vector flattenizado
    X = tf.reshape(X_flat, (102, -1)) # Reshape a (102, n_frames)
    
    # TRANSPONER: (102, n_frames) → (n_frames, 102) para RNN
    X = tf.transpose(X)
    
    # Combinar labels
    y = tf.stack([parsed['valence'], parsed['arousal']])
    
    return X, y

def load_tfrecord_dataset_optimized(tfrecord_dir, split_name="train", batch_size=64, shuffle_buffer=5000):
    """
    Carga dataset con batch_size más grande (64 en lugar de 32).
    
    Un batch_size más grande es más eficiente en GPU.
    """
    pattern = os.path.join(tfrecord_dir, f"{split_name}_batch_*.tfrecord") # Buscar archivos
    tfrecord_files = sorted(tf.io.gfile.glob(pattern)) # Listar archivos encontrados
    
    if not tfrecord_files:
        print(f"❌ No se encontraron archivos: {pattern}")
        return None
    
    print(f"✅ Encontrados {len(tfrecord_files)} archivos para {split_name}")
    
    dataset = tf.data.TFRecordDataset(tfrecord_files) # Crear dataset
    dataset = dataset.map(parse_tfrecord_optimized, num_parallel_calls=tf.data.AUTOTUNE) # Mapear con parse optimizado
    
    if split_name == "train":
        dataset = dataset.shuffle(shuffle_buffer) # Shuffle solo en train
    
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)
    
    return dataset

# Cargar datasets con batch_size=64 (mejor para GPU)
train_dataset_opt = load_tfrecord_dataset_optimized(tfrecord_output, split_name="train", batch_size=64)
val_dataset_opt = load_tfrecord_dataset_optimized(tfrecord_output, split_name="val", batch_size=64)

# Validar que el formato sea correcto para la red neuronal
print("\n📊 Validando formato del dataset optimizado...")
for X_batch, y_batch in train_dataset_opt.take(1):
    print(f"  ✅ X_batch.shape: {X_batch.shape} (esperado: (64, n_frames, 102))")
    print(f"  ✅ y_batch.shape: {y_batch.shape} (esperado: (64, 2))")
    print(f"  ✅ y_batch sample: {y_batch[0].numpy()} (valence, arousal)")

print("\n✅ Datasets optimizados cargados correctamente")
# Out:
# ============================================================
# CARGANDO DATASETS OPTIMIZADOS PARA ENTRENAMIENTO
# ============================================================
# ✅ Encontrados 134 archivos para train
# ✅ Encontrados 34 archivos para val
#
# 📊 Validando formato del dataset optimizado...
#   ✅ X_batch.shape: (64, 87, 102) (esperado: (64, n_frames, 102))
#   ✅ y_batch.shape: (64, 2) (esperado: (64, 2))
#   ✅ y_batch sample: [ 0.0370292 -0.0664814] (valence, arousal)
#
# ✅ Datasets optimizados cargados correctamente

# %%
import tensorflow as tf

# ==================== DEFINICIÓN DE MÉTRICA Y FUNCIÓN DE PÉRDIDA ====================

def ccc_score_tf(y_true, y_pred, eps=1e-8):
    """
    Calcula el Concordance Correlation Coefficient (CCC).
    
    CCC mide acuerdo entre predicción y realidad (mejor que MSE para regresión ordinal).
    Rango: [-1, 1] donde 1 = acuerdo perfecto, 0 = sin acuerdo, -1 = desacuerdo perfecto.
    
    Fórmula: CCC = 2 * cov(y_true, y_pred) / (var(y_true) + var(y_pred) + (mean_true - mean_pred)^2)
    """
    # Asegurar que ambos sean float32 (para evitar problemas con mixed precision)
    y_true = tf.cast(y_true, tf.float32) # Convertir a float32
    y_pred = tf.cast(y_pred, tf.float32) # Convertir a float32

    mean_true = tf.reduce_mean(y_true, axis=0) # Media de y_true
    mean_pred = tf.reduce_mean(y_pred, axis=0) # Media de y_pred
    var_true = tf.reduce_mean(tf.square(y_true - mean_true), axis=0) # Varianza de y_true
    var_pred = tf.reduce_mean(tf.square(y_pred - mean_pred), axis=0) # Varianza de y_pred
    cov = tf.reduce_mean((y_true - mean_true) * (y_pred - mean_pred), axis=0) # Covarianza

    ccc = (2.0 * cov) / (var_true + var_pred + tf.square(mean_true - mean_pred) + eps)
    return ccc

@tf.function
def ccc_metric(y_true, y_pred):
    """
    Métrica CCC promediada: si hay múltiples dimensiones (valence y arousal),
    retorna el promedio de CCC para ambas.
    """
    c = ccc_score_tf(y_true, y_pred)
    return tf.reduce_mean(c)

@tf.function
def ccc_loss(y_true, y_pred):
    """
    Loss basado en CCC: 1 - CCC
    Esto convierte maximización de CCC a minimización de loss.
    """
    c = ccc_score_tf(y_true, y_pred)
    return 1.0 - tf.reduce_mean(c)

def combined_loss(alpha=0.5):
    """
    Loss combinado: alpha * MSE + (1-alpha) * CCC_loss
    
    - MSE proporciona estabilidad (penaliza errores grandes)
    - CCC refina la correlación (lo importante para emoción)
    - alpha=0.5: balance entre ambos
    """
    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        
        # MSE: error cuadrático medio (penaliza desviaciones)
        mse = tf.reduce_mean(tf.square(y_true - y_pred))
        
        # CCC: correlación de concordancia (para cada dimensión: valence y arousal)
        ccc_val = 1.0 - ccc_valence(y_true, y_pred)
        ccc_aro = 1.0 - ccc_arousal(y_true, y_pred)
        avg_ccc_loss = (ccc_val + ccc_aro) / 2.0
        
        # Combinar: 50% MSE + 50% CCC
        return alpha * mse + (1.0 - alpha) * avg_ccc_loss
    return loss

@tf.function
def ccc_valence(y_true, y_pred):
    """CCC para dimensión 0 (valence solamente)"""
    return ccc_score_tf(y_true[:, 0], y_pred[:, 0])

@tf.function
def ccc_arousal(y_true, y_pred):
    """CCC para dimensión 1 (arousal solamente)"""
    return ccc_score_tf(y_true[:, 1], y_pred[:, 1])

# %% [markdown]
# ---
#
# # PARTE 2: MODELO LIMPIO DESDE CERO
#
# ## Arquitectura: CNN1D → BiGRU → Atención → Dense
#
# **Objetivo**: Dado un audio cualquiera, predecir `[valence, arousal]` ∈ [-1, 1]
#
# **Pipeline**:
# 1. Audio (MP3) → Cargar 2s centrados
# 2. Extraer 102 features
# 3. Normalizar (aplicar scaler precomputado)
# 4. Red neuronal predice emoción
# 5. Devolver [valence, arousal]

# %%
# ============================================================================
# CAPA DE ATENCIÓN (Reutilizable en cualquier red)
# ============================================================================
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers

class AttentionBlock(layers.Layer):
    """
    Capa de atención simple que pondera los frames según su importancia.
    
    Problema: En una canción de 2 segundos, hay ~86 frames.
    ¿Son todos igual de importantes para la emoción?
    
    Solución: Usar atención para dar más peso a frames importantes.
    
    Input: (batch, timesteps, features) = (64, 86, 128)
    Output: (batch, features) = (64, 128) contexto ponderado
    
    Mecanismo:
    1. Calcular score de importancia para cada frame
    2. Aplicar softmax para obtener pesos (suma = 1)
    3. Ponderar frames y sumar (weighted average)
    """
    def __init__(self, **kwargs):
        super(AttentionBlock, self).__init__(**kwargs) # Inicializar capa base
        self.score_dense = layers.Dense(1, activation='tanh') # Capa densa para scores
        self.softmax = layers.Softmax(axis=1) # Softmax sobre timesteps

    def call(self, inputs):
        # inputs: (batch, t, features)
        scores = self.score_dense(inputs)      # (batch, t, 1)
        weights = self.softmax(scores)         # (batch, t, 1) suma a 1 por timestep
        context = tf.reduce_sum(inputs * weights, axis=1)  # (batch, features)
        return context

print("✅ AttentionBlock definida")
# Out:
# ✅ AttentionBlock definida

# %%
# ============================================================================
# ARQUITECTURA PRINCIPAL: CNN1D → BiGRU → Atención → Dense (VERSIÓN REGULARIZADA)
# ============================================================================

def build_mer_model(
    n_frames=86,
    n_features=102,
    l2_reg=1e-4,
    dropout_spatial=0.4,
    dropout_dense=0.5,
    lr=1e-4
): # Construye el modelo MER regularizado
    """
    Versión regularizada del modelo MER para reducir sobreajuste.
    Cambios clave:
      - Menor número de filtros/unidades para reducir capacidad
      - Dropout espacial más alto
      - recurrent_dropout en GRU para regularizar memoria recurrente
      - LayerNormalization después de la atención
      - GaussianNoise en la entrada para robustez
    """
    inp = layers.Input(shape=(n_frames, n_features), name='input_audio_features') # Input

    # Ruido de entrada (pequeño) para robustez (se activa solo en training)
    x = layers.GaussianNoise(0.01)(inp) # Añadir ruido gaussiano

    # BLOQUE CONV 1D (más pequeño)
    x = layers.Conv1D(16, kernel_size=3, padding='same', activation='relu',
                      kernel_regularizer=regularizers.l2(l2_reg), name='conv1d_16')(x) # Menos filtros
    x = layers.BatchNormalization()(x) # Normalización por batch
    x = layers.SpatialDropout1D(dropout_spatial)(x) # Dropout espacial

    x = layers.Conv1D(32, kernel_size=3, padding='same', activation='relu',
                      kernel_regularizer=regularizers.l2(l2_reg), name='conv1d_32')(x) # Menos filtros
    x = layers.BatchNormalization()(x) # Normalización por batch
    x = layers.SpatialDropout1D(dropout_spatial)(x) # Dropout espacial

    x = layers.Conv1D(48, kernel_size=3, padding='same', activation='relu',
                      kernel_regularizer=regularizers.l2(l2_reg), name='conv1d_48')(x) # Menos filtros
    x = layers.BatchNormalization()(x) # Normalización por batch
    x = layers.SpatialDropout1D(dropout_spatial)(x) # Dropout espacial

    x = layers.MaxPooling1D(pool_size=2, name='maxpool')(x) # Reducción de dimensionalidad

    # BLOQUE BiGRU (más pequeño y con recurrent_dropout)
    # ... (Parte de CNN igual) ...

    # BIDIRECTIONAL GRU: Simplificamos a UNA sola capa más robusta
    x = layers.Bidirectional(
        layers.GRU(32, return_sequences=True, activation='tanh', # Subimos un poco unidades, quitamos una capa
                   kernel_regularizer=regularizers.l2(l2_reg),
                   recurrent_regularizer=regularizers.l2(l2_reg),
                   dropout=0.3, # Dropout interno del GRU
                   recurrent_dropout=0.0) # 0.0 para usar cuDNN (más rápido)
    )(x)
    x = layers.SpatialDropout1D(0.4)(x) # Dropout espacial después del BiGRU

    # ATENCIÓN
    context = AttentionBlock(name='attention')(x) # Capa de atención
    context = layers.LayerNormalization()(context) # Normalización de capa después de atención

    # HEAD DENSO SIMPLIFICADO
    # Quitamos la estructura profunda de Dense->Dropout->Dense->Dropout
    # Vamos directo a la predicción o con una sola capa intermedia muy regularizada
    
    x = layers.Dropout(0.5)(context) # Dropout fuerte antes de la decisión final
    
    # Salida directa (o con una capa de 16 unidades si prefieres)
    output = layers.Dense(2, activation='tanh', dtype='float32', name='output_valence_arousal')(x) # Salida final

    model = models.Model(inputs=inp, outputs=output, name='MER_CNN_BiGRU_Attention_reg') # Modelo completo

    optimizer = tf.keras.optimizers.Adam(learning_rate=lr) # Optimizador Adam
    model.compile(optimizer=optimizer,
                  loss=combined_loss(alpha=0.25),  # más peso a CCC
                  metrics=[ccc_metric, 'mae']) # Métricas: CCC y MAE
    return model

# Reconstruir modelo con la configuración regularizada
print("\n" + "="*60)
print("CONSTRUYENDO MODELO MER (VERSIÓN REGULARIZADA)")
print("="*60)
model = build_mer_model(n_frames=86, n_features=102, l2_reg=1e-4, dropout_spatial=0.4, dropout_dense=0.5, lr=1e-4) # Construir modelo
model.summary()

print("\n✅ Modelo regularizado compilado y listo para entrenar")
# Out:
# ============================================================
# CONSTRUYENDO MODELO MER (VERSIÓN REGULARIZADA)
# ============================================================
# Model: "MER_CNN_BiGRU_Attention_reg"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_audio_features (Input  [(None, 86, 102)]        0
#  Layer)
#
#  gaussian_noise (GaussianNoi  (None, 86, 102)          0
#  se)
#
#  conv1d_16 (Conv1D)          (None, 86, 16)            4912
#
#  batch_normalization (BatchN  (None, 86, 16)           64
#  ormalization)
#
#  spatial_dropout1d (SpatialD  (None, 86, 16)           0
#  ropout1D)
#
#  conv1d_32 (Conv1D)          (None, 86, 32)            1568
#
#  batch_normalization_1 (Batc  (None, 86, 32)           128
#  hNormalization)
#
#  spatial_dropout1d_1 (Spatia  (None, 86, 32)           0
#  lDropout1D)
#
#  conv1d_48 (Conv1D)          (None, 86, 48)            4656
#
#  batch_normalization_2 (Batc  (None, 86, 48)           192
#  hNormalization)
#
#  spatial_dropout1d_2 (Spatia  (None, 86, 48)           0
#  lDropout1D)
#
#  maxpool (MaxPooling1D)      (None, 43, 48)            0
#
#  bidirectional (Bidirectiona  (None, 43, 64)           15744
#  l)
#
#  spatial_dropout1d_3 (Spatia  (None, 43, 64)           0
#  lDropout1D)
#
#  attention (AttentionBlock)  (None, 64)                65
#
#  layer_normalization (LayerN  (None, 64)               128
#  ormalization)
#
#  dropout (Dropout)           (None, 64)                0
#
#  output_valence_arousal (Den  (None, 2)                130
#  se)
#
# =================================================================
# Total params: 27,587
# Trainable params: 27,395
# Non-trainable params: 192
# _________________________________________________________________
#
# ✅ Modelo regularizado compilado y listo para entrenar

# %%
# ============================================================================
# ENTRENAMIENTO: Configurar y lanzar
# ============================================================================

print("\n" + "="*70)
print("PREPARAR ENTRENAMIENT0")
print("="*70)

# 1. Cargar/verificar scaler
scaler_path = os.path.join(OUTPUT_PATH, "scaler_per_block_102.pkl")
if os.path.exists(scaler_path):
    scaler_info = joblib.load(scaler_path)
    print(f"✅ Scaler cargado: {len(scaler_info)} bloques")
else:
    print(f"❌ Scaler no encontrado en {scaler_path}")
    print("   Debes ejecutar compute_global_scaler() primero")

def mixup(ds_one, ds_two, alpha=0.2):
    # Desempaquetar
    images_one, labels_one = ds_one
    images_two, labels_two = ds_two

    # Generar lambda de distribución beta
    batch_size = tf.shape(images_one)[0]
    l = tf.random.gamma([batch_size, 1], alpha, 1.0) # Para broadcast correcto
    l = tf.random.gamma([batch_size, 1, 1], alpha, 1.0) # Para broadcast correcto en imagen

    # Mezclar imágenes
    images = l * images_one + (1 - l) * images_two

    # Mezclar etiquetas (Valence, Arousal)
    # Ajustar lambda para dimensiones de etiqueta
    l_labels = tf.reshape(l, [batch_size, 1]) 
    labels = l_labels * labels_one + (1 - l_labels) * labels_two

    return images, labels

# EN TU PIPELINE DE CARGA DE DATOS:
# Asegúrate de que train_dataset tenga drop_remainder=True para que funcione bien
train_dataset = load_tfrecord_dataset_optimized(tfrecord_output, split_name="train", batch_size=32)
val_dataset = load_tfrecord_dataset_optimized(tfrecord_output, split_name="train", batch_size=32).shuffle(1024)

# TODO: Aplicar Mixup solo al dataset de entrenamiento
# Zip del dataset consigo mismo (mezclado)
train_ds_mixup = tf.data.Dataset.zip((train_dataset, train_dataset)) # Mezclar con otro batch del mismo dataset
train_ds_mixup = train_ds_mixup.map(lambda x, y: mixup(x, y, alpha=0.2), num_parallel_calls=tf.data.AUTOTUNE) # Aplicar Mixup
train_ds_mixup = train_ds_mixup.prefetch(tf.data.AUTOTUNE) # Precarga

# IMPORTANTE: Usa 'train_ds_mixup' para model.fit, NO el train_dataset normal.
# NO apliques Mixup al validation set.

# --- Augmentación on-the-fly (solo en train): añadir ruido gaussiano pequeño a features ---
# Esto aumenta la robustez sin regenerar TFRecords
def _augment_features(X, y, noise_std=0.02):
    noise = tf.random.normal(tf.shape(X), mean=0.0, stddev=noise_std, dtype=X.dtype)
    return X + noise, y

# Aplicar augmentación solo al dataset de entrenamiento
train_dataset = train_dataset.map(lambda X, y: _augment_features(X, y, noise_std=0.02), num_parallel_calls=tf.data.AUTOTUNE) # Añadir ruido
# Mantener shuffle/prefetch para rendimiento
train_dataset = train_dataset.shuffle(2000) # Shuffle extra
train_dataset = train_dataset.prefetch(tf.data.AUTOTUNE) # Precarga

# Validar
for X_batch, y_batch in train_dataset.take(1):
    print(f"  ✅ Train batch: X={X_batch.shape}, y={y_batch.shape}")
for X_batch, y_batch in val_dataset.take(1):
    print(f"  ✅ Val batch: X={X_batch.shape}, y={y_batch.shape}")

# 3. Definir callbacks
callbacks_training = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_ccc_metric',
        mode='max',
        patience=10,
        restore_best_weights=True,
        verbose=1,
        min_delta=1e-4
    ),
    tf.keras.callbacks.ModelCheckpoint(
        os.path.join(OUTPUT_PATH, 'best_mer_model.keras'),
        monitor='val_ccc_metric',
        mode='max',
        save_best_only=True,
        save_weights_only=False,
        verbose=1
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_ccc_metric',
        mode='max',
        factor=0.2,
        patience=4,
        min_lr=1e-6,
        verbose=1
    ),
] # Callbacks para entrenamiento

print("\n✅ Configuración lista. Ejecuta la siguiente celda para entrenar.")
# Out:
# ======================================================================
# PREPARAR ENTRENAMIENT0
# ======================================================================
# ✅ Scaler cargado: 10 bloques
# ✅ Encontrados 134 archivos para train
# ✅ Encontrados 134 archivos para train
#   ✅ Train batch: X=(32, 87, 102), y=(32, 2)
#   ✅ Val batch: X=(32, 87, 102), y=(32, 2)
#
# ✅ Configuración lista. Ejecuta la siguiente celda para entrenar.

# %% [markdown]
# ENTRENAMIENTO SIN APLICAR LO DEL #TODO

# %%
# ============================================================================
# ENTRENAR MODELO
# ============================================================================

print("\n" + "="*70)
print("INICIANDO ENTRENAMIENTO")
print("="*70 + "\n")

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=50,
    callbacks=callbacks_training,
    verbose=1
)

print("\n✅ Entrenamiento completado")

# Guardar modelo
model_final_path = os.path.join(OUTPUT_PATH, 'mer_model_final.keras')
model.save(model_final_path)
print(f"💾 Modelo guardado: {model_final_path}")
# Out:
# ======================================================================
# INICIANDO ENTRENAMIENTO
# ======================================================================
#
# Epoch 1/50
#    4167/Unknown - 221s 35ms/step - loss: 0.7789 - ccc_metric: 0.1957 - mae: 0.6985
# Epoch 1: val_ccc_metric improved from -inf to 0.22826, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
#
# Epoch 1: val_ccc_metric improved from -inf to 0.22826, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 371s 71ms/step - loss: 0.7789 - ccc_metric: 0.1957 - mae: 0.6985 - val_loss: 0.7726 - val_ccc_metric: 0.2283 - val_mae: 0.7693 - lr: 1.0000e-04
# Epoch 2/50
# 4167/4167 [==============================] - 371s 71ms/step - loss: 0.7789 - ccc_metric: 0.1957 - mae: 0.6985 - val_loss: 0.7726 - val_ccc_metric: 0.2283 - val_mae: 0.7693 - lr: 1.0000e-04
# Epoch 2/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.6347 - ccc_metric: 0.2930 - mae: 0.4759
# Epoch 2: val_ccc_metric improved from 0.22826 to 0.39748, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
#
# Epoch 2: val_ccc_metric improved from 0.22826 to 0.39748, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 322s 61ms/step - loss: 0.6346 - ccc_metric: 0.2930 - mae: 0.4759 - val_loss: 0.5224 - val_ccc_metric: 0.3975 - val_mae: 0.3658 - lr: 1.0000e-04
# Epoch 3/50
# 4167/4167 [==============================] - 322s 61ms/step - loss: 0.6346 - ccc_metric: 0.2930 - mae: 0.4759 - val_loss: 0.5224 - val_ccc_metric: 0.3975 - val_mae: 0.3658 - lr: 1.0000e-04
# Epoch 3/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.4540 - ccc_metric: 0.4518 - mae: 0.2302
# Epoch 3: val_ccc_metric improved from 0.39748 to 0.44534, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
#
# Epoch 3: val_ccc_metric improved from 0.39748 to 0.44534, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 319s 62ms/step - loss: 0.4540 - ccc_metric: 0.4518 - mae: 0.2302 - val_loss: 0.4683 - val_ccc_metric: 0.4453 - val_mae: 0.2905 - lr: 1.0000e-04
# 4167/4167 [==============================] - 319s 62ms/step - loss: 0.4540 - ccc_metric: 0.4518 - mae: 0.2302 - val_loss: 0.4683 - val_ccc_metric: 0.4453 - val_mae: 0.2905 - lr: 1.0000e-04
# Epoch 4/50
# Epoch 4/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.4243 - ccc_metric: 0.4849 - mae: 0.2144
# Epoch 4: val_ccc_metric improved from 0.44534 to 0.48579, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
#
# Epoch 4: val_ccc_metric improved from 0.44534 to 0.48579, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 355s 69ms/step - loss: 0.4243 - ccc_metric: 0.4849 - mae: 0.2144 - val_loss: 0.4314 - val_ccc_metric: 0.4858 - val_mae: 0.2670 - lr: 1.0000e-04
# Epoch 5/50
# 4167/4167 [==============================] - 355s 69ms/step - loss: 0.4243 - ccc_metric: 0.4849 - mae: 0.2144 - val_loss: 0.4314 - val_ccc_metric: 0.4858 - val_mae: 0.2670 - lr: 1.0000e-04
# Epoch 5/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.4048 - ccc_metric: 0.5076 - mae: 0.2095
# Epoch 5: val_ccc_metric improved from 0.48579 to 0.51606, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
#
# Epoch 5: val_ccc_metric improved from 0.48579 to 0.51606, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 330s 63ms/step - loss: 0.4048 - ccc_metric: 0.5076 - mae: 0.2095 - val_loss: 0.4045 - val_ccc_metric: 0.5161 - val_mae: 0.2516 - lr: 1.0000e-04
# 4167/4167 [==============================] - 330s 63ms/step - loss: 0.4048 - ccc_metric: 0.5076 - mae: 0.2095 - val_loss: 0.4045 - val_ccc_metric: 0.5161 - val_mae: 0.2516 - lr: 1.0000e-04
# Epoch 6/50
# Epoch 6/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3918 - ccc_metric: 0.5226 - mae: 0.2065
# Epoch 6: val_ccc_metric improved from 0.51606 to 0.53096, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
#
# Epoch 6: val_ccc_metric improved from 0.51606 to 0.53096, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 371s 71ms/step - loss: 0.3918 - ccc_metric: 0.5226 - mae: 0.2065 - val_loss: 0.3905 - val_ccc_metric: 0.5310 - val_mae: 0.2423 - lr: 1.0000e-04
# 4167/4167 [==============================] - 371s 71ms/step - loss: 0.3918 - ccc_metric: 0.5226 - mae: 0.2065 - val_loss: 0.3905 - val_ccc_metric: 0.5310 - val_mae: 0.2423 - lr: 1.0000e-04
# Epoch 7/50
# Epoch 7/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3808 - ccc_metric: 0.5352 - mae: 0.2043
# Epoch 7: val_ccc_metric improved from 0.53096 to 0.55494, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
#
# Epoch 7: val_ccc_metric improved from 0.53096 to 0.55494, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 341s 66ms/step - loss: 0.3808 - ccc_metric: 0.5352 - mae: 0.2043 - val_loss: 0.3705 - val_ccc_metric: 0.5549 - val_mae: 0.2372 - lr: 1.0000e-04
# Epoch 8/50
# 4167/4167 [==============================] - 341s 66ms/step - loss: 0.3808 - ccc_metric: 0.5352 - mae: 0.2043 - val_loss: 0.3705 - val_ccc_metric: 0.5549 - val_mae: 0.2372 - lr: 1.0000e-04
# Epoch 8/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3719 - ccc_metric: 0.5456 - mae: 0.2023
# Epoch 8: val_ccc_metric improved from 0.55494 to 0.56633, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
#
# Epoch 8: val_ccc_metric improved from 0.55494 to 0.56633, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 330s 62ms/step - loss: 0.3719 - ccc_metric: 0.5456 - mae: 0.2023 - val_loss: 0.3608 - val_ccc_metric: 0.5663 - val_mae: 0.2361 - lr: 1.0000e-04
# Epoch 9/50
# 4167/4167 [==============================] - 330s 62ms/step - loss: 0.3719 - ccc_metric: 0.5456 - mae: 0.2023 - val_loss: 0.3608 - val_ccc_metric: 0.5663 - val_mae: 0.2361 - lr: 1.0000e-04
# Epoch 9/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3666 - ccc_metric: 0.5513 - mae: 0.2012
# Epoch 9: val_ccc_metric did not improve from 0.56633
# 4167/4167 [==============================] - 346s 68ms/step - loss: 0.3666 - ccc_metric: 0.5513 - mae: 0.2012 - val_loss: 0.3624 - val_ccc_metric: 0.5632 - val_mae: 0.2362 - lr: 1.0000e-04
#
# Epoch 9: val_ccc_metric did not improve from 0.56633
# 4167/4167 [==============================] - 346s 68ms/step - loss: 0.3666 - ccc_metric: 0.5513 - mae: 0.2012 - val_loss: 0.3624 - val_ccc_metric: 0.5632 - val_mae: 0.2362 - lr: 1.0000e-04
# Epoch 10/50
# Epoch 10/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3610 - ccc_metric: 0.5576 - mae: 0.1999
# Epoch 10: val_ccc_metric did not improve from 0.56633
# 4167/4167 [==============================] - 365s 73ms/step - loss: 0.3610 - ccc_metric: 0.5576 - mae: 0.1999 - val_loss: 0.3621 - val_ccc_metric: 0.5638 - val_mae: 0.2405 - lr: 1.0000e-04
# Epoch 11/50
#
# Epoch 10: val_ccc_metric did not improve from 0.56633
# 4167/4167 [==============================] - 365s 73ms/step - loss: 0.3610 - ccc_metric: 0.5576 - mae: 0.1999 - val_loss: 0.3621 - val_ccc_metric: 0.5638 - val_mae: 0.2405 - lr: 1.0000e-04
# Epoch 11/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3551 - ccc_metric: 0.5645 - mae: 0.1985
# Epoch 11: val_ccc_metric improved from 0.56633 to 0.56979, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
#
# Epoch 11: val_ccc_metric improved from 0.56633 to 0.56979, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 335s 65ms/step - loss: 0.3551 - ccc_metric: 0.5645 - mae: 0.1985 - val_loss: 0.3568 - val_ccc_metric: 0.5698 - val_mae: 0.2389 - lr: 1.0000e-04
# 4167/4167 [==============================] - 335s 65ms/step - loss: 0.3551 - ccc_metric: 0.5645 - mae: 0.1985 - val_loss: 0.3568 - val_ccc_metric: 0.5698 - val_mae: 0.2389 - lr: 1.0000e-04
# Epoch 12/50
# Epoch 12/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3513 - ccc_metric: 0.5688 - mae: 0.1978
# Epoch 12: val_ccc_metric improved from 0.56979 to 0.59780, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
#
# Epoch 12: val_ccc_metric improved from 0.56979 to 0.59780, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 350s 68ms/step - loss: 0.3513 - ccc_metric: 0.5688 - mae: 0.1978 - val_loss: 0.3327 - val_ccc_metric: 0.5978 - val_mae: 0.2210 - lr: 1.0000e-04
# Epoch 13/50
# 4167/4167 [==============================] - 350s 68ms/step - loss: 0.3513 - ccc_metric: 0.5688 - mae: 0.1978 - val_loss: 0.3327 - val_ccc_metric: 0.5978 - val_mae: 0.2210 - lr: 1.0000e-04
# Epoch 13/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3468 - ccc_metric: 0.5740 - mae: 0.1964
# Epoch 13: val_ccc_metric did not improve from 0.59780
# 4167/4167 [==============================] - 355s 66ms/step - loss: 0.3468 - ccc_metric: 0.5740 - mae: 0.1964 - val_loss: 0.3529 - val_ccc_metric: 0.5737 - val_mae: 0.2384 - lr: 1.0000e-04
# Epoch 14/50
#
# Epoch 13: val_ccc_metric did not improve from 0.59780
# 4167/4167 [==============================] - 355s 66ms/step - loss: 0.3468 - ccc_metric: 0.5740 - mae: 0.1964 - val_loss: 0.3529 - val_ccc_metric: 0.5737 - val_mae: 0.2384 - lr: 1.0000e-04
# Epoch 14/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3451 - ccc_metric: 0.5757 - mae: 0.1960
# Epoch 14: val_ccc_metric did not improve from 0.59780
# 4167/4167 [==============================] - 404s 82ms/step - loss: 0.3451 - ccc_metric: 0.5757 - mae: 0.1960 - val_loss: 0.3436 - val_ccc_metric: 0.5847 - val_mae: 0.2336 - lr: 1.0000e-04
# Epoch 15/50
#
# Epoch 14: val_ccc_metric did not improve from 0.59780
# 4167/4167 [==============================] - 404s 82ms/step - loss: 0.3451 - ccc_metric: 0.5757 - mae: 0.1960 - val_loss: 0.3436 - val_ccc_metric: 0.5847 - val_mae: 0.2336 - lr: 1.0000e-04
# Epoch 15/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3414 - ccc_metric: 0.5799 - mae: 0.1948
# Epoch 15: val_ccc_metric did not improve from 0.59780
# 4167/4167 [==============================] - 364s 72ms/step - loss: 0.3414 - ccc_metric: 0.5800 - mae: 0.1948 - val_loss: 0.3334 - val_ccc_metric: 0.5961 - val_mae: 0.2256 - lr: 1.0000e-04
# Epoch 16/50
#
# Epoch 15: val_ccc_metric did not improve from 0.59780
# 4167/4167 [==============================] - 364s 72ms/step - loss: 0.3414 - ccc_metric: 0.5800 - mae: 0.1948 - val_loss: 0.3334 - val_ccc_metric: 0.5961 - val_mae: 0.2256 - lr: 1.0000e-04
# Epoch 16/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3391 - ccc_metric: 0.5825 - mae: 0.1939
# Epoch 16: val_ccc_metric did not improve from 0.59780
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 4167/4167 [==============================] - 326s 63ms/step - loss: 0.3391 - ccc_metric: 0.5825 - mae: 0.1939 - val_loss: 0.3332 - val_ccc_metric: 0.5962 - val_mae: 0.2267 - lr: 1.0000e-04
# Epoch 17/50
#
# Epoch 16: val_ccc_metric did not improve from 0.59780
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 4167/4167 [==============================] - 326s 63ms/step - loss: 0.3391 - ccc_metric: 0.5825 - mae: 0.1939 - val_loss: 0.3332 - val_ccc_metric: 0.5962 - val_mae: 0.2267 - lr: 1.0000e-04
# Epoch 17/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3366 - ccc_metric: 0.5854 - mae: 0.1932
# Epoch 17: val_ccc_metric did not improve from 0.59780
# 4167/4167 [==============================] - 298s 57ms/step - loss: 0.3366 - ccc_metric: 0.5854 - mae: 0.1932 - val_loss: 0.3328 - val_ccc_metric: 0.5971 - val_mae: 0.2288 - lr: 2.0000e-05
# Epoch 18/50
#
# Epoch 17: val_ccc_metric did not improve from 0.59780
# 4167/4167 [==============================] - 298s 57ms/step - loss: 0.3366 - ccc_metric: 0.5854 - mae: 0.1932 - val_loss: 0.3328 - val_ccc_metric: 0.5971 - val_mae: 0.2288 - lr: 2.0000e-05
# Epoch 18/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3367 - ccc_metric: 0.5852 - mae: 0.1933
# Epoch 18: val_ccc_metric improved from 0.59780 to 0.60291, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
#
# Epoch 18: val_ccc_metric improved from 0.59780 to 0.60291, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 321s 61ms/step - loss: 0.3367 - ccc_metric: 0.5852 - mae: 0.1933 - val_loss: 0.3279 - val_ccc_metric: 0.6029 - val_mae: 0.2256 - lr: 2.0000e-05
# Epoch 19/50
# 4167/4167 [==============================] - 321s 61ms/step - loss: 0.3367 - ccc_metric: 0.5852 - mae: 0.1933 - val_loss: 0.3279 - val_ccc_metric: 0.6029 - val_mae: 0.2256 - lr: 2.0000e-05
# Epoch 19/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3352 - ccc_metric: 0.5870 - mae: 0.1929
# Epoch 19: val_ccc_metric did not improve from 0.60291
# 4167/4167 [==============================] - 326s 63ms/step - loss: 0.3352 - ccc_metric: 0.5871 - mae: 0.1929 - val_loss: 0.3294 - val_ccc_metric: 0.6010 - val_mae: 0.2264 - lr: 2.0000e-05
#
# Epoch 19: val_ccc_metric did not improve from 0.60291
# 4167/4167 [==============================] - 326s 63ms/step - loss: 0.3352 - ccc_metric: 0.5871 - mae: 0.1929 - val_loss: 0.3294 - val_ccc_metric: 0.6010 - val_mae: 0.2264 - lr: 2.0000e-05
# Epoch 20/50
# Epoch 20/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3354 - ccc_metric: 0.5867 - mae: 0.1928
# Epoch 20: val_ccc_metric improved from 0.60291 to 0.60769, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
#
# Epoch 20: val_ccc_metric improved from 0.60291 to 0.60769, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 321s 62ms/step - loss: 0.3354 - ccc_metric: 0.5867 - mae: 0.1928 - val_loss: 0.3238 - val_ccc_metric: 0.6077 - val_mae: 0.2227 - lr: 2.0000e-05
# Epoch 21/50
# 4167/4167 [==============================] - 321s 62ms/step - loss: 0.3354 - ccc_metric: 0.5867 - mae: 0.1928 - val_loss: 0.3238 - val_ccc_metric: 0.6077 - val_mae: 0.2227 - lr: 2.0000e-05
# Epoch 21/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3344 - ccc_metric: 0.5879 - mae: 0.1925
# Epoch 21: val_ccc_metric did not improve from 0.60769
# 4167/4167 [==============================] - 377s 73ms/step - loss: 0.3344 - ccc_metric: 0.5879 - mae: 0.1925 - val_loss: 0.3246 - val_ccc_metric: 0.6066 - val_mae: 0.2234 - lr: 2.0000e-05
# Epoch 22/50
#
# Epoch 21: val_ccc_metric did not improve from 0.60769
# 4167/4167 [==============================] - 377s 73ms/step - loss: 0.3344 - ccc_metric: 0.5879 - mae: 0.1925 - val_loss: 0.3246 - val_ccc_metric: 0.6066 - val_mae: 0.2234 - lr: 2.0000e-05
# Epoch 22/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3346 - ccc_metric: 0.5875 - mae: 0.1925
# Epoch 22: val_ccc_metric did not improve from 0.60769
# 4167/4167 [==============================] - 328s 61ms/step - loss: 0.3346 - ccc_metric: 0.5875 - mae: 0.1925 - val_loss: 0.3282 - val_ccc_metric: 0.6023 - val_mae: 0.2262 - lr: 2.0000e-05
# Epoch 23/50
#
# Epoch 22: val_ccc_metric did not improve from 0.60769
# 4167/4167 [==============================] - 328s 61ms/step - loss: 0.3346 - ccc_metric: 0.5875 - mae: 0.1925 - val_loss: 0.3282 - val_ccc_metric: 0.6023 - val_mae: 0.2262 - lr: 2.0000e-05
# Epoch 23/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3335 - ccc_metric: 0.5888 - mae: 0.1922
# Epoch 23: val_ccc_metric improved from 0.60769 to 0.61007, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
#
# Epoch 23: val_ccc_metric improved from 0.60769 to 0.61007, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 343s 67ms/step - loss: 0.3335 - ccc_metric: 0.5888 - mae: 0.1922 - val_loss: 0.3216 - val_ccc_metric: 0.6101 - val_mae: 0.2217 - lr: 2.0000e-05
# Epoch 24/50
# 4167/4167 [==============================] - 343s 67ms/step - loss: 0.3335 - ccc_metric: 0.5888 - mae: 0.1922 - val_loss: 0.3216 - val_ccc_metric: 0.6101 - val_mae: 0.2217 - lr: 2.0000e-05
# Epoch 24/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3320 - ccc_metric: 0.5908 - mae: 0.1921
# Epoch 24: val_ccc_metric did not improve from 0.61007
# 4167/4167 [==============================] - 344s 67ms/step - loss: 0.3320 - ccc_metric: 0.5908 - mae: 0.1921 - val_loss: 0.3236 - val_ccc_metric: 0.6077 - val_mae: 0.2233 - lr: 2.0000e-05
#
# Epoch 24: val_ccc_metric did not improve from 0.61007
# 4167/4167 [==============================] - 344s 67ms/step - loss: 0.3320 - ccc_metric: 0.5908 - mae: 0.1921 - val_loss: 0.3236 - val_ccc_metric: 0.6077 - val_mae: 0.2233 - lr: 2.0000e-05
# Epoch 25/50
# Epoch 25/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3312 - ccc_metric: 0.5917 - mae: 0.1915
# Epoch 25: val_ccc_metric did not improve from 0.61007
# 4167/4167 [==============================] - 373s 72ms/step - loss: 0.3312 - ccc_metric: 0.5917 - mae: 0.1915 - val_loss: 0.3293 - val_ccc_metric: 0.6007 - val_mae: 0.2264 - lr: 2.0000e-05
# Epoch 26/50
#
# Epoch 25: val_ccc_metric did not improve from 0.61007
# 4167/4167 [==============================] - 373s 72ms/step - loss: 0.3312 - ccc_metric: 0.5917 - mae: 0.1915 - val_loss: 0.3293 - val_ccc_metric: 0.6007 - val_mae: 0.2264 - lr: 2.0000e-05
# Epoch 26/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3310 - ccc_metric: 0.5919 - mae: 0.1918
# Epoch 26: val_ccc_metric did not improve from 0.61007
# 4167/4167 [==============================] - 369s 72ms/step - loss: 0.3310 - ccc_metric: 0.5919 - mae: 0.1918 - val_loss: 0.3251 - val_ccc_metric: 0.6054 - val_mae: 0.2223 - lr: 2.0000e-05
#
# Epoch 26: val_ccc_metric did not improve from 0.61007
# 4167/4167 [==============================] - 369s 72ms/step - loss: 0.3310 - ccc_metric: 0.5919 - mae: 0.1918 - val_loss: 0.3251 - val_ccc_metric: 0.6054 - val_mae: 0.2223 - lr: 2.0000e-05
# Epoch 27/50
# Epoch 27/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3321 - ccc_metric: 0.5904 - mae: 0.1916
# Epoch 27: val_ccc_metric did not improve from 0.61007
#
# Epoch 27: val_ccc_metric did not improve from 0.61007
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 4167/4167 [==============================] - 365s 72ms/step - loss: 0.3321 - ccc_metric: 0.5904 - mae: 0.1916 - val_loss: 0.3252 - val_ccc_metric: 0.6056 - val_mae: 0.2246 - lr: 2.0000e-05
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 4167/4167 [==============================] - 365s 72ms/step - loss: 0.3321 - ccc_metric: 0.5904 - mae: 0.1916 - val_loss: 0.3252 - val_ccc_metric: 0.6056 - val_mae: 0.2246 - lr: 2.0000e-05
# Epoch 28/50
# Epoch 28/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3313 - ccc_metric: 0.5914 - mae: 0.1923
# Epoch 28: val_ccc_metric improved from 0.61007 to 0.61192, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
#
# Epoch 28: val_ccc_metric improved from 0.61007 to 0.61192, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 340s 66ms/step - loss: 0.3313 - ccc_metric: 0.5914 - mae: 0.1923 - val_loss: 0.3197 - val_ccc_metric: 0.6119 - val_mae: 0.2196 - lr: 4.0000e-06
# Epoch 29/50
# 4167/4167 [==============================] - 340s 66ms/step - loss: 0.3313 - ccc_metric: 0.5914 - mae: 0.1923 - val_loss: 0.3197 - val_ccc_metric: 0.6119 - val_mae: 0.2196 - lr: 4.0000e-06
# Epoch 29/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3320 - ccc_metric: 0.5904 - mae: 0.1917
# Epoch 29: val_ccc_metric improved from 0.61192 to 0.61210, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
#
# Epoch 29: val_ccc_metric improved from 0.61192 to 0.61210, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 396s 78ms/step - loss: 0.3320 - ccc_metric: 0.5904 - mae: 0.1918 - val_loss: 0.3195 - val_ccc_metric: 0.6121 - val_mae: 0.2191 - lr: 4.0000e-06
# Epoch 30/50
# 4167/4167 [==============================] - 396s 78ms/step - loss: 0.3320 - ccc_metric: 0.5904 - mae: 0.1918 - val_loss: 0.3195 - val_ccc_metric: 0.6121 - val_mae: 0.2191 - lr: 4.0000e-06
# Epoch 30/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3321 - ccc_metric: 0.5903 - mae: 0.1918
# Epoch 30: val_ccc_metric did not improve from 0.61210
# 4167/4167 [==============================] - 357s 67ms/step - loss: 0.3321 - ccc_metric: 0.5903 - mae: 0.1918 - val_loss: 0.3203 - val_ccc_metric: 0.6112 - val_mae: 0.2200 - lr: 4.0000e-06
# Epoch 31/50
#
# Epoch 30: val_ccc_metric did not improve from 0.61210
# 4167/4167 [==============================] - 357s 67ms/step - loss: 0.3321 - ccc_metric: 0.5903 - mae: 0.1918 - val_loss: 0.3203 - val_ccc_metric: 0.6112 - val_mae: 0.2200 - lr: 4.0000e-06
# Epoch 31/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3314 - ccc_metric: 0.5912 - mae: 0.1917
# Epoch 31: val_ccc_metric did not improve from 0.61210
# 4167/4167 [==============================] - 356s 69ms/step - loss: 0.3314 - ccc_metric: 0.5912 - mae: 0.1917 - val_loss: 0.3265 - val_ccc_metric: 0.6038 - val_mae: 0.2243 - lr: 4.0000e-06
# Epoch 32/50
#
# Epoch 31: val_ccc_metric did not improve from 0.61210
# 4167/4167 [==============================] - 356s 69ms/step - loss: 0.3314 - ccc_metric: 0.5912 - mae: 0.1917 - val_loss: 0.3265 - val_ccc_metric: 0.6038 - val_mae: 0.2243 - lr: 4.0000e-06
# Epoch 32/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3322 - ccc_metric: 0.5902 - mae: 0.1919
# Epoch 32: val_ccc_metric improved from 0.61210 to 0.61504, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
#
# Epoch 32: val_ccc_metric improved from 0.61210 to 0.61504, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 338s 66ms/step - loss: 0.3322 - ccc_metric: 0.5902 - mae: 0.1919 - val_loss: 0.3171 - val_ccc_metric: 0.6150 - val_mae: 0.2180 - lr: 4.0000e-06
# Epoch 33/50
# 4167/4167 [==============================] - 338s 66ms/step - loss: 0.3322 - ccc_metric: 0.5902 - mae: 0.1919 - val_loss: 0.3171 - val_ccc_metric: 0.6150 - val_mae: 0.2180 - lr: 4.0000e-06
# Epoch 33/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3301 - ccc_metric: 0.5929 - mae: 0.1912
# Epoch 33: val_ccc_metric did not improve from 0.61504
# 4167/4167 [==============================] - 348s 68ms/step - loss: 0.3300 - ccc_metric: 0.5929 - mae: 0.1912 - val_loss: 0.3200 - val_ccc_metric: 0.6114 - val_mae: 0.2193 - lr: 4.0000e-06
# Epoch 34/50
#
# Epoch 33: val_ccc_metric did not improve from 0.61504
# 4167/4167 [==============================] - 348s 68ms/step - loss: 0.3300 - ccc_metric: 0.5929 - mae: 0.1912 - val_loss: 0.3200 - val_ccc_metric: 0.6114 - val_mae: 0.2193 - lr: 4.0000e-06
# Epoch 34/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3315 - ccc_metric: 0.5910 - mae: 0.1915
# Epoch 34: val_ccc_metric did not improve from 0.61504
#
# Epoch 34: val_ccc_metric did not improve from 0.61504
# 4167/4167 [==============================] - 356s 70ms/step - loss: 0.3315 - ccc_metric: 0.5910 - mae: 0.1915 - val_loss: 0.3177 - val_ccc_metric: 0.6143 - val_mae: 0.2187 - lr: 4.0000e-06
# 4167/4167 [==============================] - 356s 70ms/step - loss: 0.3315 - ccc_metric: 0.5910 - mae: 0.1915 - val_loss: 0.3177 - val_ccc_metric: 0.6143 - val_mae: 0.2187 - lr: 4.0000e-06
# Epoch 35/50
# Epoch 35/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3300 - ccc_metric: 0.5930 - mae: 0.1910
# Epoch 35: val_ccc_metric did not improve from 0.61504
# 4167/4167 [==============================] - 350s 68ms/step - loss: 0.3300 - ccc_metric: 0.5930 - mae: 0.1910 - val_loss: 0.3197 - val_ccc_metric: 0.6120 - val_mae: 0.2205 - lr: 4.0000e-06
# Epoch 36/50
#
# Epoch 35: val_ccc_metric did not improve from 0.61504
# 4167/4167 [==============================] - 350s 68ms/step - loss: 0.3300 - ccc_metric: 0.5930 - mae: 0.1910 - val_loss: 0.3197 - val_ccc_metric: 0.6120 - val_mae: 0.2205 - lr: 4.0000e-06
# Epoch 36/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3310 - ccc_metric: 0.5916 - mae: 0.1914
# Epoch 36: val_ccc_metric did not improve from 0.61504
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1e-06.
# 4167/4167 [==============================] - 354s 68ms/step - loss: 0.3310 - ccc_metric: 0.5916 - mae: 0.1914 - val_loss: 0.3202 - val_ccc_metric: 0.6113 - val_mae: 0.2200 - lr: 4.0000e-06
#
# Epoch 36: val_ccc_metric did not improve from 0.61504
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 1e-06.
# 4167/4167 [==============================] - 354s 68ms/step - loss: 0.3310 - ccc_metric: 0.5916 - mae: 0.1914 - val_loss: 0.3202 - val_ccc_metric: 0.6113 - val_mae: 0.2200 - lr: 4.0000e-06
# Epoch 37/50
# Epoch 37/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3299 - ccc_metric: 0.5932 - mae: 0.1922
# Epoch 37: val_ccc_metric did not improve from 0.61504
# 4167/4167 [==============================] - 354s 69ms/step - loss: 0.3300 - ccc_metric: 0.5931 - mae: 0.1922 - val_loss: 0.3207 - val_ccc_metric: 0.6104 - val_mae: 0.2193 - lr: 1.0000e-06
#
# Epoch 37: val_ccc_metric did not improve from 0.61504
# 4167/4167 [==============================] - 354s 69ms/step - loss: 0.3300 - ccc_metric: 0.5931 - mae: 0.1922 - val_loss: 0.3207 - val_ccc_metric: 0.6104 - val_mae: 0.2193 - lr: 1.0000e-06
# Epoch 38/50
# Epoch 38/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3305 - ccc_metric: 0.5924 - mae: 0.1915
# Epoch 38: val_ccc_metric did not improve from 0.61504
# 4167/4167 [==============================] - 357s 69ms/step - loss: 0.3305 - ccc_metric: 0.5924 - mae: 0.1915 - val_loss: 0.3187 - val_ccc_metric: 0.6129 - val_mae: 0.2183 - lr: 1.0000e-06
#
# Epoch 38: val_ccc_metric did not improve from 0.61504
# 4167/4167 [==============================] - 357s 69ms/step - loss: 0.3305 - ccc_metric: 0.5924 - mae: 0.1915 - val_loss: 0.3187 - val_ccc_metric: 0.6129 - val_mae: 0.2183 - lr: 1.0000e-06
# Epoch 39/50
# Epoch 39/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3313 - ccc_metric: 0.5912 - mae: 0.1917
# Epoch 39: val_ccc_metric did not improve from 0.61504
# 4167/4167 [==============================] - 356s 69ms/step - loss: 0.3313 - ccc_metric: 0.5912 - mae: 0.1917 - val_loss: 0.3171 - val_ccc_metric: 0.6148 - val_mae: 0.2169 - lr: 1.0000e-06
# Epoch 40/50
#
# Epoch 39: val_ccc_metric did not improve from 0.61504
# 4167/4167 [==============================] - 356s 69ms/step - loss: 0.3313 - ccc_metric: 0.5912 - mae: 0.1917 - val_loss: 0.3171 - val_ccc_metric: 0.6148 - val_mae: 0.2169 - lr: 1.0000e-06
# Epoch 40/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3314 - ccc_metric: 0.5911 - mae: 0.1915
# Epoch 40: val_ccc_metric did not improve from 0.61504
# 4167/4167 [==============================] - 356s 69ms/step - loss: 0.3314 - ccc_metric: 0.5911 - mae: 0.1915 - val_loss: 0.3175 - val_ccc_metric: 0.6143 - val_mae: 0.2175 - lr: 1.0000e-06
# Epoch 41/50
#
# Epoch 40: val_ccc_metric did not improve from 0.61504
# 4167/4167 [==============================] - 356s 69ms/step - loss: 0.3314 - ccc_metric: 0.5911 - mae: 0.1915 - val_loss: 0.3175 - val_ccc_metric: 0.6143 - val_mae: 0.2175 - lr: 1.0000e-06
# Epoch 41/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3309 - ccc_metric: 0.5918 - mae: 0.1918
# Epoch 41: val_ccc_metric did not improve from 0.61504
# 4167/4167 [==============================] - 357s 69ms/step - loss: 0.3309 - ccc_metric: 0.5918 - mae: 0.1918 - val_loss: 0.3191 - val_ccc_metric: 0.6124 - val_mae: 0.2183 - lr: 1.0000e-06
# Epoch 42/50
#
# Epoch 41: val_ccc_metric did not improve from 0.61504
# 4167/4167 [==============================] - 357s 69ms/step - loss: 0.3309 - ccc_metric: 0.5918 - mae: 0.1918 - val_loss: 0.3191 - val_ccc_metric: 0.6124 - val_mae: 0.2183 - lr: 1.0000e-06
# Epoch 42/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3304 - ccc_metric: 0.5923 - mae: 0.1913Restoring model weights from the end of the best epoch: 32.
# Restoring model weights from the end of the best epoch: 32.
#
# Epoch 42: val_ccc_metric did not improve from 0.61504
# 4167/4167 [==============================] - 361s 70ms/step - loss: 0.3305 - ccc_metric: 0.5923 - mae: 0.1913 - val_loss: 0.3207 - val_ccc_metric: 0.6103 - val_mae: 0.2187 - lr: 1.0000e-06
# Epoch 42: early stopping
#
# Epoch 42: val_ccc_metric did not improve from 0.61504
# 4167/4167 [==============================] - 361s 70ms/step - loss: 0.3305 - ccc_metric: 0.5923 - mae: 0.1913 - val_loss: 0.3207 - val_ccc_metric: 0.6103 - val_mae: 0.2187 - lr: 1.0000e-06
# Epoch 42: early stopping
#
# ✅ Entrenamiento completado
#
# ✅ Entrenamiento completado
# 💾 Modelo guardado: C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\mer_model_final.keras
# 💾 Modelo guardado: C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\mer_model_final.keras

# %% [markdown]
# ENTRENAMIENTO DESPUÉS DE APLICAR LO DEL #TODO (train mezclado consigo mismo, sin mezclar con val)

# %%
# ============================================================================
# ENTRENAR MODELO
# ============================================================================

print("\n" + "="*70)
print("INICIANDO ENTRENAMIENTO")
print("="*70 + "\n")

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=50,
    callbacks=callbacks_training,
    verbose=1
)

print("\n✅ Entrenamiento completado")

# Guardar modelo
model_final_path = os.path.join(OUTPUT_PATH, 'mer_model_final.keras')
model.save(model_final_path)
print(f"💾 Modelo guardado: {model_final_path}")
# Out:
# ======================================================================
# INICIANDO ENTRENAMIENTO
# ======================================================================
#
# Epoch 1/50
#    4165/Unknown - 134s 26ms/step - loss: 0.7731 - ccc_metric: 0.1966 - mae: 0.6814
# Epoch 1: val_ccc_metric improved from -inf to 0.24199, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 186s 39ms/step - loss: 0.7731 - ccc_metric: 0.1966 - mae: 0.6813 - val_loss: 0.7507 - val_ccc_metric: 0.2420 - val_mae: 0.7369 - lr: 1.0000e-04
# Epoch 2/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.5958 - ccc_metric: 0.3296 - mae: 0.4273
# Epoch 2: val_ccc_metric improved from 0.24199 to 0.41016, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 165s 37ms/step - loss: 0.5958 - ccc_metric: 0.3296 - mae: 0.4273 - val_loss: 0.5133 - val_ccc_metric: 0.4102 - val_mae: 0.3604 - lr: 1.0000e-04
# Epoch 3/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.4592 - ccc_metric: 0.4478 - mae: 0.2404
# Epoch 3: val_ccc_metric improved from 0.41016 to 0.46424, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 153s 33ms/step - loss: 0.4592 - ccc_metric: 0.4479 - mae: 0.2404 - val_loss: 0.4504 - val_ccc_metric: 0.4642 - val_mae: 0.2697 - lr: 1.0000e-04
# Epoch 4/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.4217 - ccc_metric: 0.4884 - mae: 0.2144
# Epoch 4: val_ccc_metric improved from 0.46424 to 0.49731, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 156s 34ms/step - loss: 0.4217 - ccc_metric: 0.4884 - mae: 0.2144 - val_loss: 0.4216 - val_ccc_metric: 0.4973 - val_mae: 0.2605 - lr: 1.0000e-04
# Epoch 5/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.4001 - ccc_metric: 0.5137 - mae: 0.2094
# Epoch 5: val_ccc_metric improved from 0.49731 to 0.52622, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 157s 35ms/step - loss: 0.4001 - ccc_metric: 0.5138 - mae: 0.2094 - val_loss: 0.3959 - val_ccc_metric: 0.5262 - val_mae: 0.2467 - lr: 1.0000e-04
# Epoch 6/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3882 - ccc_metric: 0.5274 - mae: 0.2070
# Epoch 6: val_ccc_metric improved from 0.52622 to 0.54120, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 155s 34ms/step - loss: 0.3882 - ccc_metric: 0.5274 - mae: 0.2070 - val_loss: 0.3827 - val_ccc_metric: 0.5412 - val_mae: 0.2437 - lr: 1.0000e-04
# Epoch 7/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3772 - ccc_metric: 0.5400 - mae: 0.2046
# Epoch 7: val_ccc_metric improved from 0.54120 to 0.55733, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 155s 34ms/step - loss: 0.3773 - ccc_metric: 0.5399 - mae: 0.2046 - val_loss: 0.3679 - val_ccc_metric: 0.5573 - val_mae: 0.2328 - lr: 1.0000e-04
# Epoch 8/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3712 - ccc_metric: 0.5465 - mae: 0.2033
# Epoch 8: val_ccc_metric did not improve from 0.55733
# 4167/4167 [==============================] - 168s 37ms/step - loss: 0.3712 - ccc_metric: 0.5466 - mae: 0.2033 - val_loss: 0.3746 - val_ccc_metric: 0.5494 - val_mae: 0.2431 - lr: 1.0000e-04
# Epoch 9/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3664 - ccc_metric: 0.5518 - mae: 0.2022
# Epoch 9: val_ccc_metric improved from 0.55733 to 0.56950, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 157s 34ms/step - loss: 0.3663 - ccc_metric: 0.5518 - mae: 0.2022 - val_loss: 0.3571 - val_ccc_metric: 0.5695 - val_mae: 0.2319 - lr: 1.0000e-04
# Epoch 10/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3599 - ccc_metric: 0.5592 - mae: 0.2003
# Epoch 10: val_ccc_metric improved from 0.56950 to 0.58372, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 151s 33ms/step - loss: 0.3599 - ccc_metric: 0.5593 - mae: 0.2002 - val_loss: 0.3448 - val_ccc_metric: 0.5837 - val_mae: 0.2250 - lr: 1.0000e-04
# Epoch 11/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3561 - ccc_metric: 0.5635 - mae: 0.1995
# Epoch 11: val_ccc_metric did not improve from 0.58372
# 4167/4167 [==============================] - 151s 34ms/step - loss: 0.3561 - ccc_metric: 0.5635 - mae: 0.1995 - val_loss: 0.3547 - val_ccc_metric: 0.5717 - val_mae: 0.2348 - lr: 1.0000e-04
# Epoch 12/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3519 - ccc_metric: 0.5681 - mae: 0.1983
# Epoch 12: val_ccc_metric did not improve from 0.58372
# 4167/4167 [==============================] - 150s 33ms/step - loss: 0.3519 - ccc_metric: 0.5681 - mae: 0.1983 - val_loss: 0.3462 - val_ccc_metric: 0.5813 - val_mae: 0.2292 - lr: 1.0000e-04
# Epoch 13/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3483 - ccc_metric: 0.5721 - mae: 0.1977
# Epoch 13: val_ccc_metric did not improve from 0.58372
# 4167/4167 [==============================] - 151s 33ms/step - loss: 0.3484 - ccc_metric: 0.5721 - mae: 0.1977 - val_loss: 0.3532 - val_ccc_metric: 0.5730 - val_mae: 0.2360 - lr: 1.0000e-04
# Epoch 14/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3452 - ccc_metric: 0.5756 - mae: 0.1966
# Epoch 14: val_ccc_metric improved from 0.58372 to 0.58985, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 151s 33ms/step - loss: 0.3452 - ccc_metric: 0.5756 - mae: 0.1966 - val_loss: 0.3386 - val_ccc_metric: 0.5899 - val_mae: 0.2262 - lr: 1.0000e-04
# Epoch 15/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3423 - ccc_metric: 0.5789 - mae: 0.1960
# Epoch 15: val_ccc_metric improved from 0.58985 to 0.59912, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 152s 33ms/step - loss: 0.3424 - ccc_metric: 0.5788 - mae: 0.1960 - val_loss: 0.3308 - val_ccc_metric: 0.5991 - val_mae: 0.2225 - lr: 1.0000e-04
# Epoch 16/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3404 - ccc_metric: 0.5810 - mae: 0.1955
# Epoch 16: val_ccc_metric did not improve from 0.59912
# 4167/4167 [==============================] - 152s 34ms/step - loss: 0.3404 - ccc_metric: 0.5810 - mae: 0.1955 - val_loss: 0.3322 - val_ccc_metric: 0.5966 - val_mae: 0.2219 - lr: 1.0000e-04
# Epoch 17/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3364 - ccc_metric: 0.5856 - mae: 0.1943
# Epoch 17: val_ccc_metric improved from 0.59912 to 0.60094, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 153s 34ms/step - loss: 0.3365 - ccc_metric: 0.5856 - mae: 0.1943 - val_loss: 0.3286 - val_ccc_metric: 0.6009 - val_mae: 0.2209 - lr: 1.0000e-04
# Epoch 18/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3360 - ccc_metric: 0.5859 - mae: 0.1942
# Epoch 18: val_ccc_metric improved from 0.60094 to 0.60198, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 153s 34ms/step - loss: 0.3360 - ccc_metric: 0.5859 - mae: 0.1942 - val_loss: 0.3278 - val_ccc_metric: 0.6020 - val_mae: 0.2225 - lr: 1.0000e-04
# Epoch 19/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3344 - ccc_metric: 0.5877 - mae: 0.1935
# Epoch 19: val_ccc_metric improved from 0.60198 to 0.60411, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 154s 34ms/step - loss: 0.3343 - ccc_metric: 0.5877 - mae: 0.1935 - val_loss: 0.3264 - val_ccc_metric: 0.6041 - val_mae: 0.2247 - lr: 1.0000e-04
# Epoch 20/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3314 - ccc_metric: 0.5912 - mae: 0.1926
# Epoch 20: val_ccc_metric improved from 0.60411 to 0.60766, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 154s 34ms/step - loss: 0.3314 - ccc_metric: 0.5912 - mae: 0.1926 - val_loss: 0.3228 - val_ccc_metric: 0.6077 - val_mae: 0.2204 - lr: 1.0000e-04
# Epoch 21/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3302 - ccc_metric: 0.5925 - mae: 0.1924
# Epoch 21: val_ccc_metric improved from 0.60766 to 0.61409, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 154s 34ms/step - loss: 0.3302 - ccc_metric: 0.5925 - mae: 0.1924 - val_loss: 0.3170 - val_ccc_metric: 0.6141 - val_mae: 0.2153 - lr: 1.0000e-04
# Epoch 22/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3287 - ccc_metric: 0.5942 - mae: 0.1921
# Epoch 22: val_ccc_metric did not improve from 0.61409
# 4167/4167 [==============================] - 154s 34ms/step - loss: 0.3287 - ccc_metric: 0.5942 - mae: 0.1921 - val_loss: 0.3199 - val_ccc_metric: 0.6116 - val_mae: 0.2225 - lr: 1.0000e-04
# Epoch 23/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3269 - ccc_metric: 0.5963 - mae: 0.1913
# Epoch 23: val_ccc_metric did not improve from 0.61409
# 4167/4167 [==============================] - 155s 34ms/step - loss: 0.3269 - ccc_metric: 0.5962 - mae: 0.1913 - val_loss: 0.3373 - val_ccc_metric: 0.5891 - val_mae: 0.2270 - lr: 1.0000e-04
# Epoch 24/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3256 - ccc_metric: 0.5977 - mae: 0.1909
# Epoch 24: val_ccc_metric did not improve from 0.61409
# 4167/4167 [==============================] - 155s 34ms/step - loss: 0.3256 - ccc_metric: 0.5977 - mae: 0.1909 - val_loss: 0.3236 - val_ccc_metric: 0.6059 - val_mae: 0.2219 - lr: 1.0000e-04
# Epoch 25/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3239 - ccc_metric: 0.5998 - mae: 0.1903
# Epoch 25: val_ccc_metric did not improve from 0.61409
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 4167/4167 [==============================] - 155s 34ms/step - loss: 0.3239 - ccc_metric: 0.5998 - mae: 0.1903 - val_loss: 0.3189 - val_ccc_metric: 0.6114 - val_mae: 0.2185 - lr: 1.0000e-04
# Epoch 26/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3229 - ccc_metric: 0.6009 - mae: 0.1900
# Epoch 26: val_ccc_metric did not improve from 0.61409
# 4167/4167 [==============================] - 156s 34ms/step - loss: 0.3229 - ccc_metric: 0.6009 - mae: 0.1900 - val_loss: 0.3200 - val_ccc_metric: 0.6108 - val_mae: 0.2226 - lr: 2.0000e-05
# Epoch 27/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3208 - ccc_metric: 0.6034 - mae: 0.1893
# Epoch 27: val_ccc_metric improved from 0.61409 to 0.61859, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 156s 34ms/step - loss: 0.3208 - ccc_metric: 0.6034 - mae: 0.1893 - val_loss: 0.3133 - val_ccc_metric: 0.6186 - val_mae: 0.2174 - lr: 2.0000e-05
# Epoch 28/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3217 - ccc_metric: 0.6023 - mae: 0.1893
# Epoch 28: val_ccc_metric did not improve from 0.61859
# 4167/4167 [==============================] - 156s 34ms/step - loss: 0.3217 - ccc_metric: 0.6023 - mae: 0.1893 - val_loss: 0.3159 - val_ccc_metric: 0.6157 - val_mae: 0.2201 - lr: 2.0000e-05
# Epoch 29/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3197 - ccc_metric: 0.6048 - mae: 0.1889
# Epoch 29: val_ccc_metric improved from 0.61859 to 0.61884, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 156s 34ms/step - loss: 0.3197 - ccc_metric: 0.6048 - mae: 0.1889 - val_loss: 0.3131 - val_ccc_metric: 0.6188 - val_mae: 0.2176 - lr: 2.0000e-05
# Epoch 30/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3197 - ccc_metric: 0.6048 - mae: 0.1888
# Epoch 30: val_ccc_metric did not improve from 0.61884
# 4167/4167 [==============================] - 155s 34ms/step - loss: 0.3197 - ccc_metric: 0.6048 - mae: 0.1888 - val_loss: 0.3151 - val_ccc_metric: 0.6161 - val_mae: 0.2176 - lr: 2.0000e-05
# Epoch 31/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3189 - ccc_metric: 0.6057 - mae: 0.1886
# Epoch 31: val_ccc_metric improved from 0.61884 to 0.62143, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 156s 34ms/step - loss: 0.3189 - ccc_metric: 0.6057 - mae: 0.1886 - val_loss: 0.3111 - val_ccc_metric: 0.6214 - val_mae: 0.2174 - lr: 2.0000e-05
# Epoch 32/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3189 - ccc_metric: 0.6057 - mae: 0.1885
# Epoch 32: val_ccc_metric improved from 0.62143 to 0.62346, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 157s 34ms/step - loss: 0.3189 - ccc_metric: 0.6057 - mae: 0.1885 - val_loss: 0.3091 - val_ccc_metric: 0.6235 - val_mae: 0.2146 - lr: 2.0000e-05
# Epoch 33/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3185 - ccc_metric: 0.6061 - mae: 0.1883
# Epoch 33: val_ccc_metric did not improve from 0.62346
# 4167/4167 [==============================] - 155s 34ms/step - loss: 0.3185 - ccc_metric: 0.6061 - mae: 0.1883 - val_loss: 0.3111 - val_ccc_metric: 0.6211 - val_mae: 0.2171 - lr: 2.0000e-05
# Epoch 34/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3189 - ccc_metric: 0.6056 - mae: 0.1885
# Epoch 34: val_ccc_metric improved from 0.62346 to 0.62743, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 157s 34ms/step - loss: 0.3189 - ccc_metric: 0.6056 - mae: 0.1885 - val_loss: 0.3056 - val_ccc_metric: 0.6274 - val_mae: 0.2117 - lr: 2.0000e-05
# Epoch 35/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3186 - ccc_metric: 0.6060 - mae: 0.1882
# Epoch 35: val_ccc_metric did not improve from 0.62743
# 4167/4167 [==============================] - 156s 34ms/step - loss: 0.3186 - ccc_metric: 0.6060 - mae: 0.1882 - val_loss: 0.3164 - val_ccc_metric: 0.6148 - val_mae: 0.2207 - lr: 2.0000e-05
# Epoch 36/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3179 - ccc_metric: 0.6068 - mae: 0.1883
# Epoch 36: val_ccc_metric did not improve from 0.62743
# 4167/4167 [==============================] - 158s 34ms/step - loss: 0.3179 - ccc_metric: 0.6068 - mae: 0.1883 - val_loss: 0.3111 - val_ccc_metric: 0.6207 - val_mae: 0.2152 - lr: 2.0000e-05
# Epoch 37/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3173 - ccc_metric: 0.6075 - mae: 0.1880
# Epoch 37: val_ccc_metric did not improve from 0.62743
# 4167/4167 [==============================] - 158s 34ms/step - loss: 0.3173 - ccc_metric: 0.6074 - mae: 0.1880 - val_loss: 0.3144 - val_ccc_metric: 0.6171 - val_mae: 0.2194 - lr: 2.0000e-05
# Epoch 38/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3172 - ccc_metric: 0.6076 - mae: 0.1878
# Epoch 38: val_ccc_metric did not improve from 0.62743
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 4167/4167 [==============================] - 159s 34ms/step - loss: 0.3172 - ccc_metric: 0.6076 - mae: 0.1878 - val_loss: 0.3127 - val_ccc_metric: 0.6190 - val_mae: 0.2177 - lr: 2.0000e-05
# Epoch 39/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3169 - ccc_metric: 0.6080 - mae: 0.1885
# Epoch 39: val_ccc_metric did not improve from 0.62743
# 4167/4167 [==============================] - 156s 34ms/step - loss: 0.3169 - ccc_metric: 0.6080 - mae: 0.1885 - val_loss: 0.3095 - val_ccc_metric: 0.6226 - val_mae: 0.2148 - lr: 4.0000e-06
# Epoch 40/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3166 - ccc_metric: 0.6082 - mae: 0.1876
# Epoch 40: val_ccc_metric did not improve from 0.62743
# 4167/4167 [==============================] - 158s 34ms/step - loss: 0.3166 - ccc_metric: 0.6083 - mae: 0.1876 - val_loss: 0.3076 - val_ccc_metric: 0.6249 - val_mae: 0.2135 - lr: 4.0000e-06
# Epoch 41/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3168 - ccc_metric: 0.6081 - mae: 0.1879
# Epoch 41: val_ccc_metric did not improve from 0.62743
# 4167/4167 [==============================] - 158s 34ms/step - loss: 0.3168 - ccc_metric: 0.6081 - mae: 0.1879 - val_loss: 0.3126 - val_ccc_metric: 0.6189 - val_mae: 0.2168 - lr: 4.0000e-06
# Epoch 42/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3158 - ccc_metric: 0.6093 - mae: 0.1876
# Epoch 42: val_ccc_metric did not improve from 0.62743
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 1e-06.
# 4167/4167 [==============================] - 157s 34ms/step - loss: 0.3158 - ccc_metric: 0.6093 - mae: 0.1876 - val_loss: 0.3078 - val_ccc_metric: 0.6248 - val_mae: 0.2141 - lr: 4.0000e-06
# Epoch 43/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3160 - ccc_metric: 0.6092 - mae: 0.1883
# Epoch 43: val_ccc_metric improved from 0.62743 to 0.62846, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 161s 35ms/step - loss: 0.3160 - ccc_metric: 0.6092 - mae: 0.1883 - val_loss: 0.3045 - val_ccc_metric: 0.6285 - val_mae: 0.2102 - lr: 1.0000e-06
# Epoch 44/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3165 - ccc_metric: 0.6084 - mae: 0.1880
# Epoch 44: val_ccc_metric improved from 0.62846 to 0.63013, saving model to C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\best_mer_model.keras
# 4167/4167 [==============================] - 160s 34ms/step - loss: 0.3165 - ccc_metric: 0.6084 - mae: 0.1880 - val_loss: 0.3032 - val_ccc_metric: 0.6301 - val_mae: 0.2095 - lr: 1.0000e-06
# Epoch 45/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3162 - ccc_metric: 0.6088 - mae: 0.1878
# Epoch 45: val_ccc_metric did not improve from 0.63013
# 4167/4167 [==============================] - 161s 35ms/step - loss: 0.3162 - ccc_metric: 0.6088 - mae: 0.1878 - val_loss: 0.3036 - val_ccc_metric: 0.6295 - val_mae: 0.2097 - lr: 1.0000e-06
# Epoch 46/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3177 - ccc_metric: 0.6069 - mae: 0.1884
# Epoch 46: val_ccc_metric did not improve from 0.63013
# 4167/4167 [==============================] - 162s 35ms/step - loss: 0.3177 - ccc_metric: 0.6069 - mae: 0.1884 - val_loss: 0.3050 - val_ccc_metric: 0.6278 - val_mae: 0.2104 - lr: 1.0000e-06
# Epoch 47/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3169 - ccc_metric: 0.6079 - mae: 0.1878
# Epoch 47: val_ccc_metric did not improve from 0.63013
# 4167/4167 [==============================] - 162s 35ms/step - loss: 0.3169 - ccc_metric: 0.6079 - mae: 0.1878 - val_loss: 0.3055 - val_ccc_metric: 0.6273 - val_mae: 0.2107 - lr: 1.0000e-06
# Epoch 48/50
# 4165/4167 [============================>.] - ETA: 0s - loss: 0.3175 - ccc_metric: 0.6072 - mae: 0.1880
# Epoch 48: val_ccc_metric did not improve from 0.63013
# 4167/4167 [==============================] - 161s 35ms/step - loss: 0.3174 - ccc_metric: 0.6072 - mae: 0.1880 - val_loss: 0.3058 - val_ccc_metric: 0.6268 - val_mae: 0.2108 - lr: 1.0000e-06
# Epoch 49/50
# 4166/4167 [============================>.] - ETA: 0s - loss: 0.3168 - ccc_metric: 0.6080 - mae: 0.1878
# Epoch 49: val_ccc_metric did not improve from 0.63013
# 4167/4167 [==============================] - 162s 35ms/step - loss: 0.3168 - ccc_metric: 0.6080 - mae: 0.1878 - val_loss: 0.3055 - val_ccc_metric: 0.6272 - val_mae: 0.2104 - lr: 1.0000e-06
# Epoch 50/50
# 4167/4167 [==============================] - ETA: 0s - loss: 0.3175 - ccc_metric: 0.6072 - mae: 0.1880
# Epoch 50: val_ccc_metric did not improve from 0.63013
# 4167/4167 [==============================] - 160s 34ms/step - loss: 0.3175 - ccc_metric: 0.6072 - mae: 0.1880 - val_loss: 0.3051 - val_ccc_metric: 0.6276 - val_mae: 0.2101 - lr: 1.0000e-06
#
# ✅ Entrenamiento completado
# 💾 Modelo guardado: C:/Users/thepe/Downloads/preprocessed_improved_features_FIXED\mer_model_final.keras

# %% [markdown]
# ENTRENAMIENTO ANTES DE APLICAR #TODO

# %%
# ============================================================================
# VISUALIZAR RESULTADOS DEL ENTRENAMIENTO
# ============================================================================

import matplotlib.pyplot as plt

h = history.history
epochs_range = range(1, len(h['loss']) + 1)

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Loss
axes[0].plot(epochs_range, h['loss'], 'o-', label='Train Loss', linewidth=2)
axes[0].plot(epochs_range, h['val_loss'], 's-', label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].set_title('Combined Loss (30% MSE + 70% CCC)')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# MAE
axes[1].plot(epochs_range, h['mae'], 'o-', label='Train MAE', linewidth=2)
axes[1].plot(epochs_range, h['val_mae'], 's-', label='Val MAE', linewidth=2)
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('MAE')
axes[1].set_title('Mean Absolute Error')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

# CCC Metric
if 'ccc_metric' in h:
    axes[2].plot(epochs_range, h['ccc_metric'], 'o-', label='Train CCC', linewidth=2)
    axes[2].plot(epochs_range, h['val_ccc_metric'], 's-', label='Val CCC', linewidth=2)
    axes[2].set_xlabel('Epoch')
    axes[2].set_ylabel('CCC')
    axes[2].set_title('Concordance Correlation Coefficient')
    axes[2].legend()
    axes[2].grid(True, alpha=0.3)
else:
    axes[2].text(0.5, 0.5, 'CCC no disponible', ha='center', va='center')
    axes[2].axis('off')

plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_PATH, 'training_curves.png'), dpi=100, bbox_inches='tight')
plt.show()

# Resumen
print("\n" + "="*70)
print("RESUMEN DE ENTRENAMIENTO")
print("="*70)
print(f"Épocas entrenadas: {len(h['loss'])}")
print(f"Mejor val_loss: {min(h['val_loss']):.6f}")
print(f"Mejor val_mae: {min(h['val_mae']):.6f}")
if 'val_ccc_metric' in h:
    print(f"Mejor val_ccc_metric: {max(h['val_ccc_metric']):.6f}")
print("="*70)
# Out:
# ======================================================================
# RESUMEN DE ENTRENAMIENTO
# ======================================================================
# Épocas entrenadas: 42
# Mejor val_loss: 0.317056
# Mejor val_mae: 0.216943
# Mejor val_ccc_metric: 0.615045
# ======================================================================

# %% [markdown]
# ENTRENAMIENTO DESPUÉS DE APLICAR #TODO

# %%
# ============================================================================
# VISUALIZAR RESULTADOS DEL ENTRENAMIENTO
# ============================================================================

import matplotlib.pyplot as plt

h = history.history
epochs_range = range(1, len(h['loss']) + 1)

fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# Loss
axes[0].plot(epochs_range, h['loss'], 'o-', label='Train Loss', linewidth=2)
axes[0].plot(epochs_range, h['val_loss'], 's-', label='Val Loss', linewidth=2)
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].set_title('Combined Loss (50% MSE + 50% CCC)')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# MAE
axes[1].plot(epochs_range, h['mae'], 'o-', label='Train MAE', linewidth=2)
axes[1].plot(epochs_range, h['val_mae'], 's-', label='Val MAE', linewidth=2)
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('MAE')
axes[1].set_title('Mean Absolute Error')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

# CCC Metric
if 'ccc_metric' in h:
    axes[2].plot(epochs_range, h['ccc_metric'], 'o-', label='Train CCC', linewidth=2)
    axes[2].plot(epochs_range, h['val_ccc_metric'], 's-', label='Val CCC', linewidth=2)
    axes[2].set_xlabel('Epoch')
    axes[2].set_ylabel('CCC')
    axes[2].set_title('Concordance Correlation Coefficient')
    axes[2].legend()
    axes[2].grid(True, alpha=0.3)
else:
    axes[2].text(0.5, 0.5, 'CCC no disponible', ha='center', va='center')
    axes[2].axis('off')

plt.tight_layout()
plt.savefig(os.path.join(OUTPUT_PATH, 'training_curves.png'), dpi=100, bbox_inches='tight')
plt.show()

# Resumen
print("\n" + "="*70)
print("RESUMEN DE ENTRENAMIENTO")
print("="*70)
print(f"Épocas entrenadas: {len(h['loss'])}")
print(f"Mejor val_loss: {min(h['val_loss']):.6f}")
print(f"Mejor val_mae: {min(h['val_mae']):.6f}")
if 'val_ccc_metric' in h:
    print(f"Mejor val_ccc_metric: {max(h['val_ccc_metric']):.6f}")
print("="*70)
# Out:
# ======================================================================
# RESUMEN DE ENTRENAMIENTO
# ======================================================================
# Épocas entrenadas: 50
# Mejor val_loss: 0.303161
# Mejor val_mae: 0.209538
# Mejor val_ccc_metric: 0.630127
# ======================================================================

# %% [markdown]
# ### EDICIÓN PEQUEÑA - VISUALIZACIÓN DE DATOS - 21:00 19/04/26 ###

# %%
# ============================================================================
# GRÁFICOS INDIVIDUALES PARA INFORME CRISP-DM
# ============================================================================
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np
import os

# Asegurar que tenemos un audio cargado para las gráficas
if 'y' not in locals() or 'sr' not in locals():
    test_audio = 'C:/Users/thepe/Downloads/DEAM/DEAM_audio/MEMD_audio/2.mp3'
    if os.path.exists(test_audio):
        print(f'Cargando audio de prueba para graficar: {test_audio}')
        y, sr = librosa.load(test_audio, sr=22050, duration=15)
    else:
        print('Por favor, indica un archivo de audio .mp3 válido en y, sr')

plt.figure(figsize=(12, 4))
# 1. Mel Spectrogram
S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=64, hop_length=512)
S_db = librosa.power_to_db(S, ref=np.max)
librosa.display.specshow(S_db, x_axis='time', y_axis='mel', sr=sr, fmax=8000, hop_length=512, cmap='magma')
plt.colorbar(format='%+2.0f dB')
plt.title('1. Mel Spectrogram (64 bandas)', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 4))
# 2. MFCC
mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13, hop_length=512)
librosa.display.specshow(mfcc, x_axis='time', sr=sr, hop_length=512, cmap='viridis')
plt.colorbar()
plt.title('2. MFCC (13 coeficientes)', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 4))
# 3. Chroma CQT
chroma_cqt = librosa.feature.chroma_cqt(y=y, sr=sr, hop_length=512)
librosa.display.specshow(chroma_cqt, x_axis='time', y_axis='chroma', sr=sr, hop_length=512, cmap='coolwarm')
plt.colorbar()
plt.title('3. Chroma CQT (12 Clases de Tono)', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 4))
# 4. Spectral Centroid
centroid = librosa.feature.spectral_centroid(y=y, sr=sr, hop_length=512)
plt.plot(centroid[0], color='blue')
plt.title('4. Spectral Centroid (Centroide Espectral)', fontsize=14, fontweight='bold')
plt.ylabel('Frecuencia (Hz)')
plt.xlabel('Tramas (Frames)')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 4))
# 5. Spectral Bandwidth
bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr, hop_length=512)
plt.plot(bandwidth[0], color='purple')
plt.title('5. Spectral Bandwidth (Ancho de Banda)', fontsize=14, fontweight='bold')
plt.ylabel('Frecuencia (Hz)')
plt.xlabel('Tramas (Frames)')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 4))
# 6. Spectral Rolloff
rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr, hop_length=512)
plt.plot(rolloff[0], color='orange')
plt.title('6. Spectral Rolloff (Frecuencia de Corte)', fontsize=14, fontweight='bold')
plt.ylabel('Frecuencia (Hz)')
plt.xlabel('Tramas (Frames)')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 4))
# 7. RMS Energy
rms = librosa.feature.rms(y=y, hop_length=512)
plt.plot(rms[0], color='darkcyan')
plt.title('7. RMS Energy (Energía Cuadrática Media)', fontsize=14, fontweight='bold')
plt.ylabel('Amplitud')
plt.xlabel('Tramas (Frames)')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 4))
# 8. Spectral Contrast
contrast = librosa.feature.spectral_contrast(y=y, sr=sr, hop_length=512)
librosa.display.specshow(contrast, x_axis='time', sr=sr, hop_length=512, cmap='coolwarm')
plt.colorbar(label='Diferencia Pico-Valle (dB)')
plt.title('8. Spectral Contrast (7 bandas)', fontsize=14, fontweight='bold')
plt.ylabel('Bandas (Frecuencia)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 4))
# 9. Zero Crossing Rate (ZCR)
zcr = librosa.feature.zero_crossing_rate(y=y, hop_length=512)
plt.plot(zcr[0], color='green')
plt.title('9. Zero Crossing Rate (ZCR)', fontsize=14, fontweight='bold')
plt.ylabel('Tasa de Cruces')
plt.xlabel('Tramas (Frames)')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 4))
# 10. Spectral Flatness
flatness = librosa.feature.spectral_flatness(y=y, hop_length=512)
plt.plot(flatness[0], color='red')
plt.title('10. Spectral Flatness (Planicidad Espectral)', fontsize=14, fontweight='bold')
plt.ylabel('Planicidad')
plt.xlabel('Tramas (Frames)')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
